# %% [markdown]
# <a href="https://colab.research.google.com/github/mevah/nailsalon/blob/master/Reuters_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connecting to the Reuters Connect API

# %% [markdown]
# How to access the **Reuters Connect API Developer Guide**:
# * http://liaison.reuters.com/
# * Choose 'Web Services - API' from dropdown menu
# * Click on 'Related Content' tab
# * Download 'API Developer Guide' (and 'XML Quick Reference')
#
# Further documentation: https://docs.google.com/document/d/14Uiys8TKyoeYfSB8TBEzwlGwvUK-PjxnyuHN-uh2BQg/edit#heading=h.m8140bfkyycf

# %% [markdown]
# ### Imports

# %%
import requests

# If you do not have any of the packages installed, e.g. requests - uncomment the line below to install.
# !pip3 install requests 

import json

from datetime import datetime

# %% [markdown]
# ### 1. Obtain a token for web services with your username and password

# %% [markdown]
# **Username** alternatives: HackAPI1, HackAPI2

# %%
username = 'HackAPI2'

# %% [markdown]
# Please retrieve the required **passwords** from the mentors on the day.

# %%
password = 'xmwMsuGfdqhXRGV' # needs to be adjusted!

# %% [markdown]
# Constructing the url to obtain the authorisation token.

# %%
auth_url = "https://commerce.reuters.com/rmd/rest/xml/login?username=" + username + "&password=" + password + "&format=json"
auth_url
# Out:
# 'https://commerce.reuters.com/rmd/rest/xml/login?username=HackAPI2&password=xmwMsuGfdqhXRGV&format=json'

# %% [markdown]
# Sending a GET request to obtain the authorisation token.

# %%
response = requests.get(auth_url)

# %% [markdown]
# Drilling down into the response to obtain the **authorisation token** and loading the response as json.

# %%
authToken = json.loads(response.text).get('authToken').get('authToken')
authToken
# Out:
# '8vsT3ETAUZaiVRklHIqY7typIwTzvjss81kIX5wuiTI='

# %% [markdown]
# **Note**: The authentication token is valid for 24 hours. Once obtained, it should be cached on your client-side and reused in subsequent calls made by other methods during the 24-hour long period.
# When the token expires, you will get an authentication error.

# %% [markdown]
# ### 2. Obtain a list of the channels to which you have access

# %%
channels_url = 'http://rmb.reuters.com/rmd/rest/json/channels?token=' + authToken + '&format=json'

# %% [markdown]
# Overriding the value of the previous response with the result for channels.

# %%
response = requests.get(channels_url)

# %%
channels = json.loads(response.text)
channels
# Out:
# {'channelIds': [158,
#   675,
#   24217,
#   585,
#   1,
#   644,
#   24242,
#   718,
#   27055,
#   61670,
#   61669,
#   656,
#   61672,
#   27052,
#   676,
#   81607,
#   176033,
#   32220,
#   174,
#   61667,
#   61671,
#   674,
#   106821,
#   61668],
#  'channelInformation': [{'alias': 'CLE548',
#    'availableContentProfiles': ['NEP-External_ANP'],
#    'category': {'description': 'Online Video', 'id': 'OLV'},
#    'description': 'BVO',
#    'lastArrivalInternal': '2019-11-01T22:37:26Z',
#    'lastUpdate': '2019-11-01T22:35:05Z'},
#   {'alias': 'Efm208',
#    'availableContentProfiles': ['SNI-Graphic'],
#    'category': {'description': 'Graphics', 'id': 'GRA'},
#    'description': 'French Language News Graphics Service',
#    'lastArrivalInternal': '2019-11-01T12:36:05Z',
#    'lastUpdate': '2019-11-01T12:35:30Z'},
#   {'alias': 'FES376',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'USA', 'id': 'OLR:USA'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'US Online Report Top News',
#    'lastArrivalInternal': '2019-11-02T13:00:28Z',
#    'lastUpdate': '2019-11-02T13:00:23Z'},
#   {'alias': 'HkV652',
#    'availableContentProfiles': ['SNI-Text'],
#    'category': {'description': 'Text', 'id': 'TXT'},
#    'description': 'German General News Service',
#    'lastArrivalInternal': '2019-11-02T13:27:16Z',
#    'lastUpdate': '2019-11-02T13:27:14Z'},
#   {'alias': 'Iwu647',
#    'availableContentProfiles': ['NEP-External_ANP'],
#    'category': {'description': 'Online Video', 'id': 'OLV'},
#    'description': 'EVO',
#    'lastArrivalInternal': '2019-11-01T18:12:59Z',
#    'lastUpdate': '2019-11-01T18:11:05Z'},
#   {'alias': 'STK567',
#    'availableContentProfiles': ['SNI-Text'],
#    'category': {'description': 'Text', 'id': 'TXT'},
#    'description': 'Reuters World Service',
#    'lastArrivalInternal': '2019-11-02T13:27:58Z',
#    'lastUpdate': '2019-11-02T13:27:55Z'},
#   {'alias': 'TRn222',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'UK', 'id': 'OLR:GBR'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'UK Online Report Top News',
#    'lastArrivalInternal': '2019-11-02T13:06:58Z',
#    'lastUpdate': '2019-11-02T13:06:54Z'},
#   {'alias': 'UXR369',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'France', 'id': 'OLR:FRA'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'France Online Report Top News',
#    'lastArrivalInternal': '2019-11-02T13:20:20Z',
#    'lastUpdate': '2019-11-02T13:20:19Z'},
#   {'alias': 'afj497',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'Germany Online Report Top News',
#    'lastArrivalInternal': '2019-11-01T15:38:43Z',
#    'lastUpdate': '2019-11-01T15:38:40Z'},
#   {'alias': 'dja779',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Markets',
#    'lastArrivalInternal': '2019-11-01T17:10:25Z',
#    'lastUpdate': '2019-11-01T17:10:22Z'},
#   {'alias': 'hro568',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Economy',
#    'lastArrivalInternal': '2019-11-01T16:53:36Z',
#    'lastUpdate': '2019-11-01T16:53:31Z'},
#   {'alias': 'jyn629',
#    'availableContentProfiles': ['SNI-Text'],
#    'category': {'description': 'Text', 'id': 'TXT'},
#    'description': 'Swiss Domestic News Service German',
#    'lastArrivalInternal': '2019-11-02T13:27:16Z',
#    'lastUpdate': '2019-11-02T13:27:14Z'},
#   {'alias': 'nch777',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR World',
#    'lastArrivalInternal': '2019-11-01T15:38:45Z',
#    'lastUpdate': '2019-11-01T15:38:42Z'},
#   {'alias': 'nld052',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'Germany Online Report World News',
#    'lastArrivalInternal': '2019-11-01T15:38:44Z',
#    'lastUpdate': '2019-11-01T15:38:42Z'},
#   {'alias': 'oYM964',
#    'availableContentProfiles': ['SNI-Graphic'],
#    'category': {'description': 'Graphics', 'id': 'GRA'},
#    'description': 'Spanish Language News Graphics Service',
#    'lastArrivalInternal': '2019-11-01T16:14:10Z',
#    'lastUpdate': '2019-11-01T16:13:59Z'},
#   {'alias': 'pbn620',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Politics'},
#   {'alias': 'pwu404',
#    'availableContentProfiles': ['SNI-Picture'],
#    'category': {'description': 'Pictures', 'id': 'PIC'},
#    'description': 'Reuters News Picture Service - RNPS',
#    'lastArrivalInternal': '2019-11-02T13:31:38Z',
#    'lastUpdate': '2019-11-02T13:31:22Z'},
#   {'alias': 'shl347',
#    'availableContentProfiles': ['SNI-Graphic'],
#    'category': {'description': 'Graphics', 'id': 'GRA'},
#    'description': 'Reuters Interactive Graphics',
#    'lastArrivalInternal': '2019-11-01T23:31:07Z',
#    'lastUpdate': '2019-11-01T23:30:49Z'},
#   {'alias': 'sst663',
#    'availableContentProfiles': ['NEP-External_ANP'],
#    'category': {'description': 'Online Video', 'id': 'OLV'},
#    'description': 'GNVO',
#    'lastArrivalInternal': '2019-11-02T13:30:10Z',
#    'lastUpdate': '2019-11-02T13:19:04Z'},
#   {'alias': 'ucz335',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Company',
#    'lastArrivalInternal': '2019-11-01T15:41:17Z',
#    'lastUpdate': '2019-11-01T15:41:06Z'},
#   {'alias': 'uzq030',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Top',
#    'lastArrivalInternal': '2019-11-01T15:38:46Z',
#    'lastUpdate': '2019-11-01T15:38:40Z'},
#   {'alias': 'wbq437',
#    'availableContentProfiles': ['SNI-Graphic'],
#    'category': {'description': 'Graphics', 'id': 'GRA'},
#    'description': 'English Language News Graphics Service',
#    'lastArrivalInternal': '2019-11-01T15:42:50Z',
#    'lastUpdate': '2019-11-01T15:42:16Z'},
#   {'alias': 'xbt154',
#    'availableContentProfiles': ['NEP-External_ANP'],
#    'category': {'description': 'Online Video', 'id': 'OLV'},
#    'description': 'Captioned Online Video - German',
#    'lastArrivalInternal': '2019-07-12T14:58:56Z',
#    'lastUpdate': '2019-07-12T14:58:35Z'},
#   {'alias': 'xnk712',
#    'availableContentProfiles': ['SNI-Text',
#     'SNI-Picture',
#     'NEP-External',
#     'SNEP-External'],
#    'category': {'category': {'description': 'Germany', 'id': 'OLR:DEU'},
#     'description': 'Online Reports',
#     'id': 'OLR'},
#    'description': 'DNP Basic Germany OLR Domestic',
#    'lastArrivalInternal': '2019-11-01T14:25:03Z',
#    'lastUpdate': '2019-11-01T14:24:59Z'}],
#  'status': {'code': 10}}

# %% [markdown]
# All descriptions of the available channels are listed below.

# %%
descriptions = [value.get('description') for value in channels.get('channelInformation')]
descriptions
# Out:
# ['BVO',
#  'French Language News Graphics Service',
#  'US Online Report Top News',
#  'German General News Service',
#  'EVO',
#  'Reuters World Service',
#  'UK Online Report Top News',
#  'France Online Report Top News',
#  'Germany Online Report Top News',
#  'DNP Basic Germany OLR Markets',
#  'DNP Basic Germany OLR Economy',
#  'Swiss Domestic News Service German',
#  'DNP Basic Germany OLR World',
#  'Germany Online Report World News',
#  'Spanish Language News Graphics Service',
#  'DNP Basic Germany OLR Politics',
#  'Reuters News Picture Service - RNPS',
#  'Reuters Interactive Graphics',
#  'GNVO',
#  'DNP Basic Germany OLR Company',
#  'DNP Basic Germany OLR Top',
#  'English Language News Graphics Service',
#  'Captioned Online Video - German',
#  'DNP Basic Germany OLR Domestic']

# %%
aliases = [value.get('alias') for value in channels.get('channelInformation')]
aliases  # will be used for the next step
# Out:
# ['CLE548',
#  'Efm208',
#  'FES376',
#  'HkV652',
#  'Iwu647',
#  'STK567',
#  'TRn222',
#  'UXR369',
#  'afj497',
#  'dja779',
#  'hro568',
#  'jyn629',
#  'nch777',
#  'nld052',
#  'oYM964',
#  'pbn620',
#  'pwu404',
#  'shl347',
#  'sst663',
#  'ucz335',
#  'uzq030',
#  'wbq437',
#  'xbt154',
#  'xnk712']

# %% [markdown]
# ### 3. Retrieve content for a specific channel

# %% [markdown]
# All of the above are examples to get an intuition how to query the API.
#
# Getting the *first* alias.

# %%
alias = channels.get('channelInformation')[0].get('alias')
alias
# Out:
# 'CLE548'

# %% [markdown]
# Get all items in a specific channel ('CLE548' in this case) for the last 24 hours.

# %%
url = 'http://rmb.reuters.com/rmd/rest/json/items?channel=' + alias + '&token=' + authToken + '&format=json'

# %%
response = requests.get(url)

# %% [markdown]
# Retrieve text-based content for a specific channel category (group of channels containing similar content) using the **channelCategory** argument.

# %%
channelCat = 'TXT'  # or: OLR, GRA, PIC, ...
url = 'http://rmb.reuters.com/rmd/rest/json/items?channelCategory=' + channelCat + '&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'pending': False,
#  'pollToken': 'ExwaY31kfnt3ZGNxcGd3YH1hYHhneg==',
#  'results': [{'channelIds': [542,
#     626,
#     159003,
#     176417,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     49349,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     68936,
#     635,
#     22370,
#     159015,
#     118201,
#     23278,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:27:55Z',
#    'geography': ['ZA', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I0AL',
#    'headline': "Rugby-Erasmus' South Africa game plan gets thumbs up from ex-Boks",
#    'id': 'tag:reuters.com,2019:newsml_L8N27I0AL:76873634',
#    'internalReceivedDate': '2019-11-02T13:27:58Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 76873634},
#   {'channelIds': [587,
#     70659,
#     70660,
#     611,
#     585,
#     63412,
#     586,
#     159005,
#     158993,
#     158997,
#     656,
#     68948,
#     63457,
#     118201,
#     63414,
#     63386,
#     68929,
#     63413,
#     158995,
#     68934],
#    'channels': ['HkV652', 'jyn629'],
#    'dateCreated': '2019-11-02T13:27:14Z',
#    'geography': ['CN'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I0A3',
#    'headline': 'FOKUS 1-Wieder Ausschreitungen bei Proteste in Hongkong',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I0A3:1534572626',
#    'internalReceivedDate': '2019-11-02T13:27:16Z',
#    'language': 'de',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'HONGKONG/PROTESTE (FOKUS 1)',
#    'source': 'Thomson Reuters',
#    'version': 1534572626},
#   {'channelIds': [626,
#     662,
#     176417,
#     63697,
#     647,
#     154257,
#     49349,
#     599,
#     63685,
#     644,
#     63665,
#     63708,
#     22370,
#     118201,
#     23278,
#     27574],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:26:16Z',
#    'geography': ['RU',
#     'UY',
#     'FJ',
#     'JP',
#     'ZA',
#     'IT',
#     'NZ',
#     'FR',
#     'AR',
#     'NA',
#     'AU',
#     'GB',
#     'TO',
#     'WS',
#     'IE',
#     'GE',
#     'CA',
#     'US'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I02Q',
#    'headline': 'FACTBOX-Rugby-World Cup finals results',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I02Q:1920991163',
#    'internalReceivedDate': '2019-11-02T13:26:24Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (FACTBOX)',
#    'source': 'Thomson Reuters',
#    'version': 1920991163},
#   {'author': 'By Greg Stutchbury',
#    'channelIds': [626,
#     159003,
#     662,
#     176417,
#     63697,
#     647,
#     154257,
#     49349,
#     63667,
#     599,
#     63685,
#     644,
#     182977,
#     63665,
#     158991,
#     63708,
#     68936,
#     635,
#     22370,
#     159015,
#     118201,
#     23278,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:23:21Z',
#    'geography': ['RU',
#     'UY',
#     'FJ',
#     'JP',
#     'ZA',
#     'IT',
#     'NZ',
#     'FR',
#     'AR',
#     'NA',
#     'AU',
#     'GB',
#     'TO',
#     'WS',
#     'IE',
#     'GE',
#     'CA',
#     'US'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I01J',
#    'headline': 'Rugby-I almost quit a year ago, says Springbok coach Erasmus',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I01J:1950391674',
#    'internalReceivedDate': '2019-11-02T13:23:29Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 1950391674},
#   {'author': 'By Jack Tarrant',
#    'channelIds': [542,
#     37917,
#     626,
#     159003,
#     662,
#     176417,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     49349,
#     63684,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     20483,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     159015,
#     41078,
#     118201,
#     23278,
#     176419,
#     634,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:16:53Z',
#    'geography': ['JP', 'ZA', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I03C',
#    'headline': 'Rugby-Crushing final defeat may motivate for years to come - England’s Itoje',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I03C:675093036',
#    'internalReceivedDate': '2019-11-02T13:16:57Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 675093036},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:14:12Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CFFO1W',
#    'headline': 'Kontinental Hockey League Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CFFO1W:1',
#    'internalReceivedDate': '2019-11-02T13:14:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ICEHOCKEY-KHL/RESULTS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [37917,
#     626,
#     68932,
#     159003,
#     176417,
#     23754,
#     49349,
#     63667,
#     63685,
#     644,
#     158991,
#     142441,
#     672,
#     635,
#     159015,
#     118201,
#     63643,
#     27081,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:09:43Z',
#    'geography': ['UA', 'CH', 'CN'],
#    'guid': 'tag:reuters.com,2019:newsml_L5N27I000',
#    'headline': 'Tennis-Svitolina reaches WTA Finals showpiece as Bencic retires',
#    'id': 'tag:reuters.com,2019:newsml_L5N27I000:1319706128',
#    'internalReceivedDate': '2019-11-02T13:09:46Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'TENNIS-WTAFINALS/ (PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1319706128},
#   {'channelIds': [63683,
#     542,
#     37917,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     63697,
#     154815,
#     647,
#     70666,
#     75332,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     20483,
#     142441,
#     68936,
#     635,
#     22370,
#     23742,
#     22285,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     127689,
#     176419,
#     634,
#     27574,
#     564,
#     127687,
#     63655,
#     70595],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:08:53Z',
#    'geography': ['AR', 'GB', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I09Z',
#    'headline': "RPT-Soweto celebrates South Africa's first Rugby World Cup win under black captain",
#    'id': 'tag:reuters.com,2019:newsml_L8N27I09Z:1458536883',
#    'internalReceivedDate': '2019-11-02T13:08:57Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/SOWETO (TV, REPEAT)',
#    'source': 'Thomson Reuters',
#    'version': 1458536883},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T13:00:00Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I04B',
#    'headline': 'Reuters World News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I04B:244027211',
#    'internalReceivedDate': '2019-11-02T13:00:02Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-WORLD',
#    'source': 'Thomson Reuters',
#    'version': 244027211},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:59Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I049',
#    'headline': 'Reuters Entertainment News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I049:279945655',
#    'internalReceivedDate': '2019-11-02T13:00:01Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-LEISURE',
#    'source': 'Thomson Reuters',
#    'version': 279945655},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:58Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I047',
#    'headline': 'Reuters Health News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I047:341917297',
#    'internalReceivedDate': '2019-11-02T13:00:01Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-HEALTH',
#    'source': 'Thomson Reuters',
#    'version': 341917297},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:57Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I043',
#    'headline': 'Reuters People News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I043:773443975',
#    'internalReceivedDate': '2019-11-02T12:59:58Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-PEOPLE',
#    'source': 'Thomson Reuters',
#    'version': 773443975},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:57Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I045',
#    'headline': 'Reuters Odd News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I045:1064540968',
#    'internalReceivedDate': '2019-11-02T12:59:58Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-ODD',
#    'source': 'Thomson Reuters',
#    'version': 1064540968},
#   {'channelIds': [37917,
#     176417,
#     159011,
#     63446,
#     644,
#     211865,
#     142441,
#     159015,
#     41078,
#     118201,
#     2213],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:56Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I041',
#    'headline': 'Reuters Science News Summary',
#    'id': 'tag:reuters.com,2019:newsml_L2N27I041:862381027',
#    'internalReceivedDate': '2019-11-02T12:59:57Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BC-SCIENCE',
#    'source': 'Thomson Reuters',
#    'version': 862381027},
#   {'author': 'By Jonathan Stempel and Shubham Kalia',
#    'channelIds': [159021,
#     28253,
#     63683,
#     37917,
#     32590,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     63693,
#     44243,
#     121245,
#     57606,
#     154815,
#     180027,
#     159019,
#     63675,
#     159011,
#     574,
#     583,
#     77679,
#     63667,
#     66918,
#     539,
#     63672,
#     23369,
#     549,
#     48620,
#     63685,
#     644,
#     182977,
#     46843,
#     76630,
#     540,
#     27214,
#     170643,
#     27199,
#     44352,
#     158991,
#     20483,
#     142441,
#     635,
#     159015,
#     176425,
#     42799,
#     23371,
#     180023,
#     41078,
#     661,
#     565,
#     24744,
#     118201,
#     139745,
#     2213,
#     170645,
#     32589,
#     176419,
#     634,
#     26784,
#     620,
#     564,
#     63655,
#     70595,
#     58686],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:59:40Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I03I',
#    'headline': "UPDATE 2-Buffett's Berkshire tops profit forecasts despite trade tensions",
#    'id': 'tag:reuters.com,2019:newsml_L2N27I03I:513350279',
#    'internalReceivedDate': '2019-11-02T12:59:43Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'BERKSHIRE-RESULTS/ (UPDATE 2, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 513350279},
#   {'author': 'By Amlan Chakraborty',
#    'channelIds': [37917,
#     626,
#     159003,
#     176417,
#     22368,
#     23754,
#     49349,
#     63667,
#     63685,
#     644,
#     158991,
#     142441,
#     635,
#     159015,
#     118201,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:55:12Z',
#    'geography': ['IN', 'BD'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I04Z',
#    'headline': 'Cricket-Bangladesh will welcome back Shakib despite mistake - Mahmudullah',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I04Z:1615457268',
#    'internalReceivedDate': '2019-11-02T12:55:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'CRICKET-T20-IND-BGD/',
#    'source': 'Thomson Reuters',
#    'version': 1615457268},
#   {'author': 'By Mitch Phillips',
#    'channelIds': [626,
#     159003,
#     662,
#     176417,
#     63697,
#     647,
#     49349,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     63708,
#     68936,
#     635,
#     22370,
#     159015,
#     118201,
#     23278,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:52:49Z',
#    'geography': ['GB', 'NZ', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I08H',
#    'headline': 'Rugby-Sometimes bad days just happen, says bemused England coach Jones',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I08H:612462795',
#    'internalReceivedDate': '2019-11-02T12:52:53Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 612462795},
#   {'author': 'By Stephen Addison and Alistair Smout',
#    'channelIds': [76637,
#     63683,
#     23925,
#     23294,
#     68928,
#     37917,
#     26786,
#     144993,
#     626,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     546,
#     34325,
#     131355,
#     63693,
#     208945,
#     121245,
#     161681,
#     57606,
#     32591,
#     154815,
#     23929,
#     63635,
#     27253,
#     23309,
#     180027,
#     159019,
#     22170,
#     63675,
#     153329,
#     211145,
#     22791,
#     75332,
#     26783,
#     159011,
#     583,
#     77679,
#     63667,
#     539,
#     164607,
#     63672,
#     23369,
#     167293,
#     150029,
#     549,
#     157307,
#     22802,
#     204119,
#     76633,
#     63648,
#     63685,
#     644,
#     159025,
#     621,
#     182977,
#     76630,
#     540,
#     63646,
#     72569,
#     159017,
#     27216,
#     27199,
#     44352,
#     211865,
#     158991,
#     142441,
#     63708,
#     566,
#     195519,
#     610,
#     635,
#     22283,
#     27213,
#     154381,
#     159015,
#     23927,
#     176425,
#     42799,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     23926,
#     661,
#     565,
#     601,
#     118201,
#     162059,
#     63669,
#     22307,
#     159065,
#     2213,
#     127689,
#     170645,
#     26791,
#     23306,
#     32589,
#     176419,
#     634,
#     34327,
#     23279,
#     93099,
#     191903,
#     564,
#     127687,
#     22807,
#     180031,
#     63655,
#     70595,
#     63709],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:35:29Z',
#    'geography': ['AU', 'CA', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I002',
#    'headline': 'UPDATE 3-In seismic shift, Britain orders immediate moratorium on fracking',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I002:1715043185',
#    'internalReceivedDate': '2019-11-02T12:35:34Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'BRITAIN-FRACKING/ (UPDATE 3, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 1715043185},
#   {'author': 'By Ossian Shine',
#    'channelIds': [542,
#     37917,
#     626,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     182977,
#     63665,
#     158991,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     23742,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     27574,
#     564,
#     63655],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:30:47Z',
#    'geography': ['JP', 'ZA', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I04C',
#    'headline': 'WRAPUP 1-Rugby-Rainbow nation turns gold as Springboks lift World Cup',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I04C:1131120046',
#    'internalReceivedDate': '2019-11-02T12:30:51Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (WRAPUP 1, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1131120046},
#   {'channelIds': [76637,
#     37917,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22331,
#     22321,
#     34325,
#     22329,
#     63693,
#     121245,
#     57606,
#     154815,
#     23929,
#     96151,
#     180027,
#     159019,
#     63675,
#     153329,
#     211145,
#     22791,
#     75332,
#     154257,
#     159011,
#     583,
#     77679,
#     63667,
#     66918,
#     539,
#     63672,
#     23369,
#     44508,
#     27212,
#     549,
#     66931,
#     204119,
#     63685,
#     644,
#     159025,
#     182977,
#     76630,
#     540,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     195519,
#     610,
#     635,
#     62870,
#     22283,
#     159015,
#     176425,
#     42799,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     26781,
#     22294,
#     601,
#     118201,
#     63669,
#     2213,
#     127689,
#     170645,
#     23306,
#     32589,
#     620,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:27:57Z',
#    'geography': ['FR', 'IT'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I0A4',
#    'headline': 'Fiat Chrysler and Peugeot expected to sign binding merger deal as soon as early-Dec -source',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I0A4:491907446',
#    'internalReceivedDate': '2019-11-02T12:28:00Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'FIAT CHRYSLER-M&A/PSA-TIMING',
#    'source': 'Thomson Reuters',
#    'version': 491907446},
#   {'channelIds': [63683,
#     542,
#     37917,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     63697,
#     154815,
#     647,
#     70666,
#     75332,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     20483,
#     142441,
#     68936,
#     635,
#     22370,
#     23742,
#     22285,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     127689,
#     176419,
#     634,
#     27574,
#     564,
#     127687,
#     63655,
#     70595],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:24:29Z',
#    'geography': ['AR', 'GB', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I09Z',
#    'headline': "Soweto celebrates South Africa's first Rugby World Cup win under black captain",
#    'id': 'tag:reuters.com,2019:newsml_L8N27I09Z:392678845',
#    'internalReceivedDate': '2019-11-02T12:24:34Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-SAFRICA/ (TV)',
#    'source': 'Thomson Reuters',
#    'version': 392678845},
#   {'channelIds': [587,
#     70659,
#     70660,
#     63658,
#     611,
#     585,
#     63703,
#     586,
#     158991,
#     159005,
#     158993,
#     158997,
#     656,
#     68948,
#     63656,
#     63637,
#     118201,
#     63657,
#     68929,
#     564,
#     158995,
#     68934],
#    'channels': ['HkV652', 'jyn629'],
#    'dateCreated': '2019-11-02T12:16:30Z',
#    'geography': ['SY', 'TR'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I0A1',
#    'headline': 'Türkei will IS-Häftlinge in Heimatländer zurückschicken',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I0A1:1709050818',
#    'internalReceivedDate': '2019-11-02T12:16:33Z',
#    'language': 'de',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'TÜRKEI/EUROPA/IS',
#    'source': 'Thomson Reuters',
#    'version': 1709050818},
#   {'channelIds': [159021,
#     28253,
#     63683,
#     37917,
#     32590,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     63693,
#     44243,
#     121245,
#     57606,
#     154815,
#     180027,
#     159019,
#     63675,
#     159011,
#     574,
#     583,
#     77679,
#     63667,
#     66918,
#     539,
#     63672,
#     23369,
#     549,
#     48620,
#     63685,
#     644,
#     182977,
#     46843,
#     76630,
#     540,
#     27214,
#     170643,
#     27199,
#     44352,
#     158991,
#     20483,
#     142441,
#     635,
#     159015,
#     176425,
#     42799,
#     23371,
#     180023,
#     41078,
#     661,
#     565,
#     24744,
#     118201,
#     139745,
#     2213,
#     170645,
#     32589,
#     176419,
#     634,
#     26784,
#     620,
#     564,
#     63655,
#     70595,
#     58686],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:09:11Z',
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I03I',
#    'headline': "UPDATE 1-Buffett's Berkshire boosts operating profit as economy improves",
#    'id': 'tag:reuters.com,2019:newsml_L2N27I03I:2065153708',
#    'internalReceivedDate': '2019-11-02T12:09:13Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'BERKSHIRE-RESULTS/ (UPDATE 1, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 2065153708},
#   {'author': 'By Clare Jim and Donny Kwok',
#    'channelIds': [76637,
#     63683,
#     37917,
#     144993,
#     626,
#     68932,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     57606,
#     154815,
#     180027,
#     23325,
#     63675,
#     75332,
#     159011,
#     583,
#     63667,
#     539,
#     63672,
#     150029,
#     549,
#     76633,
#     63685,
#     644,
#     621,
#     540,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     672,
#     610,
#     635,
#     62870,
#     22283,
#     159015,
#     176425,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     23926,
#     661,
#     565,
#     601,
#     118201,
#     63669,
#     2213,
#     63643,
#     127689,
#     176419,
#     634,
#     31377,
#     31378,
#     620,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T12:03:36Z',
#    'geography': ['GB', 'CN'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I02N',
#    'headline': 'UPDATE 5-Downtown Hong Kong becomes battleground as night falls',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I02N:1568647732',
#    'internalReceivedDate': '2019-11-02T12:03:40Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'HONGKONG-PROTESTS/ (UPDATE 5, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1568647732},
#   {'author': 'By Nick Mulvenney',
#    'channelIds': [542,
#     37917,
#     626,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     182977,
#     63665,
#     158991,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     23742,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     27574,
#     564,
#     63655],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:58:26Z',
#    'geography': ['AR', 'GB', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27H138',
#    'headline': 'UPDATE 3-Rugby-Powerpacked South Africa dominate ragged England to win third World Cup',
#    'id': 'tag:reuters.com,2019:newsml_L3N27H138:1947111597',
#    'internalReceivedDate': '2019-11-02T11:58:30Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (UPDATE 3, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1947111597},
#   {'channelIds': [626,
#     159003,
#     662,
#     176417,
#     22368,
#     49349,
#     63667,
#     63685,
#     644,
#     158991,
#     63708,
#     635,
#     159015,
#     118201,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:51:12Z',
#    'geography': ['NZ', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I04X',
#    'headline': "Cricket-England's Denly out of New Zealand T20 series with ankle injury",
#    'id': 'tag:reuters.com,2019:newsml_L3N27I04X:1693994105',
#    'internalReceivedDate': '2019-11-02T11:51:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'CRICKET-T20-NZL-ENG/ (PIX)',
#    'source': 'Thomson Reuters',
#    'version': 1693994105},
#   {'author': 'By Greg Stutchbury',
#    'channelIds': [37917,
#     626,
#     159003,
#     662,
#     176417,
#     63697,
#     647,
#     49349,
#     63684,
#     63667,
#     599,
#     63685,
#     644,
#     182977,
#     63665,
#     158991,
#     20483,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     159015,
#     41078,
#     118201,
#     23278,
#     176419,
#     634,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:50:32Z',
#    'geography': ['RU', 'GB', 'NZ', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I03M',
#    'headline': 'Rugby-Representing entire Rainbow Nation inspired us, says Springbok Vermeulen',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I03M:811650394',
#    'internalReceivedDate': '2019-11-02T11:50:37Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 811650394},
#   {'channelIds': [37917,
#     626,
#     159003,
#     176417,
#     651,
#     49349,
#     63684,
#     63667,
#     63685,
#     63698,
#     644,
#     158991,
#     142441,
#     635,
#     159015,
#     41078,
#     27078,
#     118201,
#     23536,
#     176419,
#     634,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:49:52Z',
#    'geography': ['MY', 'ID'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I04K',
#    'headline': "Motorcycling-Indonesia's Munandar dies after crash at Sepang",
#    'id': 'tag:reuters.com,2019:newsml_L3N27I04K:1840238237',
#    'internalReceivedDate': '2019-11-02T11:49:54Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'MOTORCYCLING-MALAYSIA/',
#    'source': 'Thomson Reuters',
#    'version': 1840238237},
#   {'channelIds': [28253,
#     37917,
#     26782,
#     626,
#     159003,
#     176417,
#     63692,
#     34325,
#     63693,
#     44243,
#     57606,
#     154815,
#     180027,
#     159019,
#     63675,
#     153329,
#     159011,
#     574,
#     583,
#     77679,
#     63667,
#     66918,
#     539,
#     63672,
#     23369,
#     549,
#     63685,
#     644,
#     182977,
#     76630,
#     540,
#     63646,
#     27214,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     610,
#     635,
#     62870,
#     159015,
#     176425,
#     42799,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     24744,
#     601,
#     118201,
#     139745,
#     63669,
#     2213,
#     170645,
#     32589,
#     26784,
#     620,
#     34327,
#     564,
#     180031,
#     63655,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:46:26Z',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_L2N27I03D',
#    'headline': "Buffett's Berkshire reports higher quarterly operating profit",
#    'id': 'tag:reuters.com,2019:newsml_L2N27I03D:1557146663',
#    'internalReceivedDate': '2019-11-02T11:46:29Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'BERKSHIRE-RESULTS/',
#    'source': 'Thomson Reuters',
#    'version': 1557146663},
#   {'author': 'By Nick Mulvenney',
#    'channelIds': [542,
#     37917,
#     626,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     23742,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     27574,
#     564,
#     63655],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:32:58Z',
#    'geography': ['AR', 'GB', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27H138',
#    'headline': 'UPDATE 2-Rugby-Powerpacked South Africa dominate ragged England to win third World Cup',
#    'id': 'tag:reuters.com,2019:newsml_L3N27H138:1242948066',
#    'internalReceivedDate': '2019-11-02T11:33:02Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (UPDATE 2, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1242948066},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:31:29Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CAOHWY',
#    'headline': 'J-League Top Scorers',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CAOHWY:1',
#    'internalReceivedDate': '2019-11-02T11:31:33Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-JAPAN/TOP SCORERS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [542,
#     37917,
#     26786,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     154815,
#     70666,
#     75332,
#     29598,
#     46622,
#     63633,
#     159011,
#     583,
#     63667,
#     164607,
#     150029,
#     63685,
#     644,
#     182977,
#     27216,
#     211865,
#     158991,
#     142441,
#     195519,
#     635,
#     22283,
#     23742,
#     22285,
#     159015,
#     141803,
#     23927,
#     41078,
#     23926,
#     118201,
#     2213,
#     191903,
#     564,
#     63655,
#     70595],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:27:45Z',
#    'geography': ['CD', 'BI'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I070',
#    'headline': 'Attackers kill three in heavily guarded district of Bujumbura',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I070:1373033064',
#    'internalReceivedDate': '2019-11-02T11:27:48Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'BURUNDI-VIOLENCE/',
#    'source': 'Thomson Reuters',
#    'version': 1373033064},
#   {'channelIds': [68928,
#     626,
#     159003,
#     176417,
#     546,
#     63635,
#     49349,
#     63667,
#     560,
#     63685,
#     644,
#     158991,
#     635,
#     159015,
#     118201,
#     27081,
#     564,
#     63644],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:22:49Z',
#    'geography': ['AU', 'RO', 'CZ'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I048',
#    'headline': 'Tennis-Halep defends coach Cahill after courtside dressing down',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I048:1856330725',
#    'internalReceivedDate': '2019-11-02T11:22:53Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'TENNIS-WTAFINALS/ (PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1856330725},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:22:25Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA9DWU',
#    'headline': 'J-League Standings',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA9DWU:1',
#    'internalReceivedDate': '2019-11-02T11:22:28Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-JAPAN/STANDINGS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:17Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWS',
#    'headline': 'J-League Summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWS:1',
#    'internalReceivedDate': '2019-11-02T11:21:24Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-JAPAN/SUMMARIES',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:17Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWR',
#    'headline': 'A-League Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWR:1',
#    'internalReceivedDate': '2019-11-02T11:21:22Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-AUSTRALIA/RESULTS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:17Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWQ',
#    'headline': 'A-League Summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWQ:1',
#    'internalReceivedDate': '2019-11-02T11:21:23Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-AUSTRALIA/SUMMARIES',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 23535, 49349, 644, 148391, 635, 22370, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:17Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWT',
#    'headline': 'World Cup summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWT:1',
#    'internalReceivedDate': '2019-11-02T11:21:21Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'RUGBY-UNION-WORLDCUP/SUMMARIES',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 22370, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:17Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWP',
#    'headline': 'World Cup results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWP:1',
#    'internalReceivedDate': '2019-11-02T11:21:22Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'RUGBY-UNION-WORLDCUP/RESULTS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:21:16Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWM',
#    'headline': 'J-League Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2CA7HWM:1',
#    'internalReceivedDate': '2019-11-02T11:21:21Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-JAPAN/RESULTS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'author': 'By Clare Jim and Donny Kwok',
#    'channelIds': [76637,
#     63683,
#     37917,
#     144993,
#     626,
#     68932,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     57606,
#     154815,
#     180027,
#     23325,
#     63675,
#     75332,
#     159011,
#     583,
#     63667,
#     539,
#     63672,
#     150029,
#     549,
#     76633,
#     63685,
#     644,
#     621,
#     540,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     672,
#     610,
#     635,
#     62870,
#     22283,
#     159015,
#     176425,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     23926,
#     661,
#     565,
#     601,
#     118201,
#     63669,
#     2213,
#     63643,
#     127689,
#     176419,
#     634,
#     31377,
#     31378,
#     620,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:12:16Z',
#    'geography': ['GB', 'CN'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I02N',
#    'headline': 'UPDATE 4-Downtown Hong Kong becomes battleground as night falls',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I02N:429600139',
#    'internalReceivedDate': '2019-11-02T11:12:19Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'HONGKONG-PROTESTS/ (UPDATE 4, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 429600139},
#   {'channelIds': [626, 22368, 49349, 644, 148391, 635, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:10:57Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2C9Q9WL',
#    'headline': 'Australian Sheffield Shield Scoreboard',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2C9Q9WL:1',
#    'internalReceivedDate': '2019-11-02T11:11:03Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'CRICKET-AUSTRALIA/SCOREBOARD',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'author': 'By Nick Mulvenney',
#    'channelIds': [542,
#     37917,
#     626,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     63697,
#     647,
#     70666,
#     29598,
#     63633,
#     159011,
#     49349,
#     583,
#     63667,
#     599,
#     63685,
#     644,
#     182977,
#     63665,
#     158991,
#     142441,
#     63708,
#     68936,
#     635,
#     22370,
#     23742,
#     159015,
#     41078,
#     118201,
#     23278,
#     2213,
#     27574,
#     564,
#     63655],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:07:17Z',
#    'geography': ['JP', 'ZA', 'GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27H138',
#    'headline': 'UPDATE 1-Rugby-South Africa dominate ragged England to win third World Cup',
#    'id': 'tag:reuters.com,2019:newsml_L3N27H138:1260844227',
#    'internalReceivedDate': '2019-11-02T11:07:20Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (UPDATE 1, PIX, TV)',
#    'source': 'Thomson Reuters',
#    'version': 1260844227},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T11:00:16Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB2C98GWJ',
#    'headline': 'A-League Standings',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB2C98GWJ:1',
#    'internalReceivedDate': '2019-11-02T11:00:21Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-AUSTRALIA/STANDINGS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:59:12Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQM',
#    'headline': 'UPDATE 2-A-League Summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQM:2',
#    'internalReceivedDate': '2019-11-02T10:59:16Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-AUSTRALIA/SUMMARIES (UPDATE 2)',
#    'source': 'Opta Sports Data',
#    'version': 2},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:59:12Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQN',
#    'headline': 'UPDATE 2-China Super League Summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQN:2',
#    'internalReceivedDate': '2019-11-02T10:59:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-CHINA/SUMMARIES (UPDATE 2)',
#    'source': 'Opta Sports Data',
#    'version': 2},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:59:11Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJIQQ',
#    'headline': 'UPDATE 2-A-League Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJIQQ:2',
#    'internalReceivedDate': '2019-11-02T10:59:16Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-AUSTRALIA/RESULTS (UPDATE 2)',
#    'source': 'Opta Sports Data',
#    'version': 2},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:59:11Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQO',
#    'headline': 'UPDATE 2-China Super League Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1AFJHQO:2',
#    'internalReceivedDate': '2019-11-02T10:59:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-CHINA/RESULTS (UPDATE 2)',
#    'source': 'Opta Sports Data',
#    'version': 2},
#   {'author': 'By Mitch Phillips',
#    'channelIds': [626,
#     159003,
#     662,
#     176417,
#     63697,
#     647,
#     49349,
#     63667,
#     599,
#     63685,
#     644,
#     63665,
#     158991,
#     63708,
#     68936,
#     635,
#     22370,
#     159015,
#     118201,
#     23278,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:55:56Z',
#    'geography': ['GB', 'NZ', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_L3N27I03H',
#    'headline': 'Rugby-Mapimpi, Kolbe and Pollard win World Cup for South Africa',
#    'id': 'tag:reuters.com,2019:newsml_L3N27I03H:1532700322',
#    'internalReceivedDate': '2019-11-02T10:56:00Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 1532700322},
#   {'channelIds': [626, 22368, 49349, 644, 148391, 635, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:55:08Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1AF24QH',
#    'headline': 'UPDATE 2-England in New Zealand 2019 Scoreboard',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1AF24QH:2',
#    'internalReceivedDate': '2019-11-02T10:55:13Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'CRICKET-T20/SCOREBOARD (UPDATE 2)',
#    'source': 'Opta Sports Data',
#    'version': 2},
#   {'channelIds': [626,
#     176417,
#     63411,
#     63438,
#     49349,
#     583,
#     599,
#     644,
#     22370,
#     63421,
#     118201,
#     27574],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:54:31Z',
#    'geography': ['GB', 'AU', 'NZ', 'JP', 'ZA'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTL3N27I03H1',
#    'headline': 'SOUTH AFRICA BEAT ENGLAND 32-12 TO WIN RUGBY WORLD CUP FINAL',
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTL3N27I03H1:371938083',
#    'internalReceivedDate': '2019-11-02T10:54:34Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': 'SOUTH AFRICA BEAT ENGLAND 32-12 TO WIN RUGBY WORLD CUP FINAL',
#    'source': 'Thomson Reuters',
#    'version': 371938083},
#   {'channelIds': [63674,
#     76637,
#     63683,
#     37917,
#     619,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     623,
#     57606,
#     154815,
#     31407,
#     63660,
#     180027,
#     63675,
#     75332,
#     605,
#     159011,
#     583,
#     63667,
#     539,
#     150029,
#     76633,
#     63685,
#     644,
#     621,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     20483,
#     142441,
#     610,
#     635,
#     62870,
#     589,
#     22283,
#     159015,
#     567,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     23926,
#     661,
#     565,
#     31410,
#     601,
#     118201,
#     63669,
#     22307,
#     2213,
#     127689,
#     30482,
#     63676,
#     176419,
#     634,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:46:04Z',
#    'geography': ['IQ', 'IR', 'RU', 'SY', 'TR', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_N9N21Y02O',
#    'headline': 'Turkey says will send Islamic State prisoners to home countries',
#    'id': 'tag:reuters.com,2019:newsml_N9N21Y02O:449911940',
#    'internalReceivedDate': '2019-11-02T10:46:10Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'SYRIA-SECURITY/TURKEY-ISLAMIC STATE (URGENT)',
#    'source': 'Thomson Reuters',
#    'version': 449911940},
#   {'channelIds': [159021,
#     76637,
#     37917,
#     32590,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     57606,
#     154815,
#     63660,
#     180027,
#     63675,
#     75332,
#     159011,
#     583,
#     77679,
#     63667,
#     164607,
#     150029,
#     48620,
#     76633,
#     63685,
#     644,
#     159025,
#     46843,
#     76630,
#     63646,
#     27214,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     610,
#     635,
#     62870,
#     589,
#     22283,
#     159027,
#     159015,
#     42799,
#     180025,
#     180033,
#     23371,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     601,
#     118201,
#     139745,
#     63669,
#     2213,
#     23359,
#     127689,
#     23306,
#     26784,
#     34327,
#     23279,
#     564,
#     127687,
#     152757,
#     180031,
#     63655,
#     70595,
#     588,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:40:57Z',
#    'geography': ['LB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I07U',
#    'headline': 'UPDATE 1-Lebanon\'s banks see no "extraordinary movement" of money on reopening',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I07U:1946244666',
#    'internalReceivedDate': '2019-11-02T10:41:00Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'LEBANON-PROTESTS/BANKS (UPDATE 1)',
#    'source': 'Thomson Reuters',
#    'version': 1946244666},
#   {'channelIds': [587,
#     70659,
#     70660,
#     63658,
#     611,
#     585,
#     63703,
#     586,
#     158991,
#     159005,
#     158993,
#     158997,
#     656,
#     68948,
#     63656,
#     63637,
#     118201,
#     63657,
#     68929,
#     564,
#     158995,
#     68934],
#    'channels': ['HkV652', 'jyn629'],
#    'dateCreated': '2019-11-02T10:38:27Z',
#    'geography': ['AF'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I083',
#    'headline': 'POLITIK-BLICK-Neun Schulkinder bei Minen-Explosion in Afghanistan getötet',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I083:2099447966',
#    'internalReceivedDate': '2019-11-02T10:38:29Z',
#    'language': 'de',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'POLITIK/BLICK',
#    'source': 'Thomson Reuters',
#    'version': 2099447966},
#   {'channelIds': [76637,
#     173671,
#     63683,
#     23925,
#     37917,
#     22390,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     63693,
#     208945,
#     57606,
#     154815,
#     23929,
#     27253,
#     63660,
#     22170,
#     75332,
#     159011,
#     583,
#     63667,
#     539,
#     150029,
#     157307,
#     76633,
#     63685,
#     644,
#     621,
#     27216,
#     211865,
#     158991,
#     20483,
#     142441,
#     610,
#     635,
#     589,
#     22283,
#     159015,
#     180033,
#     180023,
#     41078,
#     23926,
#     565,
#     31410,
#     118201,
#     2213,
#     127689,
#     26791,
#     30482,
#     176419,
#     634,
#     620,
#     34327,
#     564,
#     127687,
#     63655,
#     70595,
#     30480,
#     588,
#     63709],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:35:42Z',
#    'geography': ['IR', 'RU', 'IL', 'SY', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I07R',
#    'headline': 'Iran strikes initial deal to rebuild Syrian power grid',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I07R:214322793',
#    'internalReceivedDate': '2019-11-02T10:35:48Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'IRAN-SYRIA/ELECTRICITY',
#    'source': 'Thomson Reuters',
#    'version': 214322793},
#   {'channelIds': [37917,
#     626,
#     176417,
#     34325,
#     63398,
#     63411,
#     57606,
#     63438,
#     63424,
#     583,
#     539,
#     584,
#     63447,
#     63446,
#     644,
#     211865,
#     20483,
#     142441,
#     63428,
#     610,
#     63436,
#     603,
#     561,
#     661,
#     565,
#     63462,
#     601,
#     118201,
#     2213,
#     127689,
#     176419,
#     634,
#     63430,
#     34327,
#     62871,
#     127687,
#     142045,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:33:55Z',
#    'geography': ['IQ', 'IR', 'RU', 'SY', 'TR', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTN9N21Y02O2',
#    'headline': 'TURKISH INTERIOR MINISTER COMPLAINS ABOUT EUROPEAN INACTION ON ISLAMIC STATE PRISONERS, SAYS TURKEY WILL SEND THEM BACK TO THEIR HOME COUNTRIES',
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTN9N21Y02O2:2144533767',
#    'internalReceivedDate': '2019-11-02T10:34:00Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': 'TURKISH INTERIOR MINISTER COMPLAINS ABOUT EUROPEAN INACTION ON I',
#    'source': 'Thomson Reuters',
#    'version': 2144533767},
#   {'channelIds': [159021,
#     76637,
#     37917,
#     32590,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     57606,
#     154815,
#     63660,
#     180027,
#     63675,
#     75332,
#     159011,
#     583,
#     77679,
#     63667,
#     164607,
#     150029,
#     48620,
#     76633,
#     63685,
#     644,
#     159025,
#     46843,
#     76630,
#     63646,
#     27214,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     610,
#     635,
#     62870,
#     589,
#     22283,
#     159027,
#     159015,
#     42799,
#     180025,
#     180033,
#     23371,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     601,
#     118201,
#     139745,
#     63669,
#     2213,
#     23359,
#     127689,
#     23306,
#     26784,
#     34327,
#     23279,
#     564,
#     127687,
#     152757,
#     180031,
#     63655,
#     70595,
#     588,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-02T10:15:40Z',
#    'geography': ['LB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I07E',
#    'headline': 'Lebanon\'s banks see no "extraordinary movement" of money on reopening',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I07E:573063798',
#    'internalReceivedDate': '2019-11-02T10:15:42Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'LEBANON-PROTESTS/BANKS (URGENT)',
#    'source': 'Thomson Reuters',
#    'version': 573063798},
#   {'channelIds': [587,
#     70659,
#     70660,
#     63658,
#     611,
#     585,
#     63703,
#     586,
#     158991,
#     159005,
#     158993,
#     158997,
#     656,
#     68948,
#     63656,
#     63637,
#     118201,
#     63657,
#     68929,
#     564,
#     158995,
#     68934],
#    'channels': ['HkV652', 'jyn629'],
#    'dateCreated': '2019-11-02T10:06:26Z',
#    'geography': ['GB'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27I07H',
#    'headline': 'Blatt - Johnson will im Wahlkampf von Drohung mit No-Deal-Brexit abkehren',
#    'id': 'tag:reuters.com,2019:newsml_L8N27I07H:171382342',
#    'internalReceivedDate': '2019-11-02T10:06:27Z',
#    'language': 'de',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'BREXIT/GROSSBRITANNIEN/JOHNSON',
# ...
#    'version': 1572991727},
#   {'channelIds': [626,
#     148565,
#     49349,
#     148569,
#     82909,
#     644,
#     148567,
#     158991,
#     20483,
#     635,
#     159015,
#     118201,
#     176419,
#     634,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:37:58Z',
#    'guid': 'tag:reuters.com,2019:newsml_FLM6P3Snv',
#    'headline': 'Seahawks claim WR Gordon off waivers',
#    'id': 'tag:reuters.com,2019:newsml_FLM6P3Snv:336223827',
#    'internalReceivedDate': '2019-11-01T21:38:00Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'FOOTBALL-NFL-SEA-GORDON',
#    'source': 'Field Level Media. All Rights Reserved.',
#    'version': 336223827},
#   {'channelIds': [626,
#     148565,
#     49349,
#     148569,
#     82909,
#     644,
#     148567,
#     158991,
#     20483,
#     635,
#     159015,
#     118201,
#     176419,
#     634,
#     27574,
#     564],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:37:11Z',
#    'guid': 'tag:reuters.com,2019:newsml_FLM56PHbX',
#    'headline': 'Steelers RB Conner doubtful to face Colts',
#    'id': 'tag:reuters.com,2019:newsml_FLM56PHbX:936910284',
#    'internalReceivedDate': '2019-11-01T21:37:13Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'FOOTBALL-NFL-PIT-CONNER',
#    'source': 'Field Level Media. All Rights Reserved.',
#    'version': 936910284},
#   {'channelIds': [37917,
#     626,
#     176417,
#     34325,
#     63398,
#     63411,
#     57606,
#     63438,
#     63424,
#     605,
#     583,
#     539,
#     584,
#     63447,
#     63446,
#     644,
#     211865,
#     20483,
#     142441,
#     63428,
#     610,
#     63436,
#     603,
#     63431,
#     561,
#     661,
#     565,
#     63462,
#     601,
#     118201,
#     2213,
#     127689,
#     176419,
#     634,
#     63430,
#     34327,
#     62871,
#     127687,
#     142045,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:34:15Z',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M0673',
#    'headline': "DEMOCRAT BETO O'ROURKE SAYS HE IS DROPPING OUT OF U.S. PRESIDENTIAL RACE",
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M0673:1775499957',
#    'internalReceivedDate': '2019-11-01T21:34:17Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': "DEMOCRAT BETO O'ROURKE SAYS HE IS DROPPING OUT OF U.S. PRESIDENT",
#    'source': 'Thomson Reuters',
#    'version': 1775499957},
#   {'channelIds': [76637,
#     63683,
#     37917,
#     22390,
#     619,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     623,
#     57606,
#     154815,
#     31407,
#     180027,
#     63675,
#     75332,
#     23754,
#     605,
#     159011,
#     583,
#     63667,
#     539,
#     150029,
#     76633,
#     63685,
#     644,
#     621,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     20483,
#     142441,
#     610,
#     603,
#     635,
#     62870,
#     22283,
#     159015,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     23926,
#     661,
#     565,
#     601,
#     118201,
#     63669,
#     2213,
#     127689,
#     63673,
#     30482,
#     63676,
#     176419,
#     634,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     588,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:33:30Z',
#    'geography': ['IQ', 'RU', 'SY', 'TR', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_W1N26M01G',
#    'headline': 'Trump says ceasefire in northeastern Syria holding well',
#    'id': 'tag:reuters.com,2019:newsml_W1N26M01G:1349718857',
#    'internalReceivedDate': '2019-11-01T21:33:34Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'SYRIA-SECURITY/USA-TRUMP (URGENT)',
#    'source': 'Thomson Reuters',
#    'version': 1349718857},
#   {'channelIds': [63683,
#     70931,
#     37917,
#     144993,
#     626,
#     159003,
#     176417,
#     63692,
#     22321,
#     154815,
#     75332,
#     23754,
#     159011,
#     583,
#     63667,
#     539,
#     150029,
#     48620,
#     63685,
#     644,
#     159025,
#     621,
#     182977,
#     211865,
#     20483,
#     142441,
#     610,
#     635,
#     159015,
#     180033,
#     41078,
#     118201,
#     2213,
#     127689,
#     23306,
#     176419,
#     634,
#     34327,
#     127687,
#     152757,
#     63655,
#     70595,
#     30480,
#     63709],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:31:40Z',
#    'geography': ['AR', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_L2N27H1YA',
#    'headline': 'UPDATE 1-Argentine President-elect Fernandez holds call with Trump',
#    'id': 'tag:reuters.com,2019:newsml_L2N27H1YA:987950267',
#    'internalReceivedDate': '2019-11-01T21:31:43Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'ARGENTINA-ELECTION/TRUMP (UPDATE 1, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 987950267},
#   {'channelIds': [37917,
#     626,
#     176417,
#     34325,
#     63398,
#     63411,
#     57606,
#     63438,
#     63424,
#     583,
#     539,
#     584,
#     63447,
#     63446,
#     644,
#     211865,
#     20483,
#     142441,
#     63428,
#     610,
#     63436,
#     603,
#     561,
#     661,
#     565,
#     63462,
#     601,
#     118201,
#     2213,
#     127689,
#     176419,
#     634,
#     63430,
#     34327,
#     62871,
#     127687,
#     142045,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:31:10Z',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M0672',
#    'headline': 'DEMOCRAT BETO O’ROURKE IS DROPPING OUT OF THE U.S. PRESIDENTIAL RACE-NEW YORK TIMES',
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M0672:832114907',
#    'internalReceivedDate': '2019-11-01T21:31:11Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': 'DEMOCRAT BETO O’ROURKE IS DROPPING OUT OF THE U.S. PRESIDENTIAL',
#    'source': 'Thomson Reuters',
#    'version': 832114907},
#   {'author': 'By Valerie  Volcovici and Jessica Jones',
#    'channelIds': [76637,
#     63683,
#     37917,
#     144993,
#     626,
#     159003,
#     63692,
#     22321,
#     34325,
#     63693,
#     57606,
#     154815,
#     180027,
#     63675,
#     211145,
#     22791,
#     75332,
#     159011,
#     583,
#     63667,
#     63672,
#     150029,
#     549,
#     204119,
#     63685,
#     644,
#     182977,
#     540,
#     63646,
#     27199,
#     44352,
#     211865,
#     180029,
#     142441,
#     610,
#     635,
#     62870,
#     22283,
#     159015,
#     176425,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     601,
#     118201,
#     162059,
#     63669,
#     2213,
#     634,
#     31372,
#     34327,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:29:44Z',
#    'geography': ['CL', 'ES'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27H4OQ',
#    'headline': 'UPDATE 4-Spain to host UN climate talks in December after Chile cancels',
#    'id': 'tag:reuters.com,2019:newsml_L8N27H4OQ:1268584110',
#    'internalReceivedDate': '2019-11-01T21:29:48Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'CLIMATE-CHANGE/ACCORD (UPDATE 4)',
#    'source': 'Thomson Reuters',
#    'version': 1268584110},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 83280, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:29:16Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1B7OSX5',
#    'headline': 'Bundesliga Top Scorers',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1B7OSX5:1',
#    'internalReceivedDate': '2019-11-01T21:29:20Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-GERMANY/TOP SCORERS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'author': 'By Rania El Gamal and Saeed Azhar',
#    'channelIds': [159021,
#     23311,
#     76637,
#     63683,
#     37917,
#     32590,
#     144993,
#     626,
#     68932,
#     159003,
#     662,
#     176417,
#     63692,
#     22321,
#     34325,
#     63693,
#     208945,
#     121245,
#     57606,
#     154815,
#     23929,
#     27253,
#     23309,
#     180027,
#     159019,
#     22170,
#     63675,
#     153329,
#     75332,
#     23754,
#     26783,
#     159011,
#     583,
#     77679,
#     63667,
#     66918,
#     539,
#     22798,
#     63672,
#     23369,
#     150029,
#     549,
#     157307,
#     48620,
#     76633,
#     63685,
#     644,
#     159025,
#     621,
#     182977,
#     76630,
#     540,
#     63646,
#     27214,
#     159017,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     142441,
#     63708,
#     672,
#     610,
#     635,
#     62870,
#     159027,
#     27213,
#     159015,
#     176425,
#     42799,
#     180025,
#     180033,
#     23371,
#     180023,
#     180299,
#     561,
#     41078,
#     661,
#     565,
#     23297,
#     601,
#     118201,
#     139745,
#     63669,
#     2213,
#     23359,
#     63643,
#     127689,
#     23306,
#     32589,
#     176419,
#     634,
#     26784,
#     31377,
#     34327,
#     23279,
#     564,
#     127687,
#     22807,
#     180031,
#     63655,
#     70595,
#     30480,
#     31417,
#     588,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:27:11Z',
#    'geography': ['CN', 'SA', 'NL', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_L8N27H4V9',
#    'headline': 'UPDATE 2-Aramco meets investors in last-minute bid to hit $2 trillion IPO target - sources',
#    'id': 'tag:reuters.com,2019:newsml_L8N27H4V9:1682159290',
#    'internalReceivedDate': '2019-11-01T21:27:17Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'SAUDI ARAMCO-IPO/ (UPDATE 2, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 1682159290},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 83280, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:20:11Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1B79NWY',
#    'headline': 'Bundesliga Standings',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1B79NWY:1',
#    'internalReceivedDate': '2019-11-01T21:20:16Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-GERMANY/STANDINGS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:20:10Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1B0JZV5',
#    'headline': 'UPDATE 5-EuroLeague Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1B0JZV5:5',
#    'internalReceivedDate': '2019-11-01T21:20:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'BASKETBALL-EUROLEAGUE/RESULTS (UPDATE 5)',
#    'source': 'Opta Sports Data',
#    'version': 5},
#   {'channelIds': [173671,
#     63683,
#     37917,
#     619,
#     144993,
#     626,
#     68932,
#     159003,
#     176417,
#     63692,
#     88661,
#     22321,
#     34325,
#     63693,
#     623,
#     57606,
#     154815,
#     180027,
#     63675,
#     75332,
#     23754,
#     605,
#     159011,
#     583,
#     63667,
#     539,
#     150029,
#     599,
#     76633,
#     63685,
#     644,
#     621,
#     88663,
#     63646,
#     63665,
#     23751,
#     27199,
#     44352,
#     211865,
#     180029,
#     158991,
#     20483,
#     142441,
#     672,
#     610,
#     68936,
#     603,
#     635,
#     62870,
#     159015,
#     180025,
#     180033,
#     180023,
#     561,
#     41078,
#     661,
#     565,
#     601,
#     118201,
#     63669,
#     2213,
#     63643,
#     34283,
#     127689,
#     63673,
#     170645,
#     63676,
#     176419,
#     634,
#     31377,
#     34327,
#     564,
#     127687,
#     180031,
#     63655,
#     70595,
#     30480,
#     63709,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:19:20Z',
#    'geography': ['US', 'CN'],
#    'guid': 'tag:reuters.com,2019:newsml_W1N26M01X',
#    'headline': 'Trump says trade deal with China coming along well',
#    'id': 'tag:reuters.com,2019:newsml_W1N26M01X:1703688553',
#    'internalReceivedDate': '2019-11-01T21:19:23Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 2,
#    'slug': 'USA-TRADE/CHINA-TRUMP (URGENT)',
#    'source': 'Thomson Reuters',
#    'version': 1703688553},
#   {'channelIds': [63750,
#     37917,
#     63767,
#     32590,
#     626,
#     176417,
#     63741,
#     34325,
#     57606,
#     63779,
#     63789,
#     63773,
#     63788,
#     583,
#     63790,
#     539,
#     584,
#     599,
#     63781,
#     48620,
#     63771,
#     644,
#     211865,
#     20483,
#     142441,
#     672,
#     610,
#     603,
#     63763,
#     561,
#     661,
#     565,
#     62873,
#     601,
#     118201,
#     2213,
#     63738,
#     127689,
#     176419,
#     634,
#     34327,
#     127687,
#     142045,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:19:17Z',
#    'geography': ['US', 'CN'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTW1N27700H2',
#    'headline': 'WHITE HOUSE TRADE ADVISER NAVARRO SAYS CHINA TRADE DEAL WILL REQUIRE THREE PHASES -FOX BUSINESS NETWORK INTERVIEW',
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTW1N27700H2:482153661',
#    'internalReceivedDate': '2019-11-01T21:19:20Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': 'WHITE HOUSE TRADE ADVISER NAVARRO SAYS CHINA TRADE DEAL WILL REQ',
#    'source': 'Thomson Reuters',
#    'version': 482153661},
#   {'channelIds': [37917,
#     626,
#     176417,
#     34325,
#     63398,
#     63411,
#     57606,
#     63438,
#     63424,
#     583,
#     539,
#     584,
#     63447,
#     63446,
#     644,
#     211865,
#     20483,
#     142441,
#     63428,
#     610,
#     63436,
#     603,
#     561,
#     661,
#     565,
#     63462,
#     601,
#     118201,
#     2213,
#     127689,
#     176419,
#     634,
#     63430,
#     34327,
#     62871,
#     127687,
#     142045,
#     554],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:19:15Z',
#    'geography': ['IQ', 'RU', 'SY', 'TR', 'US'],
#    'guid': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M01G4',
#    'headline': 'TRUMP SAYS CEASEFIRE HAS HELD VERY NICELY IN SYRIA',
#    'id': 'tag:reuters.com,2019:newsml_MT1ALTW1N26M01G4:220272264',
#    'internalReceivedDate': '2019-11-01T21:19:19Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 1,
#    'slug': 'TRUMP SAYS CEASEFIRE HAS HELD VERY NICELY IN SYRIA',
#    'source': 'Thomson Reuters',
#    'version': 220272264},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 83280, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:19:12Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1B780WX',
#    'headline': 'Bundesliga Results',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1B780WX:1',
#    'internalReceivedDate': '2019-11-01T21:19:16Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-GERMANY/RESULTS',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'channelIds': [626, 49349, 644, 148391, 635, 159015, 27079, 83280, 27132],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:19:12Z',
#    'guid': 'tag:reuters.com,2019:newsml_MTZXEFB1B780WW',
#    'headline': 'Bundesliga Summaries',
#    'id': 'tag:reuters.com,2019:newsml_MTZXEFB1B780WW:1',
#    'internalReceivedDate': '2019-11-01T21:19:16Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'SOCCER-GERMANY/SUMMARIES',
#    'source': 'Opta Sports Data',
#    'version': 1},
#   {'author': 'By Michael Erman',
#    'channelIds': [76637,
#     63683,
#     37917,
#     626,
#     154817,
#     159003,
#     176417,
#     63692,
#     56876,
#     47570,
#     63693,
#     121245,
#     57606,
#     55072,
#     154815,
#     180027,
#     159019,
#     56134,
#     63675,
#     153329,
#     23754,
#     154257,
#     159011,
#     583,
#     77679,
#     63667,
#     539,
#     23369,
#     54941,
#     204119,
#     63685,
#     644,
#     55285,
#     159025,
#     26785,
#     76630,
#     170643,
#     27199,
#     44352,
#     211865,
#     55283,
#     158991,
#     20483,
#     142441,
#     635,
#     22283,
#     159015,
#     42799,
#     27215,
#     180023,
#     41078,
#     661,
#     565,
#     118201,
#     2213,
#     170645,
#     70937,
#     23306,
#     32589,
#     176419,
#     634,
#     47543,
#     49668,
#     620,
#     46844,
#     191903,
#     564,
#     63655,
#     70595,
#     47569],
#    'channels': ['STK567'],
#    'dateCreated': '2019-11-01T21:18:56Z',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_L2N27H1WQ',
#    'headline': 'UPDATE 2-FDA downplays risks from already recalled heartburn drug Zantac',
#    'id': 'tag:reuters.com,2019:newsml_L2N27H1WQ:144473425',
#    'internalReceivedDate': '2019-11-01T21:18:59Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 3,
#    'slug': 'FDA-HEARTBURN/ZANTAC (UPDATE 2, PIX)',
#    'source': 'Thomson Reuters',
#    'version': 144473425}],
#  'status': {'code': 10}}

# %% [markdown]
# Retrieve items for the last 4 hours using the **maxAge** argument.

# %%
max_age = '4h' 
url = 'http://rmb.reuters.com/rmd/rest/json/items?channel=CLE548&maxAge=' + max_age + '&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'pending': False, 'results': [], 'status': {'code': 10}}

# %% [markdown]
# Retrieve items for a given date range using the **dateRange** argument.

# %%
date_range = '2019.10.22-2019.10.28'  # YYYY.MM.DD; If no date range filter is supplied, the news items returned will be limited to the past 24 hours.
url = 'http://rmb.reuters.com/rmd/rest/json/items?channel=CLE548&dateRange=' + date_range + '&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'pending': False,
#  'pollToken': 'ExwaY31kfnt3ZWF1cGF0ZHltYH9hdg==',
#  'results': [{'author': 'Reuters, OCT 26',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-26T15:13:08Z',
#    'dimensions': '960x540',
#    'duration': 108,
#    'editNumber': '6434BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#    'id': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2',
#    'internalReceivedDate': '2019-10-26T15:13:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2QOJ1N:2/tag:reuters.com,2019:binary_LOP000LBM8PBP-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'PENTAGON-JEDI',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 26',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-26T10:31:07Z',
#    'dimensions': '960x540',
#    'duration': 108,
#    'editNumber': '6434BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#    'id': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:1',
#    'internalReceivedDate': '2019-10-26T10:33:05Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2QOJ1N:1/tag:reuters.com,2019:binary_LOP000LBM8PBP-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'PENTAGON-JEDI',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T23:49:05Z',
#    'dimensions': '960x540',
#    'duration': 111,
#    'editNumber': '5458BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP9CB',
#    'headline': 'Facebook launches tab for professional news',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP9CB:1',
#    'internalReceivedDate': '2019-10-25T23:51:30Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP9CB:1/tag:reuters.com,2019:binary_LOP000LBJR2H1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'FACEBOOK/ZUCKERBERG',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T21:40:05Z',
#    'dimensions': '960x540',
#    'duration': 114,
#    'editNumber': '5459BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LPA4R',
#    'headline': 'S&P 500 closes points from record high',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LPA4R:1',
#    'internalReceivedDate': '2019-10-25T21:43:46Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LPA4R:1/tag:reuters.com,2019:binary_LOP000LBJR2V9-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/CLOSE',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 25',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T20:04:12Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2OGVMT',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 2100GMT, FRIDAY, OCTOBER 25, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2OGVMT:1',
#    'internalReceivedDate': '2019-10-25T20:05:12Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 2100GMT, FRIDAY, OCTOBER 25, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T19:24:11Z',
#    'dimensions': '960x540',
#    'duration': 71,
#    'editNumber': '5457BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP8JV',
#    'headline': 'Week ahead on Wall Street',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP8JV:1',
#    'internalReceivedDate': '2019-10-25T19:39:48Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP8JV:1/tag:reuters.com,2019:binary_LOP000LBJR22T-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AMERS-WHATTOWATCH',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T18:48:09Z',
#    'dimensions': '960x540',
#    'duration': 284,
#    'editNumber': '5449BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP28B',
#    'headline': 'Look for stocks to struggle - Wolff',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP28B:1',
#    'internalReceivedDate': '2019-10-25T19:08:38Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP28B:1/tag:reuters.com,2019:binary_LOP000LBJQYX1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/ANALYST',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 25',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T15:56:30Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2NPP2D',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, FRIDAY, OCTOBER 25, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2NPP2D:1',
#    'internalReceivedDate': '2019-10-25T15:57:09Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, FRIDAY, OCTOBER 25, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T14:26:08Z',
#    'dimensions': '960x540',
#    'duration': 61,
#    'editNumber': '5448BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP1FV',
#    'headline': 'Verizon adds subscribers, profit rises',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP1FV:2',
#    'internalReceivedDate': '2019-10-25T14:29:08Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP1FV:2/tag:reuters.com,2019:binary_LOP000LBJQYIT-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'VERIZON-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T14:22:09Z',
#    'dimensions': '960x540',
#    'duration': 54,
#    'editNumber': '5452BO',
#    'geography': ['CN'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP4LN',
#    'headline': "Britain's ARM to continue supplying chip technology to Huawei",
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP4LN:1',
#    'internalReceivedDate': '2019-10-25T14:26:19Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP4LN:1/tag:reuters.com,2019:binary_LOP000LBJR03P-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'CHINA-USA/HUAWEI ARM',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T13:46:10Z',
#    'dimensions': '960x540',
#    'duration': 64,
#    'editNumber': '5448BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LP1FV',
#    'headline': 'Verizon adds subscribers, profit rises',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LP1FV:1',
#    'internalReceivedDate': '2019-10-25T13:54:39Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LP1FV:1/tag:reuters.com,2019:binary_LOP000LBJQYIT-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'VERIZON-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T13:16:04Z',
#    'dimensions': '960x540',
#    'duration': 62,
#    'editNumber': '5445BO',
#    'geography': ['BE'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOZ2J',
#    'headline': 'Megabrewer AB InBev drags European shares lower',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOZ2J:1',
#    'internalReceivedDate': '2019-10-25T13:20:37Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOZ2J:1/tag:reuters.com,2019:binary_LOP000LBJQXC5-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AB INBEV-RESULTS/ ',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T12:22:04Z',
#    'dimensions': '960x540',
#    'duration': 60,
#    'editNumber': '5446BO',
#    'geography': ['GB'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOZU3',
#    'headline': 'EU agrees to Brexit extension, in principle',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOZU3:2',
#    'internalReceivedDate': '2019-10-25T12:22:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOZU3:2/tag:reuters.com,2019:binary_LOP000LBJQXPX-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'BRITAIN-EU/EXTENSION',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T10:56:05Z',
#    'dimensions': '960x540',
#    'duration': 69,
#    'editNumber': '5440BO',
#    'geography': ['GB'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOV4B',
#    'headline': 'Barclays cautions on profit targets despite third-quarter trading boost',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOV4B:1',
#    'internalReceivedDate': '2019-10-25T11:00:55Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOV4B:1/tag:reuters.com,2019:binary_LOP000LBJQVD1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'BARCLAYS-RESULTS/ ',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T10:40:05Z',
#    'dimensions': '960x540',
#    'duration': 152,
#    'editNumber': '5431BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOO0B',
#    'headline': 'French labor reforms are put to the test',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOO0B:1',
#    'internalReceivedDate': '2019-10-25T10:50:43Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOO0B:1/tag:reuters.com,2019:binary_LOP000LBJQRT1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'FRANCE-REFORM/LABOR',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T09:39:05Z',
#    'dimensions': '960x540',
#    'duration': 59,
#    'editNumber': '5441BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOVWR',
#    'headline': 'Renault revenue hit by Nissan woes, diesel decline',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOVWR:1',
#    'internalReceivedDate': '2019-10-25T09:43:18Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOVWR:1/tag:reuters.com,2019:binary_LOP000LBJQVR9-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'RENAULT-RESULTS/ ',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391, 156455, 158, 63328, 166089, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T09:22:05Z',
#    'dimensions': '960x540',
#    'duration': 97,
#    'editNumber': '5439BO',
#    'geography': ['ID'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOUBV',
#    'headline': 'Indonesia report on 737 MAX crash faults Boeing design, Lion Air mistakes',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOUBV:1',
#    'internalReceivedDate': '2019-10-25T09:29:18Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOUBV:1/tag:reuters.com,2019:binary_LOP000LBJQUYT-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'INDONESIA-LION AIR CRASH/UPDATE',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: UNDERWATER FOOTAGE MUST COURTESY BASARNAS AND NO RESALE / AERIAL FOOTAGE MUST COURTESY INDONESIAN AIR FORCE AND NO RESALE Digital: UNDERWATER FOOTAGE MUST COURTESY BASARNAS AND NO RESALE / AERIAL FOOTAGE MUST COURTESY INDONESIAN AIR FORCE AND NO RESALE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [157, 172391, 156455, 158, 63328, 212951, 166089, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T08:28:05Z',
#    'dimensions': '960x540',
#    'duration': 83,
#    'editNumber': '5435BO',
#    'geography': ['KR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOR57',
#    'headline': 'Samsung heir appears at court for bribery trial',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOR57:1',
#    'internalReceivedDate': '2019-10-25T08:28:40Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOR57:1/tag:reuters.com,2019:binary_LOP000LBJQTDH-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'SOUTHKOREA-CORRUPTION/SAMSUNG',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters:  NO USE SOUTH KOREA Digital: NO USE SOUTH KOREA. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 25',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T07:44:42Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2M7Q5H',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 0800GMT, FRIDAY, OCTOBER 25, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2M7Q5H:1',
#    'internalReceivedDate': '2019-10-25T07:45:15Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 0800GMT, FRIDAY, OCTOBER 25, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T07:37:06Z',
#    'dimensions': '960x540',
#    'duration': 75,
#    'editNumber': '4472BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPRPN',
#    'headline': "Amazon's gloomy holiday outlook drives down shares",
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPRPN:2',
#    'internalReceivedDate': '2019-10-25T07:37:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPRPN:2/tag:reuters.com,2019:binary_LOP000LBH9BNP-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AMAZON-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T04:56:04Z',
#    'dimensions': '960x540',
#    'duration': 81,
#    'editNumber': '5433BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOPKB',
#    'headline': 'Walmart, CVS pull J&J baby powder from shelves',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOPKB:3',
#    'internalReceivedDate': '2019-10-25T04:56:11Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOPKB:3/tag:reuters.com,2019:binary_LOP000LBJQSL1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'JOHNSON&JOHNSON-TALC',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 3},
#   {'author': 'Reuters, OCT 25',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-25T04:55:05Z',
#    'dimensions': '960x540',
#    'duration': 81,
#    'editNumber': '5433BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2LOPKB',
#    'headline': 'Walmart, CVS pull J&J baby powder from shelves',
#    'id': 'tag:reuters.com,2019:newsml_OVB2LOPKB:2',
#    'internalReceivedDate': '2019-10-25T04:55:11Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2LOPKB:2/tag:reuters.com,2019:binary_LOP000LBJQSL1-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'JOHNSON&JOHNSON-TALC',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T22:44:09Z',
#    'dimensions': '960x540',
#    'duration': 75,
#    'editNumber': '4472BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPRPN',
#    'headline': "Amazon's gloomy holiday outlook drives down shares",
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPRPN:1',
#    'internalReceivedDate': '2019-10-24T22:57:54Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPRPN:1/tag:reuters.com,2019:binary_LOP000LBH9BNP-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AMAZON-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T21:35:10Z',
#    'dimensions': '960x540',
#    'duration': 91,
#    'editNumber': '4467BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPNRF',
#    'headline': 'Strong tech results propel S&P 500, Nasdaq',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPNRF:1',
#    'internalReceivedDate': '2019-10-24T21:54:26Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPNRF:1/tag:reuters.com,2019:binary_LOP000LBH99OL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/CLOSE',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     156455,
#     158,
#     194309,
#     63328,
#     212951,
#     182549,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T20:01:04Z',
#    'dimensions': '960x540',
#    'duration': 101,
#    'editNumber': '4456BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPF4V',
#    'headline': 'As fires burn, thousands in California without power',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPF4V:3',
#    'internalReceivedDate': '2019-10-24T20:01:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPF4V:3/tag:reuters.com,2019:binary_LOP000LBH95DB-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'CALIFORNIA-WILDFIRE/PG&E',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'BROADCASTERS: NO USE. DIGITAL: KGO. NO USE AUSTRALIA BROADCASTERS. NO USE ABC, CNN, FOX, UNIVISION, TELEMUNDO, BBC AMERICA, NBC, OR THEIR DIGITAL/MOBILE PLATFORMS. No use San Francisco, California media markets. For Reuters customers only.',
#    'version': 3},
#   {'author': 'REUTERS, OCT 24',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T20:00:55Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2JGPWL',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 2100GMT, THURSDAY, OCTOBER 24, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2JGPWL:1',
#    'internalReceivedDate': '2019-10-24T20:02:10Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 2100GMT, THURSDAY, OCTOBER 24, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [157,
#     172391,
#     156455,
#     158,
#     194309,
#     63328,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T19:43:10Z',
#    'dimensions': '960x540',
#    'duration': 112,
#    'editNumber': '4459BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPHE3',
#    'headline': 'Pence backs HK protesters, slams Nike',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPHE3:1',
#    'internalReceivedDate': '2019-10-24T19:48:11Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPHE3:1/tag:reuters.com,2019:binary_LOP000LBH96HX-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-CHINA/PENCE',
#    'source': 'Thomson Reuters',
#    'usageTerms': "BROADCASTER: NO USE. DIGITAL: NO USE AUSTRALIA BROADCASTER WEBSITES. NO USE ABC AMERICA, FOX, CNN, UNIVISION, TELEMUNDO, BBC AMERICA, NBC, OR THEIR DIGITAL/MOBILE PLATFORMS. VIDEO MUST BE USED IN ITS ENTIRETY. EXISTING GRAPHICS MAY BE OVERWRITTEN BY CLIENT'S OWN GRAPHICS BUT NO FURTHER EDITS ARE PERMITTED, INCLUDING FOR LENGTH.. For Reuters customers only.",
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T19:11:10Z',
#    'dimensions': '960x540',
#    'duration': 249,
#    'editNumber': '4450BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPABV',
#    'headline': 'Alternative assets for uncertain times',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPABV:1',
#    'internalReceivedDate': '2019-10-24T19:29:59Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPABV:1/tag:reuters.com,2019:binary_LOP000LBH92YT-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/ANALYST',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [157,
#     155169,
#     210823,
#     156455,
#     158,
#     63328,
#     212951,
#     66535,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T18:29:04Z',
#    'dimensions': '960x540',
#    'duration': 70,
#    'editNumber': '4466BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPN1B',
#    'headline': 'Pence slams Nike, NBA over Hong Kong',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPN1B:3',
#    'internalReceivedDate': '2019-10-24T18:29:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPN1B:3/tag:reuters.com,2019:binary_LOP000LBH99BJ-VIEWIMAGE:512X288',
#    'priority': 2,
#    'remoteContentComplete': True,
#    'slug': 'USA-CHINA/NBA ROUGH CUT',
#    'source': 'Thomson Reuters',
#    'usageTerms': "BROADCASTER: NO USE. DIGITAL: NO USE AUSTRALIA BROADCASTER WEBSITES. NO USE ABC AMERICA, FOX, CNN, UNIVISION, TELEMUNDO, BBC AMERICA, NBC, OR THEIR DIGITAL/MOBILE PLATFORMS. VIDEO MUST BE USED IN ITS ENTIRETY. EXISTING GRAPHICS MAY BE OVERWRITTEN BY CLIENT'S OWN GRAPHICS BUT NO FURTHER EDITS ARE PERMITTED, INCLUDING FOR LENGTH.. For Reuters customers only.",
#    'version': 3},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [157,
#     155169,
#     210823,
#     156455,
#     158,
#     63328,
#     212951,
#     66535,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T18:28:04Z',
#    'dimensions': '960x540',
#    'duration': 70,
#    'editNumber': '4466BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPN1B',
#    'headline': 'Pence slams Nike, NBA over Hong Kong',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPN1B:2',
#    'internalReceivedDate': '2019-10-24T18:28:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPN1B:2/tag:reuters.com,2019:binary_LOP000LBH99BJ-VIEWIMAGE:512X288',
#    'priority': 2,
#    'remoteContentComplete': True,
#    'slug': 'USA-CHINA/NBA ROUGH CUT',
#    'source': 'Thomson Reuters',
#    'usageTerms': "BROADCASTER: NO USE. DIGITAL: NO USE AUSTRALIA BROADCASTER WEBSITES. NO USE ABC AMERICA, FOX, CNN, UNIVISION, TELEMUNDO, BBC AMERICA, NBC, OR THEIR DIGITAL/MOBILE PLATFORMS. VIDEO MUST BE USED IN ITS ENTIRETY. EXISTING GRAPHICS MAY BE OVERWRITTEN BY CLIENT'S OWN GRAPHICS BUT NO FURTHER EDITS ARE PERMITTED, INCLUDING FOR LENGTH.. For Reuters customers only.",
#    'version': 2},
#   {'author': 'REUTERS, OCT 24',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T16:26:44Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2IT7OL',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, THURSDAY, OCTOBER 24, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2IT7OL:1',
#    'internalReceivedDate': '2019-10-24T16:27:12Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, THURSDAY, OCTOBER 24, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     156455,
#     158,
#     194309,
#     63328,
#     212951,
#     182549,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T16:26:05Z',
#    'dimensions': '960x540',
#    'duration': 101,
#    'editNumber': '4456BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPF4V',
#    'headline': 'As fires burn, thousands in California without power',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPF4V:2',
#    'internalReceivedDate': '2019-10-24T16:26:11Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPF4V:2/tag:reuters.com,2019:binary_LOP000LBH95DB-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'CALIFORNIA-WILDFIRE/PG&E',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'BROADCASTERS: NO USE. DIGITAL: KGO. NO USE AUSTRALIA BROADCASTERS. NO USE ABC, CNN, FOX, UNIVISION, TELEMUNDO, BBC AMERICA, NBC, OR THEIR DIGITAL/MOBILE PLATFORMS. No use San Francisco, California media markets. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T16:01:07Z',
#    'dimensions': '960x540',
#    'duration': 92,
#    'editNumber': '4457BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPFUZ',
#    'headline': 'Office workers beware! A glimpse into an unhealthy future',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPFUZ:4',
#    'internalReceivedDate': '2019-10-24T16:03:02Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPFUZ:4/tag:reuters.com,2019:binary_LOP000LBH95QD-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'HEALTH-WORK/MODEL',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 4},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:45:08Z',
#    'dimensions': '960x540',
#    'duration': 115,
#    'editNumber': '4452BO',
#    'geography': ['DE'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPBWR',
#    'headline': 'Draghi defends legacy as ECB keeps money taps on',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPBWR:2',
#    'internalReceivedDate': '2019-10-24T15:45:13Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPBWR:2/tag:reuters.com,2019:binary_LOP000LBH93R9-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'ECB-POLICY',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 2},
#   {'author': 'REUTERS, OCT 24',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:41:43Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2IO9WL',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, THURSDAY, OCTOBER 24, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2IO9WL:1',
#    'internalReceivedDate': '2019-10-24T15:44:11Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, THURSDAY, OCTOBER 24, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:30:07Z',
#    'dimensions': '960x540',
#    'duration': 92,
#    'editNumber': '4457BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPFUZ',
#    'headline': 'Office workers beware! A glimpse into an unhealthy future',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPFUZ:2',
#    'internalReceivedDate': '2019-10-24T15:45:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPFUZ:2/tag:reuters.com,2019:binary_LOP000LBH95QD-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'HEALTH-WORK/MODEL',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:30:07Z',
#    'dimensions': '960x540',
#    'duration': 92,
#    'editNumber': '4457BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPFUZ',
#    'headline': 'Office workers beware! A glimpse into an unhealthy future',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPFUZ:1',
#    'internalReceivedDate': '2019-10-24T15:32:01Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPFUZ:1/tag:reuters.com,2019:binary_LOP000LBH95QD-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'HEALTH-WORK/MODEL',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:30:07Z',
#    'dimensions': '960x540',
#    'duration': 92,
#    'editNumber': '4457BO',
#    'geography': ['FR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPFUZ',
#    'headline': 'Office workers beware! A glimpse into an unhealthy future',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPFUZ:3',
#    'internalReceivedDate': '2019-10-24T15:54:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPFUZ:3/tag:reuters.com,2019:binary_LOP000LBH95QD-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'HEALTH-WORK/MODEL',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 3},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T15:30:04Z',
#    'dimensions': '960x540',
#    'duration': 115,
#    'editNumber': '4452BO',
#    'geography': ['DE'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GPBWR',
#    'headline': 'Draghi bows out as ECB keeps money taps on',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GPBWR:1',
#    'internalReceivedDate': '2019-10-24T15:35:55Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GPBWR:1/tag:reuters.com,2019:binary_LOP000LBH93R9-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'ECB-POLICY',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T14:27:08Z',
#    'dimensions': '960x540',
#    'duration': 58,
#    'editNumber': '4449BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GP9JF',
#    'headline': 'Twitter profit drops, shares plunge',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GP9JF:3',
#    'internalReceivedDate': '2019-10-24T14:27:13Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GP9JF:3/tag:reuters.com,2019:binary_LOP000LBH92KL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'TWITTER-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 3},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T14:27:05Z',
#    'dimensions': '960x540',
#    'duration': 58,
#    'editNumber': '4449BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GP9JF',
#    'headline': 'Twitter profit drops, shares plunge',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GP9JF:2',
#    'internalReceivedDate': '2019-10-24T14:27:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GP9JF:2/tag:reuters.com,2019:binary_LOP000LBH92KL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'TWITTER-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T13:55:09Z',
#    'dimensions': '960x540',
#    'duration': 58,
#    'editNumber': '4449BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GP9JF',
#    'headline': 'Twitter profit drops, shares plunge',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GP9JF:1',
#    'internalReceivedDate': '2019-10-24T14:03:00Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GP9JF:1/tag:reuters.com,2019:binary_LOP000LBH92KL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'TWITTER-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T10:56:05Z',
#    'dimensions': '960x540',
#    'duration': 63,
#    'editNumber': '4440BO',
#    'geography': ['HK'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GP2FF',
#    'headline': 'Hermès defies Hong Kong turmoil as Chinese demand buoys sales',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GP2FF:1',
#    'internalReceivedDate': '2019-10-24T11:00:13Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GP2FF:1/tag:reuters.com,2019:binary_LOP000LBH8Z0L-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'HERMES-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T10:53:04Z',
#    'dimensions': '960x540',
#    'duration': 97,
#    'editNumber': '4441BO',
#    'geography': ['XX'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GP37V',
#    'headline': 'Europe markets: Daimler lifts Dax, Nokia tanks',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GP37V:1',
#    'internalReceivedDate': '2019-10-24T11:00:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GP37V:1/tag:reuters.com,2019:binary_LOP000LBH8ZET-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'EUROPE-MARKETS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 24',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T09:07:04Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB2HGYSL',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 0900GMT, THURSDAY, OCTOBER 24, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB2HGYSL:1',
#    'internalReceivedDate': '2019-10-24T09:08:13Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 0900GMT, THURSDAY, OCTOBER 24, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 24',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-24T07:09:05Z',
#    'dimensions': '960x540',
#    'duration': 79,
#    'editNumber': '4432BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2GOW3V',
#    'headline': 'Tesla shares soar after posting surprise profit',
#    'id': 'tag:reuters.com,2019:newsml_OVB2GOW3V:1',
#    'internalReceivedDate': '2019-10-24T07:10:36Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2GOW3V:1/tag:reuters.com,2019:binary_LOP000LBH8VUT-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'TESLA-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 23',
#    'channelIds': [157,
#     172391,
#     156455,
#     18876,
#     158,
#     194309,
#     63328,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-23T22:40:07Z',
#    'dimensions': '960x540',
#    'duration': 106,
#    'editNumber': '3470BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2BPXEZ',
#    'headline': 'Rethink that last toke for the road with pot breathalyzers',
#    'id': 'tag:reuters.com,2019:newsml_OVB2BPXEZ:1',
#    'internalReceivedDate': '2019-10-23T22:41:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2BPXEZ:1/tag:reuters.com,2019:binary_LOP000LBEREID-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-MARIJUANA/BREATHALYZER',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NO ARCHIVE USE AND NO RESALES Digital: NO ARCHIVE USE AND NO RESALES. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 23',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-23T21:32:12Z',
#    'dimensions': '960x540',
#    'duration': 93,
#    'editNumber': '3474BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2BQ0LN',
#    'headline': 'Wall St gains as investors shrug off earnings',
#    'id': 'tag:reuters.com,2019:newsml_OVB2BQ0LN:1',
#    'internalReceivedDate': '2019-10-23T21:39:25Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2BQ0LN:1/tag:reuters.com,2019:binary_LOP000LBERG3P-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/CLOSE',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 23',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-23T20:43:04Z',
#    'dimensions': '960x540',
#    'duration': 188,
#    'editNumber': '3458BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2BPNYJ',
#    'headline': 'Zuckerberg reassures Congress on his digital currency',
#    'id': 'tag:reuters.com,2019:newsml_OVB2BPNYJ:1',
#    'internalReceivedDate': '2019-10-23T20:45:34Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB2BPNYJ:1/tag:reuters.com,2019:binary_LOP000LBER9S5-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'FACEBOOK-CONGRESS/LIBRA',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 23',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-23T19:27:10Z',
#    'dimensions': '960x540',
#    'duration': 302,
#    'editNumber': '3452BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB2BPJ7V',
#    'headline': 'Invest in small firms for the long run',
#    'id': 'tag:reuters.com,2019:newsml_OVB2BPJ7V:1',
# ...
#    'version': 2},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391, 156455, 158, 63328, 212951, 166089, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T22:17:06Z',
#    'dimensions': '960x540',
#    'duration': 120,
#    'editNumber': '2456BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PTOR',
#    'headline': 'Wall St. drops as Brexit strikes again',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PTOR:1',
#    'internalReceivedDate': '2019-10-22T22:19:17Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PTOR:1/tag:reuters.com,2019:binary_LOP000LBC9CN9-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/CLOSE',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters:  ACCESS ALL. NEWS AND CURRENT AFFAIRS USE ONLY. CANNOT BE USED FOR LIGHT ENTERTAINMENT OR SATIRICAL PURPOSES. PARTY POLITICAL BROADCAST USAGE MUST BE CLEARED WITH PBU Digital: ACCESS ALL. NEWS AND CURRENT AFFAIRS USE ONLY. CANNOT BE USED FOR LIGHT ENTERTAINMENT OR SATIRICAL PURPOSES. PARTY POLITICAL BROADCAST USAGE MUST BE CLEARED WITH PBU.. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T19:43:04Z',
#    'dimensions': '960x540',
#    'duration': 319,
#    'editNumber': '2457BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PUH7',
#    'headline': 'Earnings season looking better than expected -Winthrop Capital',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PUH7:1',
#    'internalReceivedDate': '2019-10-22T19:55:08Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PUH7:1/tag:reuters.com,2019:binary_LOP000LBC9D1H-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-STOCKS/ANALYST',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T19:37:22Z',
#    'dimensions': '960x540',
#    'duration': 103,
#    'editNumber': '2467BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26Q2DN',
#    'headline': 'Meat waste joins biofuels at luxury jet show',
#    'id': 'tag:reuters.com,2019:newsml_OVB26Q2DN:1',
#    'internalReceivedDate': '2019-10-22T19:42:45Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26Q2DN:1/tag:reuters.com,2019:binary_LOP000LBC9GZP-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AEROSPACE-BUSINESSJETS/ENVIRONMENT',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE.. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [157,
#     172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T19:26:04Z',
#    'dimensions': '960x540',
#    'duration': 52,
#    'editNumber': '2459BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PW17',
#    'headline': "Gulfstream unveils 'most spacious' G700 private jet",
#    'id': 'tag:reuters.com,2019:newsml_OVB26PW17:1',
#    'internalReceivedDate': '2019-10-22T19:29:30Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PW17:1/tag:reuters.com,2019:binary_LOP000LBC9DTH-VIEWIMAGE:512X288',
#    'priority': 2,
#    'remoteContentComplete': True,
#    'slug': 'AEROSPACE-BUSINESSJETS/',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391, 156455, 158, 194309, 63328, 166089, 32100, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T19:17:04Z',
#    'dimensions': '960x540',
#    'duration': 57,
#    'editNumber': '2466BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26Q1NJ',
#    'headline': 'Facebook probe by U.S. states expands to 47 attorneys general',
#    'id': 'tag:reuters.com,2019:newsml_OVB26Q1NJ:1',
#    'internalReceivedDate': '2019-10-22T19:21:55Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26Q1NJ:1/tag:reuters.com,2019:binary_LOP000LBC9GMN-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'USA-TECH-ANTITRUST-FACEBOOK',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: FACEBOOK HANDOUT: FOR EDITORIAL USE ONLY / NO ARCHIVE / NO RESALE Digital: FACEBOOK HANDOUT: FOR EDITORIAL USE ONLY / NO ARCHIVE / NO RESALE: . For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391, 156455, 158, 63328, 212951, 166089, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T16:56:05Z',
#    'dimensions': '960x540',
#    'duration': 59,
#    'editNumber': '2453BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PRBF',
#    'headline': "Biogen resurrects Alzheimer's drug, stock soars",
#    'id': 'tag:reuters.com,2019:newsml_OVB26PRBF:1',
#    'internalReceivedDate': '2019-10-22T16:57:17Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PRBF:1/tag:reuters.com,2019:binary_LOP000LBC9BGL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'BIOGEN-ALZHEIMERS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: PART MUST COURTESY YOUTUBE/BIOGEN Digital: PART MUST COURTESY YOUTUBE/BIOGEN. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 22',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T15:23:47Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB28MPLX',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, TUESDAY, OCTOBER 22, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB28MPLX:1',
#    'internalReceivedDate': '2019-10-22T15:24:12Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1600GMT, TUESDAY, OCTOBER 22, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T15:10:05Z',
#    'dimensions': '960x540',
#    'duration': 79,
#    'editNumber': '2447BO',
#    'geography': ['GB'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PMKR',
#    'headline': 'Prosus $6 bln Just Eat bid sets up food fight with Takeaway',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PMKR:1',
#    'internalReceivedDate': '2019-10-22T15:21:40Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PMKR:1/tag:reuters.com,2019:binary_LOP000LBC9939-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'JUST EAT-M&A/PROSUS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T15:07:07Z',
#    'dimensions': '960x540',
#    'duration': 116,
#    'editNumber': '2448BO',
#    'geography': ['XX'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PND7',
#    'headline': 'Air taxi startups race for the skies',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PND7:1',
#    'internalReceivedDate': '2019-10-22T15:16:09Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PND7:1/tag:reuters.com,2019:binary_LOP000LBC99HH-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'AVIATION-TAXIS/LILIUM',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE  Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     194309,
#     63328,
#     79133,
#     212951,
#     166089,
#     32100,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T15:06:07Z',
#    'dimensions': '960x540',
#    'duration': 67,
#    'editNumber': '2451BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PPQJ',
#    'headline': "McDonald's shares drop after rare profit miss",
#    'id': 'tag:reuters.com,2019:newsml_OVB26PPQJ:2',
#    'internalReceivedDate': '2019-10-22T15:06:13Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PPQJ:2/tag:reuters.com,2019:binary_LOP000LBC9AO5-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'MCDONALDS-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE. For Reuters customers only.',
#    'version': 2},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T14:42:07Z',
#    'dimensions': '960x540',
#    'duration': 67,
#    'editNumber': '2451BO',
#    'geography': ['US'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PPQJ',
#    'headline': "McDonald's shares drop after rare profit miss",
#    'id': 'tag:reuters.com,2019:newsml_OVB26PPQJ:1',
#    'internalReceivedDate': '2019-10-22T14:43:23Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PPQJ:1/tag:reuters.com,2019:binary_LOP000LBC9AO5-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'MCDONALDS-RESULTS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE. Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [157, 172391, 156455, 158, 63328, 212951, 166089, 122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T12:08:07Z',
#    'dimensions': '960x540',
#    'duration': 104,
#    'editNumber': '2445BO',
#    'geography': ['KR'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PKYZ',
#    'headline': 'Uniqlo ad sparks protests and parody in S. Korea',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PKYZ:2',
#    'internalReceivedDate': '2019-10-22T12:08:14Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PKYZ:2/tag:reuters.com,2019:binary_LOP000LBC98AD-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'SOUTHKOREA-JAPAN/UNIQLO ',
#    'source': 'Thomson Reuters',
#    'usageTerms': "Broadcasters:  FOR EDITORIAL USE ONLY /  MUST ON SCREEN COURTESY 'YOUN DONG-HYEUN' Digital: FOR EDITORIAL USE ONLY /  MUST ON SCREEN COURTESY 'YOUN DONG-HYEUN' . For Reuters customers only.",
#    'version': 2},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T11:36:07Z',
#    'dimensions': '960x540',
#    'duration': 114,
#    'editNumber': '2444BO',
#    'geography': ['CH'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PK7F',
#    'headline': 'UBS tightens investment banking belt as earnings slide continues',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PK7F:1',
#    'internalReceivedDate': '2019-10-22T11:42:10Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PK7F:1/tag:reuters.com,2019:binary_LOP000LBC97WL-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'UBS GROUP-RESULTS/',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [172391,
#     93257,
#     156455,
#     158,
#     182551,
#     63328,
#     79133,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T11:25:05Z',
#    'dimensions': '960x540',
#    'duration': 121,
#    'editNumber': '2439BO',
#    'geography': ['XX'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PG97',
#    'headline': 'European shares dip after flood of earnings',
#    'id': 'tag:reuters.com,2019:newsml_OVB26PG97:1',
#    'internalReceivedDate': '2019-10-22T11:27:21Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PG97:1/tag:reuters.com,2019:binary_LOP000LBC95XH-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'EUROPE-STOCKS/EARNINGS',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NONE Digital: NONE. For Reuters customers only.',
#    'version': 1},
#   {'author': 'REUTERS, OCT 22',
#    'channelIds': [172391, 158, 36964, 212951],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T09:46:27Z',
#    'editNumber': '0000BO',
#    'guid': 'tag:reuters.com,2019:newsml_ADB27LP2D',
#    'headline': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1000GMT, TUESDAY, OCTOBER 22, 2019',
#    'id': 'tag:reuters.com,2019:newsml_ADB27LP2D:1',
#    'internalReceivedDate': '2019-10-22T09:47:12Z',
#    'language': 'en',
#    'mediaType': 'T',
#    'priority': 4,
#    'slug': 'ADVISORY REUTERS BUSINESS REPORTS (BIZREP) / BUSINESS VIDEO ONLINE (BVO) 1000GMT, TUESDAY, OCTOBER 22, 2019',
#    'source': 'Thomson Reuters',
#    'version': 1},
#   {'author': 'Reuters, OCT 22',
#    'channelIds': [157,
#     172391,
#     156455,
#     158,
#     194309,
#     63328,
#     212951,
#     166089,
#     122641],
#    'channels': ['CLE548'],
#    'dateCreated': '2019-10-22T09:32:05Z',
#    'dimensions': '960x540',
#    'duration': 131,
#    'editNumber': '2437BO',
#    'geography': ['CA'],
#    'guid': 'tag:reuters.com,2019:newsml_OVB26PENF',
#    'headline': "Canada's Trudeau to remain in power but with minority government",
#    'id': 'tag:reuters.com,2019:newsml_OVB26PENF:2',
#    'internalReceivedDate': '2019-10-22T09:32:12Z',
#    'language': 'en',
#    'mediaType': 'V',
#    'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_OVB26PENF:2/tag:reuters.com,2019:binary_LOP000LBC954L-VIEWIMAGE:512X288',
#    'priority': 4,
#    'remoteContentComplete': True,
#    'slug': 'CANADA-ELECTION',
#    'source': 'Thomson Reuters',
#    'usageTerms': 'Broadcasters: NO USE CANADA Digital: NO USE CANADA . For Reuters customers only.',
#    'version': 2}],
#  'status': {'code': 10}}

# %% [markdown]
# ### 4. Retrieve the NewsML for an item

# %% [markdown]
# The item method is used to retrieve a particular news item as a NewsMLG2 document. To invoke this method, you must know the item ID of the news item you wish to retrieve.

# %%
ids = json.loads(response.text).get('results')

# %%
example_id = ids[0].get('id')
example_id
# Out:
# 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'

# %% [markdown]
# The *item* method is used to obtain a list of news items.

# %%
url = 'http://rmb.reuters.com/rmd/rest/json/item?id=' + example_id + '&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'associations': [{'body_xhtml': '              <p>Microsoft has won the Pentagon\'s $10 billion cloud computing contract.</p>\n              <p>And beaten out favorite Amazon.</p>\n              <p/>\n              <p>The U.S. Defense Department made the announcement on Friday (October 25).</p>\n              <p>The contracting process had long been mired in conflict of interest allegations.</p>\n              <p>And had even drawn the attention of President Donald Trump - who has publicly taken swipes at Amazon and its founder Jeff Bezos. </p>\n              <p>The Joint Enterprise Defense Infrastructure Cloud contract - or JEDI as it is known - is part of a broader digital modernization of the Pentagon.</p>\n              <p>The idea is to make it more technologically agile.</p>\n              <p>And specifically to give the military better access to data and the cloud from battlefields and other remote locations.</p>\n              <p>Although the Pentagon boasts the world\'s most potent fighting force, many officials say its information technology is woefully inadequate.</p>\n              <p>Tech giant and fellow bidder Oracle had expressed concerns about the award process for the contract...</p>\n              <p>Including the role of a former Amazon employee who worked on the project at the Defense Department but recused himself.</p>\n              <p>Then later left the Defense Department and returned to Amazon Web Services.</p>\n              <p>Other companies were concerned a single award would give the winner an unfair advantage in follow-on work. </p>\n              <p>The Pentagon has said it planned to award future cloud deals to multiple contractors.</p>\n              <p>After the announcement was made, a statement from the Amazon Web Services spokesman said the company was "surprised about this conclusion."</p>\n              <p>And that a "detailed assessment purely on the comparative offerings" would "clearly lead to a different conclusion".</p>\n              <p>A person familiar with the matter told Reuters Amazon is considering protesting the award.</p>\n              <p>Microsoft shares were up 3% in after-hours trading after the news. </p>\n              <p>Amazon shares were down 0.92%.</p>\n            ',
#    'byline': 'Reuters, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'dateline': 'RECENT, FILE',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#    'intro': "Microsoft has won the Pentagon's $10 billion cloud computing contract, the Defense Department said on Friday, beating out favorite Amazon. Mia Womersley reports",
#    'language': 'en',
#    'located': 'VARIOUS',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Text',
#    'signal': ['prodId:VID', 'edStat:U'],
#    'slug': 'PENTAGON-JEDI',
#    'source': {'literal': 'Reuters'},
#    'type': 'text',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1M',
#    'usn': 'OVB2QOJ1M',
#    'version': '2',
#    'versioncreated': '2019-10-26T15:12:53.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1M:2',
#    'wordcount': 266},
#   {'audio': 'NATURAL WITH ENGLISH SPEECH',
#    'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Video',
#    'renditions': [{'audiobitrate': 12200,
#      'audiosamplerate': 8000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-80-11X9-3G2_PENTAGON-JEDI.3G2',
#      'format': 'fmt:3gpp2MultimediaFile',
#      'generated': '2019-10-26T10:31:21.000Z',
#      'height': 144,
#      'mimetype': 'video/3gpp2',
#      'rendition': 'rend:stream:80:11x9:3g2',
#      'sizeinbytes': 1071179,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:80:11X9:3G2',
#      'videoaspectratio': '11:9',
#      'width': 176},
#     {'audiobitrate': 48000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-512-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 288,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:512:16x9:flv',
#      'sizeinbytes': 6981426,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:512:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 512},
#     {'audiobitrate': 12200,
#      'audiosamplerate': 8000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-80-11X9-3GP_PENTAGON-JEDI.3GP',
#      'format': 'fmt:3gppMultimediaFile',
#      'generated': '2019-10-26T10:31:21.000Z',
#      'height': 144,
#      'mimetype': 'video/3gpp',
#      'rendition': 'rend:stream:80:11x9:3gp',
#      'sizeinbytes': 1071179,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:80:11X9:3GP',
#      'videoaspectratio': '11:9',
#      'width': 176},
#     {'audiobitrate': 32000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-300-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 216,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:300:16x9:mp4',
#      'sizeinbytes': 4073043,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:300:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 384},
#     {'audiobitrate': 32000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-300-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 216,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:300:16x9:flv',
#      'sizeinbytes': 4137840,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:300:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 384},
#     {'audiobitrate': 128000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-5128-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 720,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:5128:16x9:mp4',
#      'sizeinbytes': 69401601,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:5128:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1280},
#     {'audiobitrate': 128000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-2000-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 432,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:2000:16x9:mp4',
#      'sizeinbytes': 26854991,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:2000:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 768},
#     {'audiobitrate': 76000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-700-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 360,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:700:16x9:mp4',
#      'sizeinbytes': 9469949,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:700:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 640},
#     {'audiobitrate': 96000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-700-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 324,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:700:16x9:flv',
#      'sizeinbytes': 9500375,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:700:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 576},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-8256M-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 1080,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:8256m:16x9:mp4',
#      'sizeinbytes': 105716193,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:8256M:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1920},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 48000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-6756-16X9-MPG_PENTAGON-JEDI.MPG',
#      'format': 'fmt:mpeg',
#      'generated': '2019-10-26T10:32:15.000Z',
#      'height': 576,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:6756:16x9:mpg',
#      'sizeinbytes': 96667648,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:6756:16X9:MPG',
#      'videoaspectratio': '16:9',
#      'width': 720},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-8256-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 1080,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:8256:16x9:mp4',
#      'sizeinbytes': 106130443,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:8256:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1920},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 48000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-1756-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:04.000Z',
#      'height': 720,
#      'mimetype': 'video/mp4',
#      'rendition': 'rend:stream:1756:16x9:mp4',
#      'sizeinbytes': 30293516,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:1756:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1280}],
#    'source': {'literal': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT'},
#    'type': 'video',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOV000LBM8PBP',
#    'usn': 'LOV000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOV000LBM8PBP:1'},
#   {'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Audio',
#    'renditions': [{'audiobitrate': 56000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOA000LBM8PBP_RTRMADA_STREAM-22-050-MP3_PENTAGON-JEDI.MP3',
#      'format': 'fmt:mpeg',
#      'generated': '2019-10-26T10:31:10.000Z',
#      'mimetype': 'audio/mpeg',
#      'rendition': 'rend:stream:22.050:mp3',
#      'sizeinbytes': 755164,
#      'uri': 'tag:reuters.com,2019:binary_LOA000LBM8PBP-STREAM:22.050:MP3'}],
#    'type': 'audio',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOA000LBM8PBP',
#    'usn': 'LOA000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOA000LBM8PBP:1'},
#   {'altid': {'iid': 'LOP000LBM8PBP'},
#    'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Picture',
#    'renditions': [{'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_VIEWIMAGE-512X288_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:07.000Z',
#      'height': 288,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:viewImage:512x288',
#      'sizeinbytes': 12791,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-VIEWIMAGE:512X288',
#      'width': 512},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_THUMBNAILGRID_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 240,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:thumbnailgrid',
#      'sizeinbytes': 191667,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-THUMBNAILGRID',
#      'width': 8967},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_THUMBNAIL-160X90_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:08.000Z',
#      'height': 90,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:thumbnail:160x90',
#      'sizeinbytes': 5854,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-THUMBNAIL:160X90',
#      'width': 160},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_BASEIMAGE-960X540_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:07.000Z',
#      'height': 540,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:baseImage:960x540',
#      'sizeinbytes': 23940,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-BASEIMAGE:960X540',
#      'width': 960}],
#    'type': 'picture',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOP000LBM8PBP',
#    'usn': 'LOP000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOP000LBM8PBP:1'}],
#  'byline': 'Reuters, OCT 26',
#  'copyrightholder': 'Thomson Reuters',
#  'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#  'dateline': 'RECENT, FILE',
#  'destination': ['BVO', 'NVO', 'USVO'],
#  'editnumber': '6434',
#  'firstcreated': '2019-10-26T10:26:32.000Z',
#  'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#  'language': 'en',
#  'located': 'VARIOUS',
#  'mimetype': 'application/json',
#  'productlabel': 'video-package',
#  'profile': 'NEP-External_ANP',
#  'renditions': [{'filename': '2019-10-26T151253Z_2_OVB2QOJ1N_RTRMADC_0_PENTAGON-JEDI.XML',
#    'mimetype': 'application/vnd.iptc.g2.newsitem+xml',
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'},
#   {'filename': '2019-10-26T151253Z_2_OVB2QOJ1N_RTRMADC_0_PENTAGON-JEDI',
#    'mimetype': 'application/json',
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'}],
#  'representationtype': 'complete',
#  'signal': ['pmt:video',
#   'sic:WNE',
#   'prodId:VID',
#   'sic:ATOMIC',
#   'svd:Mixed',
#   'sic:NORC',
#   'sic:VIDRTPCON',
#   'edStat:U'],
#  'slug': 'PENTAGON-JEDI',
#  'source': {'literal': 'Reuters'},
#  'subject': [{'code': 'ISLC:No-Data-Available'},
#   {'code': 'N2:AERO'},
#   {'code': 'N2:DEF', 'name': 'Defence'},
#   {'code': 'N2:POL', 'name': 'Government/Politics'},
#   {'code': 'N2:US'},
#   {'code': 'WNSFR:USVO'},
#   {'code': 'rvnServiceCode:BO', 'name': 'BVO'},
#   {'code': 'rvnServiceCode:BR', 'name': 'Business Report'},
#   {'code': 'rvnServiceCode:NO', 'name': 'NVO'},
#   {'code': 'rvnServiceCode:RR', 'name': 'R Rep'},
#   {'code': 'rvnServiceCode:UO', 'name': 'USVO'},
#   {'code': 'tvsc:PIA'},
#   {'name': 'VARIOUS'}],
#  'subjectlocation': {'city': 'VARIOUS',
#   'countrycode': 'N2:US',
#   'countryname': 'US'},
#  'type': 'video',
#  'urgency': 4,
#  'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#  'usageterms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#  'usagetermsrole': 'Online',
#  'usn': 'OVB2QOJ1N',
#  'version': '2',
#  'versioncreated': '2019-10-26T15:13:08.000Z',
#  'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'}

# %% [markdown]
# Highlighting company entities in a NewsML2 text item using **entityMarkup** (needs to be applied to a text-based example_id).

# %%
url = 'http://rmb.reuters.com/rmd/rest/json/item?id=' + example_id + '&entityMarkup=newsml&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'associations': [{'body_xhtml': '              <p>Microsoft has won the Pentagon\'s $10 billion cloud computing contract.</p>\n              <p>And beaten out favorite Amazon.</p>\n              <p/>\n              <p>The U.S. Defense Department made the announcement on Friday (October 25).</p>\n              <p>The contracting process had long been mired in conflict of interest allegations.</p>\n              <p>And had even drawn the attention of President Donald Trump - who has publicly taken swipes at Amazon and its founder Jeff Bezos. </p>\n              <p>The Joint Enterprise Defense Infrastructure Cloud contract - or JEDI as it is known - is part of a broader digital modernization of the Pentagon.</p>\n              <p>The idea is to make it more technologically agile.</p>\n              <p>And specifically to give the military better access to data and the cloud from battlefields and other remote locations.</p>\n              <p>Although the Pentagon boasts the world\'s most potent fighting force, many officials say its information technology is woefully inadequate.</p>\n              <p>Tech giant and fellow bidder Oracle had expressed concerns about the award process for the contract...</p>\n              <p>Including the role of a former Amazon employee who worked on the project at the Defense Department but recused himself.</p>\n              <p>Then later left the Defense Department and returned to Amazon Web Services.</p>\n              <p>Other companies were concerned a single award would give the winner an unfair advantage in follow-on work. </p>\n              <p>The Pentagon has said it planned to award future cloud deals to multiple contractors.</p>\n              <p>After the announcement was made, a statement from the Amazon Web Services spokesman said the company was "surprised about this conclusion."</p>\n              <p>And that a "detailed assessment purely on the comparative offerings" would "clearly lead to a different conclusion".</p>\n              <p>A person familiar with the matter told Reuters Amazon is considering protesting the award.</p>\n              <p>Microsoft shares were up 3% in after-hours trading after the news. </p>\n              <p>Amazon shares were down 0.92%.</p>\n            ',
#    'byline': 'Reuters, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'dateline': 'RECENT, FILE',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#    'intro': "Microsoft has won the Pentagon's $10 billion cloud computing contract, the Defense Department said on Friday, beating out favorite Amazon. Mia Womersley reports",
#    'language': 'en',
#    'located': 'VARIOUS',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Text',
#    'signal': ['prodId:VID', 'edStat:U'],
#    'slug': 'PENTAGON-JEDI',
#    'source': {'literal': 'Reuters'},
#    'type': 'text',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1M',
#    'usn': 'OVB2QOJ1M',
#    'version': '2',
#    'versioncreated': '2019-10-26T15:12:53.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1M:2',
#    'wordcount': 266},
#   {'audio': 'NATURAL WITH ENGLISH SPEECH',
#    'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Video',
#    'renditions': [{'audiobitrate': 12200,
#      'audiosamplerate': 8000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-80-11X9-3G2_PENTAGON-JEDI.3G2',
#      'format': 'fmt:3gpp2MultimediaFile',
#      'generated': '2019-10-26T10:31:21.000Z',
#      'height': 144,
#      'mimetype': 'video/3gpp2',
#      'rendition': 'rend:stream:80:11x9:3g2',
#      'sizeinbytes': 1071179,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:80:11X9:3G2',
#      'videoaspectratio': '11:9',
#      'width': 176},
#     {'audiobitrate': 48000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-512-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 288,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:512:16x9:flv',
#      'sizeinbytes': 6981426,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:512:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 512},
#     {'audiobitrate': 12200,
#      'audiosamplerate': 8000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-80-11X9-3GP_PENTAGON-JEDI.3GP',
#      'format': 'fmt:3gppMultimediaFile',
#      'generated': '2019-10-26T10:31:21.000Z',
#      'height': 144,
#      'mimetype': 'video/3gpp',
#      'rendition': 'rend:stream:80:11x9:3gp',
#      'sizeinbytes': 1071179,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:80:11X9:3GP',
#      'videoaspectratio': '11:9',
#      'width': 176},
#     {'audiobitrate': 32000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-300-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 216,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:300:16x9:mp4',
#      'sizeinbytes': 4073043,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:300:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 384},
#     {'audiobitrate': 32000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-300-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 216,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:300:16x9:flv',
#      'sizeinbytes': 4137840,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:300:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 384},
#     {'audiobitrate': 128000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-5128-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 720,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:5128:16x9:mp4',
#      'sizeinbytes': 69401601,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:5128:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1280},
#     {'audiobitrate': 128000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-2000-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 432,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:2000:16x9:mp4',
#      'sizeinbytes': 26854991,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:2000:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 768},
#     {'audiobitrate': 76000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-700-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:31:56.000Z',
#      'height': 360,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:700:16x9:mp4',
#      'sizeinbytes': 9469949,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:700:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 640},
#     {'audiobitrate': 96000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-700-16X9-FLV_PENTAGON-JEDI.FLV',
#      'format': 'fmt:flashVideo',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 324,
#      'mimetype': 'video/x-flv',
#      'rendition': 'rend:stream:700:16x9:flv',
#      'sizeinbytes': 9500375,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:700:16X9:FLV',
#      'videoaspectratio': '16:9',
#      'width': 576},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-8256M-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 1080,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:8256m:16x9:mp4',
#      'sizeinbytes': 105716193,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:8256M:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1920},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 48000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-6756-16X9-MPG_PENTAGON-JEDI.MPG',
#      'format': 'fmt:mpeg',
#      'generated': '2019-10-26T10:32:15.000Z',
#      'height': 576,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:6756:16x9:mpg',
#      'sizeinbytes': 96667648,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:6756:16X9:MPG',
#      'videoaspectratio': '16:9',
#      'width': 720},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 44100,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-8256-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:55.000Z',
#      'height': 1080,
#      'mimetype': 'video/mpeg',
#      'rendition': 'rend:stream:8256:16x9:mp4',
#      'sizeinbytes': 106130443,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:8256:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1920},
#     {'audiobitrate': 256000,
#      'audiosamplerate': 48000,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOV000LBM8PBP_RTRMADV_STREAM-1756-16X9-MP4_PENTAGON-JEDI.MP4',
#      'format': 'fmt:H264/mpeg',
#      'generated': '2019-10-26T10:32:04.000Z',
#      'height': 720,
#      'mimetype': 'video/mp4',
#      'rendition': 'rend:stream:1756:16x9:mp4',
#      'sizeinbytes': 30293516,
#      'uri': 'tag:reuters.com,2019:binary_LOV000LBM8PBP-STREAM:1756:16X9:MP4',
#      'videoaspectratio': '16:9',
#      'width': 1280}],
#    'source': {'literal': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT'},
#    'type': 'video',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOV000LBM8PBP',
#    'usn': 'LOV000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOV000LBM8PBP:1'},
#   {'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Audio',
#    'renditions': [{'audiobitrate': 56000,
#      'audiosamplerate': 22050,
#      'duration': 108,
#      'filename': '2019-10-26T102632Z_1_LOA000LBM8PBP_RTRMADA_STREAM-22-050-MP3_PENTAGON-JEDI.MP3',
#      'format': 'fmt:mpeg',
#      'generated': '2019-10-26T10:31:10.000Z',
#      'mimetype': 'audio/mpeg',
#      'rendition': 'rend:stream:22.050:mp3',
#      'sizeinbytes': 755164,
#      'uri': 'tag:reuters.com,2019:binary_LOA000LBM8PBP-STREAM:22.050:MP3'}],
#    'type': 'audio',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOA000LBM8PBP',
#    'usn': 'LOA000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOA000LBM8PBP:1'},
#   {'altid': {'iid': 'LOP000LBM8PBP'},
#    'byline': 'REUTERS / MICROSOFT HANDOUT / US DEPARTMENT OF DEFENSE HANDOUT, OCT 26',
#    'copyrightholder': 'Thomson Reuters',
#    'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#    'firstcreated': '2019-10-26T10:26:32.000Z',
#    'language': 'en',
#    'mimetype': 'application/json',
#    'profile': 'SNI-Picture',
#    'renditions': [{'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_VIEWIMAGE-512X288_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:07.000Z',
#      'height': 288,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:viewImage:512x288',
#      'sizeinbytes': 12791,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-VIEWIMAGE:512X288',
#      'width': 512},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_THUMBNAILGRID_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:58.000Z',
#      'height': 240,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:thumbnailgrid',
#      'sizeinbytes': 191667,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-THUMBNAILGRID',
#      'width': 8967},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_THUMBNAIL-160X90_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:08.000Z',
#      'height': 90,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:thumbnail:160x90',
#      'sizeinbytes': 5854,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-THUMBNAIL:160X90',
#      'width': 160},
#     {'filename': '2019-10-26T102632Z_1_LOP000LBM8PBP_RTRMADP_BASEIMAGE-960X540_PENTAGON-JEDI.JPG',
#      'format': 'fmt:jpegBaseline',
#      'generated': '2019-10-26T10:31:07.000Z',
#      'height': 540,
#      'mimetype': 'image/jpeg',
#      'rendition': 'rend:baseImage:960x540',
#      'sizeinbytes': 23940,
#      'uri': 'tag:reuters.com,2019:binary_LOP000LBM8PBP-BASEIMAGE:960X540',
#      'width': 960}],
#    'type': 'picture',
#    'urgency': 4,
#    'uri': 'tag:reuters.com,2019:newsml_LOP000LBM8PBP',
#    'usn': 'LOP000LBM8PBP',
#    'version': '1',
#    'versioncreated': '2019-10-26T15:13:08.000Z',
#    'versionedguid': 'tag:reuters.com,2019:newsml_LOP000LBM8PBP:1'}],
#  'byline': 'Reuters, OCT 26',
#  'copyrightholder': 'Thomson Reuters',
#  'copyrightnotice': '(c) 2019 Thomson Reuters, unless otherwise identified. Full statement available at https://www.thomsonreuters.com/en/copyright.html',
#  'dateline': 'RECENT, FILE',
#  'destination': ['BVO', 'NVO', 'USVO'],
#  'editnumber': '6434',
#  'firstcreated': '2019-10-26T10:26:32.000Z',
#  'headline': "Microsoft beats Amazon for Pentagon's $10 bln cloud computing contract",
#  'language': 'en',
#  'located': 'VARIOUS',
#  'mimetype': 'application/json',
#  'productlabel': 'video-package',
#  'profile': 'NEP-External_ANP',
#  'renditions': [{'filename': '2019-10-26T151253Z_2_OVB2QOJ1N_RTRMADC_0_PENTAGON-JEDI.XML',
#    'mimetype': 'application/vnd.iptc.g2.newsitem+xml',
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'},
#   {'filename': '2019-10-26T151253Z_2_OVB2QOJ1N_RTRMADC_0_PENTAGON-JEDI',
#    'mimetype': 'application/json',
#    'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#    'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'}],
#  'representationtype': 'complete',
#  'signal': ['pmt:video',
#   'sic:WNE',
#   'prodId:VID',
#   'sic:ATOMIC',
#   'svd:Mixed',
#   'sic:NORC',
#   'sic:VIDRTPCON',
#   'edStat:U'],
#  'slug': 'PENTAGON-JEDI',
#  'source': {'literal': 'Reuters'},
#  'subject': [{'code': 'ISLC:No-Data-Available'},
#   {'code': 'N2:AERO'},
#   {'code': 'N2:DEF', 'name': 'Defence'},
#   {'code': 'N2:POL', 'name': 'Government/Politics'},
#   {'code': 'N2:US'},
#   {'code': 'WNSFR:USVO'},
#   {'code': 'rvnServiceCode:BO', 'name': 'BVO'},
#   {'code': 'rvnServiceCode:BR', 'name': 'Business Report'},
#   {'code': 'rvnServiceCode:NO', 'name': 'NVO'},
#   {'code': 'rvnServiceCode:RR', 'name': 'R Rep'},
#   {'code': 'rvnServiceCode:UO', 'name': 'USVO'},
#   {'code': 'tvsc:PIA'},
#   {'name': 'VARIOUS'}],
#  'subjectlocation': {'city': 'VARIOUS',
#   'countrycode': 'N2:US',
#   'countryname': 'US'},
#  'type': 'video',
#  'urgency': 4,
#  'uri': 'tag:reuters.com,2019:newsml_OVB2QOJ1N',
#  'usageterms': 'Broadcasters: NONE Digital: NONE . For Reuters customers only.',
#  'usagetermsrole': 'Online',
#  'usn': 'OVB2QOJ1N',
#  'version': '2',
#  'versioncreated': '2019-10-26T15:13:08.000Z',
#  'versionedguid': 'tag:reuters.com,2019:newsml_OVB2QOJ1N:2'}

# %% [markdown]
# ### 5. Search functionality

# %% [markdown]
# The search method is used to obtain a list of news items which match the search criteria you provide. This method provides more advanced filtering options than those offered with the items method as well as full text search capabilities. You can find more examples on p. 49 of the developer guide.

# %% [markdown]
# Example query based on the *headline* and *topic* of news articles.

# %%
# Can do search queries for following fields: headline, slug, body, caption, topic, entity, ... (fulltext, main)
search_query = 'headline:obama AND iraq||topic:POL||topic:WAR OR SPO'
url = 'http://rmb.reuters.com/rmd/rest/json/search?q=' + search_query + '&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'results': {'mediaTypeBreakdownPercent': {'C': 2,
#    'G': 0,
#    'P': 80,
#    'T': 17,
#    'V': 1},
#   'numFound': 2886,
#   'result': [{'author': 'AKHTAR SOOMRO',
#     'channelIds': [175935,
#      86083,
#      175155,
#      175217,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      175219,
#      130019,
#      134801,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701625000,
#     'destination': ['RPA'],
#     'dimensions': '3352x4490',
#     'geography': ['PAK'],
#     'guid': 'tag:reuters.com,2019:newsml_RC14C207D760',
#     'headline': 'Supporters of religious and political party during what participants call Freedom March to protest the government of Prime Minister Imran Khan in Islamabad',
#     'id': 'tag:reuters.com,2019:newsml_RC14C207D760:746757794',
#     'indexTimestamp': 1572701642141,
#     'internalReceivedDate': 1572701642141,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC14C207D760:746757794/tag:reuters.com,2019:binary_RC14C207D760-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 3264057,
#     'slug': 'PAKISTAN-POLITICS/PROTESTS',
#     'source': 'Thomson Reuters',
#     'version': 746757794},
#    {'author': 'ALBERTO LINGRIA',
#     'channelIds': [106339,
#      86083,
#      175155,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      78177,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701579000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '2524x1775',
#     'geography': ['ITA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1C01056930',
#     'headline': 'Serie A - AS Roma v Napoli',
#     'id': 'tag:reuters.com,2019:newsml_RC1C01056930:620440346',
#     'indexTimestamp': 1572701599141,
#     'internalReceivedDate': 1572701599141,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1C01056930:620440346/tag:reuters.com,2019:binary_RC1C01056930-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1273590,
#     'slug': 'SOCCER-ITALY-ROM-NA/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 620440346},
#    {'author': 'COURTESY OF ABI/BOLIVIAN INFORMA',
#     'channelIds': [175935,
#      175217,
#      136867,
#      823,
#      198575,
#      136717,
#      149225,
#      130019,
#      134801,
#      176033,
#      812,
#      130523],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701577000,
#     'destination': ['RPA'],
#     'dimensions': '3501x2523',
#     'geography': ['BOL'],
#     'guid': 'tag:reuters.com,2019:newsml_RC16FE93E730',
#     'headline': "President of Bolivia's Supreme Electoral Tribunal (TSE) Maria Eugenia Choque speaks during a news conference in La Paz",
#     'id': 'tag:reuters.com,2019:newsml_RC16FE93E730:254980797',
#     'indexTimestamp': 1572701599912,
#     'internalReceivedDate': 1572701599912,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC16FE93E730:254980797/tag:reuters.com,2019:binary_RC16FE93E730-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 2224542,
#     'slug': 'BOLIVIA-ELCTION/',
#     'source': 'Thomson Reuters',
#     'usageTerms': '3TP',
#     'version': 254980797},
#    {'author': 'AKHTAR SOOMRO',
#     'channelIds': [175935,
#      86083,
#      175155,
#      175217,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      175219,
#      130019,
#      134801,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701551000,
#     'destination': ['RPA'],
#     'dimensions': '6720x4479',
#     'geography': ['PAK'],
#     'guid': 'tag:reuters.com,2019:newsml_RC168424C2F0',
#     'headline': 'Supporters of religious and political party during what participants call Freedom March to protest the government of Prime Minister Imran Khan in Islamabad,',
#     'id': 'tag:reuters.com,2019:newsml_RC168424C2F0:172778050',
#     'indexTimestamp': 1572701574344,
#     'internalReceivedDate': 1572701574344,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC168424C2F0:172778050/tag:reuters.com,2019:binary_RC168424C2F0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 5630522,
#     'slug': 'PAKISTAN-POLITICS/PROTESTS',
#     'source': 'Thomson Reuters',
#     'version': 172778050},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701450000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '4850x3219',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1E32D6E600',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC1E32D6E600:2050146651',
#     'indexTimestamp': 1572701472055,
#     'internalReceivedDate': 1572701472055,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1E32D6E600:2050146651/tag:reuters.com,2019:binary_RC1E32D6E600-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 3646597,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 2050146651},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701447000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '3012x2188',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1A97594E30',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC1A97594E30:3812576',
#     'indexTimestamp': 1572701464561,
#     'internalReceivedDate': 1572701464561,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1A97594E30:3812576/tag:reuters.com,2019:binary_RC1A97594E30-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1247697,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 3812576},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701429000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '4383x3006',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1C151F0490',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC1C151F0490:1626117751',
#     'indexTimestamp': 1572701453635,
#     'internalReceivedDate': 1572701453635,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1C151F0490:1626117751/tag:reuters.com,2019:binary_RC1C151F0490-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1864981,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 1626117751},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701428000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '4245x2964',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC18F7A3C6A0',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC18F7A3C6A0:1805195662',
#     'indexTimestamp': 1572701445619,
#     'internalReceivedDate': 1572701445619,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC18F7A3C6A0:1805195662/tag:reuters.com,2019:binary_RC18F7A3C6A0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2008793,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 1805195662},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701426000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '3167x2292',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC14062EBEE0',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC14062EBEE0:883358373',
#     'indexTimestamp': 1572701444111,
#     'internalReceivedDate': 1572701444111,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC14062EBEE0:883358373/tag:reuters.com,2019:binary_RC14062EBEE0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1127554,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 883358373},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701425000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '2764x1988',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1F244C5580',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC1F244C5580:200052649',
#     'indexTimestamp': 1572701447128,
#     'internalReceivedDate': 1572701447128,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1F244C5580:200052649/tag:reuters.com,2019:binary_RC1F244C5580-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 957792,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 200052649},
#    {'author': 'ALY SONG',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701414000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '5184x3456',
#     'geography': ['CHN'],
#     'guid': 'tag:reuters.com,2019:newsml_RC11ED07D5D0',
#     'headline': 'WTA Tour Finals',
#     'id': 'tag:reuters.com,2019:newsml_RC11ED07D5D0:83649147',
#     'indexTimestamp': 1572701435505,
#     'internalReceivedDate': 1572701435505,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC11ED07D5D0:83649147/tag:reuters.com,2019:binary_RC11ED07D5D0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 4437566,
#     'slug': 'TENNIS-WTAFINALS/',
#     'source': 'Thomson Reuters',
#     'version': 83649147},
#    {'channelIds': [542,
#      626,
#      159003,
#      176417,
#      22321,
#      63697,
#      647,
#      70666,
#      29598,
#      63633,
#      49349,
#      63667,
#      599,
#      63685,
#      644,
#      63665,
#      158991,
#      68936,
#      635,
#      22370,
#      159015,
#      118201,
#      23278,
#      27574,
#      564],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572701275000,
#     'destination': ['PSC',
#      'LBY',
#      'DNP',
#      'AFN',
#      'J',
#      'PSP',
#      'RSP',
#      'CSA',
#      'UCDPTEST',
#      'SF',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['ZA', 'GB'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27I0AL',
#     'headline': "Rugby-Erasmus' South Africa game plan gets thumbs up from ex-Boks",
#     'id': 'tag:reuters.com,2019:newsml_L8N27I0AL:76873634',
#     'indexTimestamp': 1572701278735,
#     'internalReceivedDate': 1572701278735,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 76873634},
#    {'channelIds': [587,
#      70659,
#      70660,
#      611,
#      585,
#      63412,
#      586,
#      159005,
#      158993,
#      158997,
#      656,
#      68948,
#      63457,
#      118201,
#      63414,
#      63386,
#      68929,
#      63413,
#      158995,
#      68934],
#     'channels': ['HkV652', 'jyn629'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572701234000,
#     'destination': ['UCDPTEST', 'GERT', 'GEA', 'SWI', 'OE', 'GEM'],
#     'geography': ['CN'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27I0A3',
#     'headline': 'FOKUS 1-Wieder Ausschreitungen bei Proteste in Hongkong',
#     'id': 'tag:reuters.com,2019:newsml_L8N27I0A3:1534572626',
#     'indexTimestamp': 1572701236588,
#     'internalReceivedDate': 1572701236588,
#     'language': 'de',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'var:itemEvol',
#      'source:ids',
#      'sic:XBSUM',
#      'edStat:N'],
#     'slug': 'HONGKONG/PROTESTE (FOKUS 1)',
#     'source': 'Thomson Reuters',
#     'version': 1534572626},
#    {'author': 'CHRISTIAN MANG',
#     'channelIds': [175935,
#      86083,
#      175155,
#      175217,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      205403,
#      149225,
#      130019,
#      134801,
#      122999,
#      175215,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701182000,
#     'destination': ['RPA'],
#     'dimensions': '5713x3743',
#     'geography': ['DEU'],
#     'guid': 'tag:reuters.com,2019:newsml_RC11AB0F5D00',
#     'headline': "People attend a pro-Kurdish demonstration against Turkey's military action in northeastern Syria, in Berlin",
#     'id': 'tag:reuters.com,2019:newsml_RC11AB0F5D00:1865176025',
#     'indexTimestamp': 1572701201636,
#     'internalReceivedDate': 1572701201636,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC11AB0F5D00:1865176025/tag:reuters.com,2019:binary_RC11AB0F5D00-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 4242445,
#     'slug': 'SYRIA-SECURITY/GERMANY-KURDS',
#     'source': 'Thomson Reuters',
#     'version': 1865176025},
#    {'channelIds': [626,
#      662,
#      176417,
#      63697,
#      647,
#      154257,
#      49349,
#      599,
#      63685,
#      644,
#      63665,
#      63708,
#      22370,
#      118201,
#      23278,
#      27574],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572701176000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'UKI',
#      'SF',
#      'RWSA',
#      'J',
#      'REULB',
#      'AFA',
#      'RSP',
#      'RBN'],
#     'geography': ['RU',
#      'UY',
#      'FJ',
#      'JP',
#      'ZA',
#      'IT',
#      'NZ',
#      'FR',
#      'AR',
#      'NA',
#      'AU',
#      'GB',
#      'TO',
#      'WS',
#      'IE',
#      'GE',
#      'CA',
#      'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27I02Q',
#     'headline': 'FACTBOX-Rugby-World Cup finals results',
#     'id': 'tag:reuters.com,2019:newsml_L3N27I02Q:1920991163',
#     'indexTimestamp': 1572701184757,
#     'internalReceivedDate': 1572701184757,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (FACTBOX)',
#     'source': 'Thomson Reuters',
#     'version': 1920991163},
#    {'author': 'CRAIG BROUGH',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      179339,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701151000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '5184x3456',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC13B00EC160',
#     'headline': 'Premier League - Aston Villa v Liverpool',
#     'id': 'tag:reuters.com,2019:newsml_RC13B00EC160:525665253',
#     'indexTimestamp': 1572701175752,
#     'internalReceivedDate': 1572701175752,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC13B00EC160:525665253/tag:reuters.com,2019:binary_RC13B00EC160-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 7777645,
#     'slug': 'SOCCER-ENGLAND-AVA-LIV/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 525665253},
#    {'author': 'CRAIG BROUGH',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      179339,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701150000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '5184x3456',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1BB80E2410',
#     'headline': 'Premier League - Aston Villa v Liverpool',
#     'id': 'tag:reuters.com,2019:newsml_RC1BB80E2410:1081583299',
#     'indexTimestamp': 1572701177599,
#     'internalReceivedDate': 1572701177599,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1BB80E2410:1081583299/tag:reuters.com,2019:binary_RC1BB80E2410-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 6786175,
#     'slug': 'SOCCER-ENGLAND-AVA-LIV/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1081583299},
#    {'author': 'CHRISTIAN MANG',
#     'channelIds': [175935,
#      86083,
#      175155,
#      175217,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      205403,
#      149225,
#      130019,
#      134801,
#      122999,
#      175215,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701145000,
#     'destination': ['RPA'],
#     'dimensions': '5225x3486',
#     'geography': ['DEU'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1A9D641380',
#     'headline': "People attend a pro-Kurdish demonstration against Turkey's military action in northeastern Syria, in Berlin",
#     'id': 'tag:reuters.com,2019:newsml_RC1A9D641380:1664200086',
#     'indexTimestamp': 1572701165261,
#     'internalReceivedDate': 1572701165261,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1A9D641380:1664200086/tag:reuters.com,2019:binary_RC1A9D641380-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 3836947,
#     'slug': 'SYRIA-SECURITY/GERMANY-KURDS',
#     'source': 'Thomson Reuters',
#     'version': 1664200086},
#    {'author': 'JAVIER BARBANCHO',
#     'channelIds': [106339,
#      86083,
#      82915,
#      175155,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701090000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '5184x3456',
#     'geography': ['ESP'],
#     'guid': 'tag:reuters.com,2019:newsml_RC190945CF00',
#     'headline': 'La Liga Santander - Levante v FC Barcelona',
#     'id': 'tag:reuters.com,2019:newsml_RC190945CF00:1271653156',
#     'indexTimestamp': 1572701115589,
#     'internalReceivedDate': 1572701115589,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC190945CF00:1271653156/tag:reuters.com,2019:binary_RC190945CF00-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 6478798,
#     'slug': 'SOCCER-SPAIN-LVT-FCB/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1271653156},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701039000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2300x1484',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1D6AC83350',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1D6AC83350:1676789260',
#     'indexTimestamp': 1572701059381,
#     'internalReceivedDate': 1572701059381,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1D6AC83350:1676789260/tag:reuters.com,2019:binary_RC1D6AC83350-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1036017,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1676789260},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572701027000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2532x1804',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1A23589230',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1A23589230:855072326',
#     'indexTimestamp': 1572701046953,
#     'internalReceivedDate': 1572701046953,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1A23589230:855072326/tag:reuters.com,2019:binary_RC1A23589230-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2083355,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 855072326},
#    {'author': 'By Greg Stutchbury',
#     'channelIds': [626,
#      159003,
#      662,
#      176417,
#      63697,
#      647,
#      154257,
#      49349,
#      63667,
#      599,
#      63685,
#      644,
#      182977,
#      63665,
#      158991,
#      63708,
#      68936,
#      635,
#      22370,
#      159015,
#      118201,
#      23278,
#      27574,
#      564],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572701001000,
#     'destination': ['PSC',
#      'LBY',
#      'DNP',
#      'J',
#      'PSP',
#      'RSP',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'SF',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['RU',
#      'UY',
#      'FJ',
#      'JP',
#      'ZA',
#      'IT',
#      'NZ',
#      'FR',
#      'AR',
#      'NA',
#      'AU',
#      'GB',
#      'TO',
#      'WS',
#      'IE',
#      'GE',
#      'CA',
#      'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27I01J',
#     'headline': 'Rugby-I almost quit a year ago, says Springbok coach Erasmus',
#     'id': 'tag:reuters.com,2019:newsml_L3N27I01J:1950391674',
#     'indexTimestamp': 1572701009150,
#     'internalReceivedDate': 1572701009150,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (TV, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1950391674},
#    {'author': 'EMMANUEL FOUDROT',
#     'channelIds': [106339,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700991000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '2634x1764',
#     'geography': ['FRA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1B95511D00',
#     'headline': 'ISU Grand Prix of Figure Skating - 2019 Internationaux de France',
#     'id': 'tag:reuters.com,2019:newsml_RC1B95511D00:169611920',
#     'indexTimestamp': 1572701009728,
#     'internalReceivedDate': 1572701009728,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1B95511D00:169611920/tag:reuters.com,2019:binary_RC1B95511D00-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1135871,
#     'slug': 'FIGURESKATING-ISU/',
#     'source': 'Thomson Reuters',
#     'version': 169611920},
#    {'author': 'CHRISTIAN MANG',
#     'channelIds': [175935,
#      86083,
#      175155,
#      175217,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      205403,
#      149225,
#      130019,
#      134801,
#      122999,
#      175215,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700926000,
#     'destination': ['RPA'],
#     'dimensions': '6720x4480',
#     'geography': ['DEU'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1EC3EE6670',
#     'headline': "People attend a pro-Kurdish demonstration against Turkey's military action in northeastern Syria, in Berlin",
#     'id': 'tag:reuters.com,2019:newsml_RC1EC3EE6670:429803171',
#     'indexTimestamp': 1572700946602,
#     'internalReceivedDate': 1572700946602,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1EC3EE6670:429803171/tag:reuters.com,2019:binary_RC1EC3EE6670-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 6445163,
#     'slug': 'SYRIA-SECURITY/GERMANY-KURDS',
#     'source': 'Thomson Reuters',
#     'version': 429803171},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700920000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '3812x2661',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1D7F8DF300',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1D7F8DF300:2066889820',
#     'indexTimestamp': 1572700940863,
#     'internalReceivedDate': 1572700940863,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1D7F8DF300:2066889820/tag:reuters.com,2019:binary_RC1D7F8DF300-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 3184878,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 2066889820},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700870000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2300x1611',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1BEE23E540',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1BEE23E540:324762246',
#     'indexTimestamp': 1572700887011,
#     'internalReceivedDate': 1572700887011,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1BEE23E540:324762246/tag:reuters.com,2019:binary_RC1BEE23E540-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1522310,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 324762246},
#    {'author': 'DYLAN MARTINEZ',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700835000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2256x1457',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1F18DB5CD0',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1F18DB5CD0:1526473755',
#     'indexTimestamp': 1572700853043,
#     'internalReceivedDate': 1572700853043,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1F18DB5CD0:1526473755/tag:reuters.com,2019:binary_RC1F18DB5CD0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 1187217,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1526473755},
#    {'author': 'SOE ZEYA TUN',
#     'channelIds': [86083,
#      175155,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      130019,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      82913,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700834000,
#     'destination': ['RPA'],
#     'dimensions': '5000x3333',
#     'geography': ['THA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1E327FF400',
#     'headline': 'ASEAN leaders pose with t-shirts at a signing ceremony of the Memorandum of Understanding between ASEAN and FIFA, in Bangkok',
#     'id': 'tag:reuters.com,2019:newsml_RC1E327FF400:423047412',
#     'indexTimestamp': 1572700852125,
#     'internalReceivedDate': 1572700852125,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1E327FF400:423047412/tag:reuters.com,2019:binary_RC1E327FF400-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 3978404,
#     'slug': 'ASEAN-SUMMIT/',
#     'source': 'Thomson Reuters',
#     'version': 423047412},
#    {'author': 'DYLAN MARTINEZ',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700812000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '3678x2234',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1CEED45CB0',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1CEED45CB0:1692651389',
#     'indexTimestamp': 1572700836694,
#     'internalReceivedDate': 1572700836694,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1CEED45CB0:1692651389/tag:reuters.com,2019:binary_RC1CEED45CB0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2957349,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1692651389},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700798000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '1854x1227',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1E69DCD490',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1E69DCD490:2133140924',
#     'indexTimestamp': 1572700815047,
#     'internalReceivedDate': 1572700815047,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1E69DCD490:2133140924/tag:reuters.com,2019:binary_RC1E69DCD490-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 782661,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 2133140924},
#    {'author': 'JAVIER BARBANCHO',
#     'channelIds': [106339,
#      86083,
#      82915,
#      175155,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700792000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '5184x3456',
#     'geography': ['ESP'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1C38BA6550',
#     'headline': 'La Liga Santander - Levante v FC Barcelona',
#     'id': 'tag:reuters.com,2019:newsml_RC1C38BA6550:2003954781',
#     'indexTimestamp': 1572700822791,
#     'internalReceivedDate': 1572700822791,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1C38BA6550:2003954781/tag:reuters.com,2019:binary_RC1C38BA6550-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 10767936,
#     'slug': 'SOCCER-SPAIN-LVT-FCB/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 2003954781},
#    {'author': 'JAVIER BARBANCHO',
#     'channelIds': [106339,
#      86083,
#      82915,
#      175155,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700791000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '5069x3351',
#     'geography': ['ESP'],
#     'guid': 'tag:reuters.com,2019:newsml_RC16B64B4390',
#     'headline': 'La Liga Santander - Levante v FC Barcelona',
#     'id': 'tag:reuters.com,2019:newsml_RC16B64B4390:970478706',
#     'indexTimestamp': 1572700815265,
#     'internalReceivedDate': 1572700815265,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC16B64B4390:970478706/tag:reuters.com,2019:binary_RC16B64B4390-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 8698231,
#     'slug': 'SOCCER-SPAIN-LVT-FCB/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 970478706},
#    {'author': 'ANDREW COULDRIDGE',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700787000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2531x1694',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1DDB7B98D0',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC1DDB7B98D0:610023912',
#     'indexTimestamp': 1572700806670,
#     'internalReceivedDate': 1572700806670,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1DDB7B98D0:610023912/tag:reuters.com,2019:binary_RC1DDB7B98D0-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2073972,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 610023912},
#    {'author': 'DYLAN MARTINEZ',
#     'channelIds': [106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      138917,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      73812,
#      77862,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700763000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2899x1878',
#     'geography': ['GBR'],
#     'guid': 'tag:reuters.com,2019:newsml_RC14A4630980',
#     'headline': 'Premier League - AFC Bournemouth v Manchester United',
#     'id': 'tag:reuters.com,2019:newsml_RC14A4630980:1010938484',
#     'indexTimestamp': 1572700779544,
#     'internalReceivedDate': 1572700779544,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC14A4630980:1010938484/tag:reuters.com,2019:binary_RC14A4630980-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2035562,
#     'slug': 'SOCCER-ENGLAND-BOU-MUN/REPORT',
#     'source': 'Thomson Reuters',
#     'version': 1010938484},
#    {'author': 'SOE ZEYA TUN',
#     'channelIds': [86083,
#      175155,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      130019,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      82913,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700762000,
#     'destination': ['RPA'],
#     'dimensions': '5000x3230',
#     'geography': ['THA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC176E9C6800',
#     'headline': 'Gianni Infantino, the current president of FIFA (not in picture), poses with ASEAN leaders at a signing ceremony of the Memorandum of Understanding between ASEAN and FIFA, in Bangkok',
#     'id': 'tag:reuters.com,2019:newsml_RC176E9C6800:1662227821',
#     'indexTimestamp': 1572700782092,
#     'internalReceivedDate': 1572700782092,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC176E9C6800:1662227821/tag:reuters.com,2019:binary_RC176E9C6800-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 4641162,
#     'slug': 'ASEAN-SUMMIT/',
#     'source': 'Thomson Reuters',
#     'version': 1662227821},
#    {'author': 'CHRISTIAN HARTMANN',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700757000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '4107x2681',
#     'geography': ['FRA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1C7E963410',
#     'headline': 'ATP 1000 - Paris Masters',
#     'id': 'tag:reuters.com,2019:newsml_RC1C7E963410:109094079',
#     'indexTimestamp': 1572700777376,
#     'internalReceivedDate': 1572700777376,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC1C7E963410:109094079/tag:reuters.com,2019:binary_RC1C7E963410-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 580660,
#     'slug': 'TENNIS-PARIS/',
#     'source': 'Thomson Reuters',
#     'version': 109094079},
#    {'author': 'CHRISTIAN HARTMANN',
#     'channelIds': [106339,
#      23532,
#      86083,
#      175155,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572700755000,
#     'destination': ['AISPTS', 'RPA'],
#     'dimensions': '3344x2224',
#     'geography': ['FRA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC1C1488E240',
#     'headline': 'ATP 1000 - Paris Masters',
#     'id': 'tag:reuters.com,2019:newsml_RC1C1488E240:587454630',
# ...
#     'dimensions': '4815x3133',
#     'geography': ['ZAF'],
#     'guid': 'tag:reuters.com,2019:newsml_RC12824BB700',
#     'headline': 'Rugby World Cup - Final - Fans watch England v South Africa in Cape Town',
#     'id': 'tag:reuters.com,2019:newsml_RC12824BB700:239317571',
#     'indexTimestamp': 1572695329730,
#     'internalReceivedDate': 1572695329730,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC12824BB700:239317571/tag:reuters.com,2019:binary_RC12824BB700-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 4040526,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/REACTIONS',
#     'source': 'Thomson Reuters',
#     'version': 239317571},
#    {'author': 'SOE ZEYA TUN',
#     'channelIds': [86083,
#      175155,
#      140103,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      204003,
#      191555,
#      130019,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      82913,
#      812,
#      130523,
#      125677,
#      215187,
#      198571],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572695301000,
#     'destination': ['RPA'],
#     'dimensions': '4510x2992',
#     'geography': ['THA'],
#     'guid': 'tag:reuters.com,2019:newsml_RC133DE66290',
#     'headline': 'Gianni Infantino, the current president of FIFA, attends a signing ceremony of the Memorandum of Understanding between ASEAN and FIFA',
#     'id': 'tag:reuters.com,2019:newsml_RC133DE66290:1820499710',
#     'indexTimestamp': 1572695319096,
#     'internalReceivedDate': 1572695319096,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_RC133DE66290:1820499710/tag:reuters.com,2019:binary_RC133DE66290-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture', 'prodId:PIX', 'source:ids', 'edStat:N'],
#     'size': 3363373,
#     'slug': 'ASEAN-SUMMIT/',
#     'source': 'Thomson Reuters',
#     'version': 1820499710},
#    {'author': 'PETER CZIBORRA',
#     'channelIds': [82918,
#      106339,
#      86083,
#      175155,
#      123473,
#      175143,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      195331,
#      215187,
#      191549,
#      175913],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572695295000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '4128x2675',
#     'geography': ['JPN'],
#     'guid': 'tag:reuters.com,2019:newsml_UP1EFB20WSFRH',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_UP1EFB20WSFRH:387116024',
#     'indexTimestamp': 1572695303412,
#     'internalReceivedDate': 1572695303412,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_UP1EFB20WSFRH:387116024/tag:reuters.com,2019:binary_UP1EFB20WSFRH-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 3504507,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/',
#     'source': 'Thomson Reuters',
#     'version': 387116024},
#    {'author': 'ISSEI KATO',
#     'channelIds': [82918,
#      106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572695278000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '4012x2571',
#     'geography': ['JPN'],
#     'guid': 'tag:reuters.com,2019:newsml_UP1EFB20WRYRG',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_UP1EFB20WRYRG:780358211',
#     'indexTimestamp': 1572695285795,
#     'internalReceivedDate': 1572695285795,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_UP1EFB20WRYRG:780358211/tag:reuters.com,2019:binary_UP1EFB20WRYRG-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 3282227,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/',
#     'source': 'Thomson Reuters',
#     'version': 780358211},
#    {'author': 'ISSEI KATO',
#     'channelIds': [82918,
#      106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572695266000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '3812x2529',
#     'geography': ['JPN'],
#     'guid': 'tag:reuters.com,2019:newsml_UP1EFB20WRMRF',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_UP1EFB20WRMRF:724689588',
#     'indexTimestamp': 1572695274908,
#     'internalReceivedDate': 1572695274908,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_UP1EFB20WRMRF:724689588/tag:reuters.com,2019:binary_UP1EFB20WRMRF-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 3143990,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/',
#     'source': 'Thomson Reuters',
#     'version': 724689588},
#    {'author': 'PETER CZIBORRA',
#     'channelIds': [82918,
#      106339,
#      86083,
#      175155,
#      123473,
#      61055,
#      136867,
#      216649,
#      204337,
#      823,
#      198575,
#      136717,
#      125675,
#      149225,
#      191555,
#      134801,
#      192815,
#      199319,
#      122999,
#      176033,
#      812,
#      130523,
#      125677,
#      215187,
#      191549],
#     'channels': ['pwu404'],
#     'contributorId': 'RTRS',
#     'contributorName': 'REUTERS',
#     'dateCreated': 1572695266000,
#     'destination': ['AISPTS', 'RPA', 'ACI'],
#     'dimensions': '2948x2085',
#     'geography': ['JPN'],
#     'guid': 'tag:reuters.com,2019:newsml_UP1EFB20WRMRE',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_UP1EFB20WRMRE:19487899',
#     'indexTimestamp': 1572695273186,
#     'internalReceivedDate': 1572695273186,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_UP1EFB20WRMRE:19487899/tag:reuters.com,2019:binary_UP1EFB20WRMRE-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'prodId:PIX',
#      'source:ids',
#      'sic:hasParent',
#      'edStat:N'],
#     'size': 2006215,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/',
#     'source': 'Thomson Reuters',
#     'version': 19487899},
#    {'author': 'ISSEI KATO',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x554',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1086',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1086:1',
#     'indexTimestamp': 1572695254977,
#     'internalReceivedDate': 1572695254977,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1086:1/tag:reuters.com,2019:binary_LYNXMPEFA1086-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 160860,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'ISSEI KATO',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x464',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1085',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1085:1',
#     'indexTimestamp': 1572695256479,
#     'internalReceivedDate': 1572695256479,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1085:1/tag:reuters.com,2019:binary_LYNXMPEFA1085-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 114632,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'PETER CZIBORRA',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x553',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1084',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1084:1',
#     'indexTimestamp': 1572695253588,
#     'internalReceivedDate': 1572695253588,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1084:1/tag:reuters.com,2019:binary_LYNXMPEFA1084-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 97044,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'PETER CZIBORRA',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x516',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1083',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1083:1',
#     'indexTimestamp': 1572695255185,
#     'internalReceivedDate': 1572695255185,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1083:1/tag:reuters.com,2019:binary_LYNXMPEFA1083-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 84049,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'ISSEI KATO',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x500',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1082',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1082:1',
#     'indexTimestamp': 1572695255595,
#     'internalReceivedDate': 1572695255595,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1082:1/tag:reuters.com,2019:binary_LYNXMPEFA1082-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 156878,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'EDGAR SU',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x518',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1081',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1081:1',
#     'indexTimestamp': 1572695255932,
#     'internalReceivedDate': 1572695255932,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1081:1/tag:reuters.com,2019:binary_LYNXMPEFA1081-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 67580,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'ISSEI KATO',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x554',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA1080',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA1080:1',
#     'indexTimestamp': 1572695254345,
#     'internalReceivedDate': 1572695254345,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA1080:1/tag:reuters.com,2019:binary_LYNXMPEFA1080-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 79848,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1},
#    {'author': 'PETER CZIBORRA',
#     'channelIds': [23271, 73352, 61422, 73353, 153071, 25411, 24242, 24240],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695248000,
#     'destination': ['ORTAK', 'OUKTPM', 'OUKSPM'],
#     'dimensions': '800x531',
#     'geography': ['JPN', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_LYNXMPEFA107Z',
#     'headline': 'Rugby World Cup - Final - England v South Africa',
#     'id': 'tag:reuters.com,2019:newsml_LYNXMPEFA107Z:1',
#     'indexTimestamp': 1572695254095,
#     'internalReceivedDate': 1572695254095,
#     'language': 'en',
#     'mediaType': 'P',
#     'previewUrl': 'http://content.reuters.com/auth-server/content/tag:reuters.com,2019:newsml_LYNXMPEFA107Z:1/tag:reuters.com,2019:binary_LYNXMPEFA107Z-VIEWIMAGE',
#     'priority': 4,
#     'signal': ['pmt:picture',
#      'var:binMod',
#      'prodId:PIX',
#      'source:ids',
#      'edStat:N'],
#     'size': 106803,
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF',
#     'source': 'Thomson Reuters',
#     'version': 1}],
#   'size': 300,
#   'start': 0,
#   'status': {'code': 10}}}

# %% [markdown]
# In the next query, we are looking for the keyword *trafficking* in the main text.
#
# (*main*: used to specify the keywords that may be contained within one or more of the following fields of the news items that are retrieved: body, headline, caption, id, topic, signal and slug.)
#
# **Note**: If a *daterange* is not specified, then the results are for the last 24h.

# %%
search_query = 'main:trafficking'
url = 'http://rmb.reuters.com/rmd/rest/json/search?q=' + search_query + '&mediaType=T&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'results': {'mediaTypeBreakdownPercent': {'C': 0,
#    'G': 0,
#    'P': 0,
#    'T': 100,
#    'V': 0},
#   'numFound': 10,
#   'result': [{'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      161681,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      164607,
#      150029,
#      76633,
#      63685,
#      31396,
#      644,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572659257000,
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'ZD',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'geography': ['VN', 'BE', 'GB', 'CN', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27I00W',
#     'headline': 'Vietnam says human traffickers must be strictly dealt with',
#     'id': 'tag:reuters.com,2019:newsml_L3N27I00W:391219080',
#     'indexTimestamp': 1572659267216,
#     'internalReceivedDate': 1572659267216,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BRITAIN-BODIES/VIETNAM',
#     'source': 'Thomson Reuters',
#     'version': 391219080},
#    {'channelIds': [37917,
#      176417,
#      75332,
#      159011,
#      63446,
#      644,
#      211865,
#      142441,
#      159015,
#      41078,
#      118201,
#      2213],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572652457000,
#     'destination': ['CSA',
#      'UCDPTEST',
#      'LBY',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H278',
#     'headline': 'Reuters World News Summary',
#     'id': 'tag:reuters.com,2019:newsml_L2N27H278:286682283',
#     'indexTimestamp': 1572652460109,
#     'internalReceivedDate': 1572652460109,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BC-WORLD',
#     'source': 'Thomson Reuters',
#     'version': 286682283},
#    {'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      31386,
#      63692,
#      22321,
#      154815,
#      31371,
#      75332,
#      651,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      31376,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      31374,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572646886000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['BR', 'BD', 'MX', 'AF', 'IN', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H5Q0',
#     'headline': "Brazil police arrest man said to be one of world's most prolific human traffickers",
#     'id': 'tag:reuters.com,2019:newsml_L8N27H5Q0:447177668',
#     'indexTimestamp': 1572646890383,
#     'internalReceivedDate': 1572646890383,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BRAZIL-HUMAN TRAFFICKING/ (TV)',
#     'source': 'Thomson Reuters',
#     'version': 447177668},
#    {'author': 'By Daina Beth Solomon',
#     'channelIds': [176647,
#      176649,
#      56668,
#      150629,
#      65819,
#      134469,
#      65820,
#      24218,
#      24217,
#      25532,
#      133467,
#      133263],
#     'channels': ['FES376'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640833000,
#     'destination': ['OUSWDM', 'OCATPM', 'RTRFLN', 'OUSTPM', 'OUS12'],
#     'geography': ['IND', 'US', 'MX'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB51S',
#     'headline': "Mexico says U.S. fentanyl crackdown led to botched arrest of El Chapo's son",
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB51S:3',
#     'indexTimestamp': 1572640837028,
#     'internalReceivedDate': 1572640837028,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'US-MEXICO-DRUGS',
#     'source': 'Thomson Reuters',
#     'version': 3},
#    {'author': 'By Amanda Ferguson',
#     'channelIds': [23276,
#      83733,
#      22849,
#      25437,
#      176625,
#      23274,
#      149055,
#      176631,
#      24244,
#      153071,
#      176461,
#      25411,
#      24237,
#      24242,
#      176629],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640591000,
#     'destination': ['NOINSKM',
#      'OUKDNM',
#      'NOINWDM',
#      'ORTAK',
#      'OUKWDM',
#      'OUKTPM',
#      'ORTOA'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB3XS',
#     'headline': 'Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB3XS:6',
#     'indexTimestamp': 1572640594477,
#     'internalReceivedDate': 1572640594477,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'UK-BRITAIN-BODIES',
#     'source': 'Thomson Reuters',
#     'version': 6},
#    {'author': 'By Amanda Ferguson',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      154815,
#      63699,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      22802,
#      63685,
#      31396,
#      644,
#      211865,
#      158991,
#      142441,
#      63708,
#      648,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      118201,
#      31397,
#      22307,
#      2213,
#      127689,
#      170645,
#      176419,
#      634,
#      31377,
#      68945,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640534000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'RNP',
#      'RWSA',
#      'SI',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H2WN',
#     'headline': 'UPDATE 3-Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H2WN:1498332260',
#     'indexTimestamp': 1572640540811,
#     'internalReceivedDate': 1572640540811,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U',
#      'sic:XBSUM'],
#     'slug': 'BRITAIN-BODIES/ (UPDATE 3, PIX, TV)',
#     'source': 'Thomson Reuters',
#     'version': 1498332260},
#    {'author': 'By Daina Beth Solomon',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      154815,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      199799,
#      150029,
#      63685,
#      644,
#      211865,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      31374,
#      118201,
#      2213,
#      210815,
#      127689,
#      176419,
#      634,
#      191903,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640468000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['US', 'MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H0Y7',
#     'headline': "Mexico says U.S. fentanyl crackdown led to botched arrest of El Chapo's son",
#     'id': 'tag:reuters.com,2019:newsml_L2N27H0Y7:748611583',
#     'indexTimestamp': 1572640471975,
#     'internalReceivedDate': 1572640471975,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO-DRUGS/',
#     'source': 'Thomson Reuters',
#     'version': 748611583},
#    {'author': 'By John Bartlett, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      66631,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572637626000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'TRFDN',
#      'RWSA',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'geography': ['CL', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H58U',
#     'headline': 'ANALYSIS-Chile urged not to lose environmental steam after cancelling UN talks',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H58U:681342346',
#     'indexTimestamp': 1572637630304,
#     'internalReceivedDate': 1572637630304,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CLIMATE-CHANGE/CHILE-ENVIRONMENT (ANALYSIS)',
#     'source': 'Thomson Reuters',
#     'version': 681342346},
#    {'author': 'By Oscar Lopez, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      208945,
#      23929,
#      27253,
#      22170,
#      211145,
#      22791,
#      75332,
#      23754,
#      26783,
#      159011,
#      583,
#      63667,
#      66918,
#      539,
#      150029,
#      204119,
#      63685,
#      644,
#      621,
#      182977,
#      211865,
#      142441,
#      610,
#      635,
#      22283,
#      27213,
#      159015,
#      180033,
#      41078,
#      31374,
#      118201,
#      162059,
#      2213,
#      634,
#      34327,
#      66631,
#      63655,
#      70595,
#      30480,
#      63709],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572631454000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'ABN',
#      'GNS',
#      'PGE',
#      'O',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'OIL',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G04W',
#     'headline': 'FEATURE-Amid climate worries, Mexico doubles down on fossil fuels',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G04W:1681907105',
#     'indexTimestamp': 1572631458388,
#     'internalReceivedDate': 1572631458388,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO-CLIMATE-CHANGE/OIL (FEATURE)',
#     'source': 'Thomson Reuters',
#     'version': 1681907105},
#    {'channelIds': [37917,
#      626,
#      176417,
#      34325,
#      63398,
#      63411,
#      57606,
#      63393,
#      63438,
#      63424,
#      583,
#      539,
#      584,
#      63447,
#      63446,
#      644,
#      211865,
#      20483,
#      142441,
#      672,
#      610,
#      63436,
#      561,
#      661,
#      565,
#      63462,
#      601,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      63430,
#      34327,
#      62871,
#      127687,
#      142045,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572615643000,
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'U',
#      'Z',
#      'REULB',
#      'RBN',
#      'LBY',
#      'ZD',
#      'SOF',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'REUEB',
#      'AFA'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2',
#     'headline': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFICKING OFFENCES  IN RELATION TO 39 DEATHS IN UK TRUCK -  POLICE',
#     'id': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1099731627',
#     'indexTimestamp': 1572615647562,
#     'internalReceivedDate': 1572615647562,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 1,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:N'],
#     'slug': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFI',
#     'source': 'Thomson Reuters',
#     'version': 1099731627}],
#   'size': 10,
#   'start': 0,
#   'status': {'code': 10}}}

# %% [markdown]
# The query below is looking for the keyword *foundation* in the fulltext.
#
# (*fulltext*: used to specify the keywords that may be contained within one or more of the following fields of the news items that are retrieved: body, headline, caption.)

# %%
search_query = 'fulltext:foundation'
url = 'http://rmb.reuters.com/rmd/rest/json/search?q=' + search_query + '&mediaType=T&token=' + authToken + '&format=json'
response = requests.get(url)
json.loads(response.text)
# Out:
# {'results': {'mediaTypeBreakdownPercent': {'C': 0,
#    'G': 0,
#    'P': 0,
#    'T': 100,
#    'V': 0},
#   'numFound': 11,
#   'result': [{'author': 'By Nick Mulvenney',
#     'channelIds': [542,
#      37917,
#      626,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      63697,
#      647,
#      70666,
#      29598,
#      63633,
#      159011,
#      49349,
#      583,
#      63667,
#      599,
#      63685,
#      644,
#      182977,
#      63665,
#      158991,
#      142441,
#      63708,
#      68936,
#      635,
#      22370,
#      23742,
#      159015,
#      41078,
#      118201,
#      23278,
#      2213,
#      27574,
#      564,
#      63655],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572695906000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'J',
#      'PSP',
#      'GNS',
#      'RSP',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'SF',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['AR', 'GB', 'JP', 'ZA'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27H138',
#     'headline': 'UPDATE 3-Rugby-Powerpacked South Africa dominate ragged England to win third World Cup',
#     'id': 'tag:reuters.com,2019:newsml_L3N27H138:1947111597',
#     'indexTimestamp': 1572695910376,
#     'internalReceivedDate': 1572695910376,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:U'],
#     'slug': 'RUGBY-UNION-WORLDCUP-ENG-ZAF/ (UPDATE 3, PIX, TV)',
#     'source': 'Thomson Reuters',
#     'version': 1947111597},
#    {'author': 'By Valerie  Volcovici and Jessica Jones',
#     'channelIds': [176577,
#      176647,
#      176649,
#      56668,
#      65819,
#      72733,
#      134469,
#      25424,
#      65820,
#      24218,
#      72735,
#      24217,
#      72736,
#      72737,
#      25532,
#      72734,
#      133263,
#      72738,
#      72739,
#      179497],
#     'channels': ['FES376'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572647971000,
#     'destination': ['OUSWDM', 'RTRFLN', 'OUSTPM', 'OUS12', 'ORTAGM', 'OUSESG'],
#     'geography': ['CL', 'IND', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB4HT',
#     'headline': 'Spain to host U.N. climate talks in December after Chile cancels',
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB4HT:7',
#     'indexTimestamp': 1572647973950,
#     'internalReceivedDate': 1572647973950,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'US-CLIMATE-CHANGE-ACCORD',
#     'source': 'Thomson Reuters',
#     'version': 7},
#    {'author': 'By Joseph Ax and Amanda Becker',
#     'channelIds': [28253,
#      63683,
#      37917,
#      144993,
#      626,
#      154817,
#      159003,
#      176417,
#      63692,
#      22321,
#      34325,
#      47570,
#      63693,
#      44243,
#      57606,
#      55072,
#      154815,
#      180027,
#      63675,
#      75332,
#      23754,
#      159011,
#      574,
#      583,
#      63667,
#      164607,
#      63672,
#      150029,
#      204119,
#      58139,
#      63685,
#      644,
#      182977,
#      26785,
#      76630,
#      63646,
#      27214,
#      27199,
#      44352,
#      211865,
#      55283,
#      180029,
#      20483,
#      142441,
#      610,
#      635,
#      62870,
#      22283,
#      159015,
#      176425,
#      180025,
#      180033,
#      27215,
#      180023,
#      561,
#      41078,
#      661,
#      565,
#      601,
#      118201,
#      139745,
#      63669,
#      2213,
#      127689,
#      170645,
#      70937,
#      55077,
#      176419,
#      634,
#      26784,
#      47543,
#      34327,
#      46844,
#      191903,
#      127687,
#      180031,
#      63655,
#      70595,
#      58686,
#      63709,
#      47569,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572646116000,
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'RHELIN',
#      'G',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'REULB',
#      'FUN',
#      'RBN',
#      'PSC',
#      'LBY',
#      'REUFF',
#      'ZD',
#      'SOF',
#      'RHIND',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H0E2',
#     'headline': "UPDATE 6-Democrat Warren: Medicare for All would not raise U.S. middle-class taxes 'one penny'",
#     'id': 'tag:reuters.com,2019:newsml_L2N27H0E2:1212466706',
#     'indexTimestamp': 1572646125884,
#     'internalReceivedDate': 1572646125884,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:U'],
#     'slug': 'USA-ELECTION/WARREN-MEDICARE (UPDATE 6, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1212466706},
#    {'author': 'By Jason Lange and Amanda Becker',
#     'channelIds': [176647,
#      56668,
#      65819,
#      176571,
#      24206,
#      72723,
#      65811,
#      176643,
#      72724,
#      72722,
#      65815,
#      24217,
#      25532,
#      24208,
#      24212,
#      65810,
#      72719,
#      176637,
#      72721,
#      72725,
#      72717],
#     'channels': ['FES376'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572645806000,
#     'destination': ['OUSHEM', 'OUSPOM', 'RTRFLN', 'OUSDNM', 'OUSTPM', 'OUS12'],
#     'geography': ['IND', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB52O',
#     'headline': "Warren's big healthcare plan relies on big assumptions",
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB52O:3',
#     'indexTimestamp': 1572645809364,
#     'internalReceivedDate': 1572645809364,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'US-USA-ELECTION-WARREN-FEASIBILITY-ANALYSIS',
#     'source': 'Thomson Reuters',
#     'version': 3},
#    {'author': 'By Valerie  Volcovici and Jessica Jones',
#     'channelIds': [23276,
#      83733,
#      22849,
#      25437,
#      23274,
#      176631,
#      24244,
#      153071,
#      176461,
#      25411,
#      24242,
#      176629],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572643890000,
#     'destination': ['OUKWDM', 'NOINWDM', 'ORTAK', 'OUKTPM', 'ORTOA'],
#     'geography': ['CL', 'IND', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB4HV',
#     'headline': 'Spain to host U.N. climate talks in December after Chile cancels',
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB4HV:5',
#     'indexTimestamp': 1572643893407,
#     'internalReceivedDate': 1572643893407,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'UK-CLIMATE-CHANGE-ACCORD',
#     'source': 'Thomson Reuters',
#     'version': 5},
#    {'author': 'By Valerie  Volcovici and Jessica Jones',
#     'channelIds': [76637,
#      63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      34325,
#      63693,
#      57606,
#      154815,
#      180027,
#      63675,
#      211145,
#      22791,
#      75332,
#      159011,
#      583,
#      63667,
#      63672,
#      150029,
#      549,
#      204119,
#      63685,
#      644,
#      182977,
#      540,
#      63646,
#      27199,
#      44352,
#      211865,
#      180029,
#      142441,
#      610,
#      635,
#      62870,
#      22283,
#      159015,
#      176425,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      661,
#      565,
#      601,
#      118201,
#      162059,
#      63669,
#      2213,
#      634,
#      31372,
#      34327,
#      127687,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572643784000,
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'M',
#      'BNX',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'ABX',
#      'REULB',
#      'FUN',
#      'RBN',
#      'PSC',
#      'LBY',
#      'ZD',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'geography': ['CL', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H4OQ',
#     'headline': 'UPDATE 4-Spain to host UN climate talks in December after Chile cancels',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H4OQ:1268584110',
#     'indexTimestamp': 1572643788593,
#     'internalReceivedDate': 1572643788593,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:U'],
#     'slug': 'CLIMATE-CHANGE/ACCORD (UPDATE 4)',
#     'source': 'Thomson Reuters',
#     'version': 1268584110},
#    {'author': 'By Jason Lange and Amanda Becker',
#     'channelIds': [63683,
#      37917,
#      626,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      44243,
#      57606,
#      75332,
#      583,
#      539,
#      63685,
#      644,
#      63646,
#      211865,
#      20483,
#      142441,
#      22283,
#      180023,
#      561,
#      41078,
#      565,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      127687,
#      180031,
#      63655,
#      70595,
#      58686],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572641704000,
#     'destination': ['PSC',
#      'LBY',
#      'D',
#      'E',
#      'G',
#      'ABN',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H0UV',
#     'headline': "ANALYSIS-Warren's big healthcare plan relies on big assumptions",
#     'id': 'tag:reuters.com,2019:newsml_L2N27H0UV:1286991081',
#     'indexTimestamp': 1572641707606,
#     'internalReceivedDate': 1572641707606,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'USA-ELECTION/WARREN-FEASIBILITY (ANALYSIS, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1286991081},
#    {'author': 'By John Bartlett, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      66631,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572637626000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'TRFDN',
#      'RWSA',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'geography': ['CL', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H58U',
#     'headline': 'ANALYSIS-Chile urged not to lose environmental steam after cancelling UN talks',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H58U:681342346',
#     'indexTimestamp': 1572637630304,
#     'internalReceivedDate': 1572637630304,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CLIMATE-CHANGE/CHILE-ENVIRONMENT (ANALYSIS)',
#     'source': 'Thomson Reuters',
#     'version': 681342346},
#    {'channelIds': [22830,
#      176623,
#      25437,
#      24236,
#      176451,
#      153071,
#      25411,
#      24242,
#      22844,
#      176629],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572632894000,
#     'destination': ['OUKBSM',
#      'NOINBSM',
#      'NOINEBM',
#      'ORTAK',
#      'OUKTPM',
#      'ORTOA'],
#     'geography': ['IND', 'US', 'CN'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB4U4',
#     'headline': 'U.S. disappointed by WTO decision allowing China to slap trade sanctions on U.S. goods',
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB4U4:2',
#     'indexTimestamp': 1572632896441,
#     'internalReceivedDate': 1572632896441,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'UK-CHINA-TRADE-USA-REACTION',
#     'source': 'Thomson Reuters',
#     'version': 2},
#    {'author': 'By Oscar Lopez, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      208945,
#      23929,
#      27253,
#      22170,
#      211145,
#      22791,
#      75332,
#      23754,
#      26783,
#      159011,
#      583,
#      63667,
#      66918,
#      539,
#      150029,
#      204119,
#      63685,
#      644,
#      621,
#      182977,
#      211865,
#      142441,
#      610,
#      635,
#      22283,
#      27213,
#      159015,
#      180033,
#      41078,
#      31374,
#      118201,
#      162059,
#      2213,
#      634,
#      34327,
#      66631,
#      63655,
#      70595,
#      30480,
#      63709],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572631454000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'ABN',
#      'GNS',
#      'PGE',
#      'O',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'OIL',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G04W',
#     'headline': 'FEATURE-Amid climate worries, Mexico doubles down on fossil fuels',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G04W:1681907105',
#     'indexTimestamp': 1572631458388,
#     'internalReceivedDate': 1572631458388,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO-CLIMATE-CHANGE/OIL (FEATURE)',
#     'source': 'Thomson Reuters',
#     'version': 1681907105},
#    {'author': 'By Sophie Davies, Thomson Reuters Foundation',
#     'channelIds': [159335,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      22800,
#      55889,
#      154815,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      66631,
#      191903,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572617873000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H435',
#     'headline': 'Anger erupts in Spain as five men acquitted of gang-raping teenager',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H435:1967061469',
#     'indexTimestamp': 1572617876481,
#     'internalReceivedDate': 1572617876481,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'SPAIN-COURT/SEXCRIMES',
#     'source': 'Thomson Reuters',
#     'version': 1967061469}],
#   'size': 11,
#   'start': 0,
#   'status': {'code': 10}}}

# %% [markdown]
# We could also consider creating queries that find content created by the Thomson Reuters Foundation (e.g. 'contributorName': 'Thomson Reuters Foundation', 'contributorId': 'TRFN')

# %% [markdown]
# The below query returns all results within a given date range that include keywords: *slavery* or *trafficking*
#
# **Note**: The keyword trafficking might be related to other topics as well (drugs, etc.). Therefore, think about the search terms.

# %%
search_query = 'fullText:(slavery OR trafficking)'
current_date = datetime.today().strftime('%Y.%m.%d')
past_date = '2019.10.02' # This date needs to be changed as the API can get only articles in the past 30 days.
url_parts = [
    'http://rmb.reuters.com/rmd/rest/json/search?q=',
    search_query,
    '&mediaType=T&token=',
    authToken,
    '&format=json',
    '&dateRange=',
    past_date,
    '-',
    current_date]

url = ''.join(url_parts)
response = requests.get(url)
json.loads(response.text)
# Out:
# {'results': {'mediaTypeBreakdownPercent': {'C': 0,
#    'G': 0,
#    'P': 0,
#    'T': 100,
#    'V': 0},
#   'numFound': 426,
#   'result': [{'channelIds': [37917,
#      176417,
#      75332,
#      159011,
#      63446,
#      644,
#      211865,
#      142441,
#      159015,
#      41078,
#      118201,
#      2213],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572652457000,
#     'destination': ['CSA',
#      'UCDPTEST',
#      'LBY',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H278',
#     'headline': 'Reuters World News Summary',
#     'id': 'tag:reuters.com,2019:newsml_L2N27H278:286682283',
#     'indexTimestamp': 1572652460109,
#     'internalReceivedDate': 1572652460109,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BC-WORLD',
#     'source': 'Thomson Reuters',
#     'version': 286682283},
#    {'channelIds': [63683,
#      37917,
#      626,
#      176417,
#      63692,
#      22331,
#      22321,
#      131355,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      20483,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      210815,
#      127689,
#      176419,
#      634,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572647654000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'RWSA',
#      'RAST',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H21B',
#     'headline': 'FACTBOX-Four Republicans, 17 Democrats vie for U.S. presidential nominations',
#     'id': 'tag:reuters.com,2019:newsml_L2N27H21B:322005150',
#     'indexTimestamp': 1572647662371,
#     'internalReceivedDate': 1572647662371,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'USA-ELECTION/2020-CANDIDATES (UPDATE 1, FACTBOX, GRAPHIC)',
#     'source': 'Thomson Reuters',
#     'version': 322005150},
#    {'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      31386,
#      63692,
#      22321,
#      154815,
#      31371,
#      75332,
#      651,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      31376,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      31374,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572646886000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['BR', 'BD', 'MX', 'AF', 'IN', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H5Q0',
#     'headline': "Brazil police arrest man said to be one of world's most prolific human traffickers",
#     'id': 'tag:reuters.com,2019:newsml_L8N27H5Q0:447177668',
#     'indexTimestamp': 1572646890383,
#     'internalReceivedDate': 1572646890383,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BRAZIL-HUMAN TRAFFICKING/ (TV)',
#     'source': 'Thomson Reuters',
#     'version': 447177668},
#    {'author': 'By Daina Beth Solomon',
#     'channelIds': [176647,
#      176649,
#      56668,
#      150629,
#      65819,
#      134469,
#      65820,
#      24218,
#      24217,
#      25532,
#      133467,
#      133263],
#     'channels': ['FES376'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640833000,
#     'destination': ['OUSWDM', 'OCATPM', 'RTRFLN', 'OUSTPM', 'OUS12'],
#     'geography': ['IND', 'US', 'MX'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB51S',
#     'headline': "Mexico says U.S. fentanyl crackdown led to botched arrest of El Chapo's son",
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB51S:3',
#     'indexTimestamp': 1572640837028,
#     'internalReceivedDate': 1572640837028,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'US-MEXICO-DRUGS',
#     'source': 'Thomson Reuters',
#     'version': 3},
#    {'author': 'By Amanda Ferguson',
#     'channelIds': [23276,
#      83733,
#      22849,
#      25437,
#      176625,
#      23274,
#      149055,
#      176631,
#      24244,
#      153071,
#      176461,
#      25411,
#      24237,
#      24242,
#      176629],
#     'channels': ['TRn222'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640591000,
#     'destination': ['NOINSKM',
#      'OUKDNM',
#      'NOINWDM',
#      'ORTAK',
#      'OUKWDM',
#      'OUKTPM',
#      'ORTOA'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG', 'IND'],
#     'guid': 'tag:reuters.com,2019:newsml_KBN1XB3XS',
#     'headline': 'Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'id': 'tag:reuters.com,2019:newsml_KBN1XB3XS:6',
#     'indexTimestamp': 1572640594477,
#     'internalReceivedDate': 1572640594477,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'UK-BRITAIN-BODIES',
#     'source': 'Thomson Reuters',
#     'version': 6},
#    {'author': 'By Amanda Ferguson',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      154815,
#      63699,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      22802,
#      63685,
#      31396,
#      644,
#      211865,
#      158991,
#      142441,
#      63708,
#      648,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      118201,
#      31397,
#      22307,
#      2213,
#      127689,
#      170645,
#      176419,
#      634,
#      31377,
#      68945,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640534000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'RNP',
#      'RWSA',
#      'SI',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H2WN',
#     'headline': 'UPDATE 3-Second man charged over UK truck deaths, victims now thought to be Vietnamese',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H2WN:1498332260',
#     'indexTimestamp': 1572640540811,
#     'internalReceivedDate': 1572640540811,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U',
#      'sic:XBSUM'],
#     'slug': 'BRITAIN-BODIES/ (UPDATE 3, PIX, TV)',
#     'source': 'Thomson Reuters',
#     'version': 1498332260},
#    {'author': 'By Daina Beth Solomon',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      154815,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      199799,
#      150029,
#      63685,
#      644,
#      211865,
#      20483,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      23926,
#      31374,
#      118201,
#      2213,
#      210815,
#      127689,
#      176419,
#      634,
#      191903,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572640468000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['US', 'MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H0Y7',
#     'headline': "Mexico says U.S. fentanyl crackdown led to botched arrest of El Chapo's son",
#     'id': 'tag:reuters.com,2019:newsml_L2N27H0Y7:748611583',
#     'indexTimestamp': 1572640471975,
#     'internalReceivedDate': 1572640471975,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO-DRUGS/',
#     'source': 'Thomson Reuters',
#     'version': 748611583},
#    {'author': 'By John Bartlett, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      66631,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572637626000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'TRFDN',
#      'RWSA',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'geography': ['CL', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H58U',
#     'headline': 'ANALYSIS-Chile urged not to lose environmental steam after cancelling UN talks',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H58U:681342346',
#     'indexTimestamp': 1572637630304,
#     'internalReceivedDate': 1572637630304,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CLIMATE-CHANGE/CHILE-ENVIRONMENT (ANALYSIS)',
#     'source': 'Thomson Reuters',
#     'version': 681342346},
#    {'author': 'By Oscar Lopez, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      208945,
#      23929,
#      27253,
#      22170,
#      211145,
#      22791,
#      75332,
#      23754,
#      26783,
#      159011,
#      583,
#      63667,
#      66918,
#      539,
#      150029,
#      204119,
#      63685,
#      644,
#      621,
#      182977,
#      211865,
#      142441,
#      610,
#      635,
#      22283,
#      27213,
#      159015,
#      180033,
#      41078,
#      31374,
#      118201,
#      162059,
#      2213,
#      634,
#      34327,
#      66631,
#      63655,
#      70595,
#      30480,
#      63709],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572631454000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'ABN',
#      'GNS',
#      'PGE',
#      'O',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'OIL',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G04W',
#     'headline': 'FEATURE-Amid climate worries, Mexico doubles down on fossil fuels',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G04W:1681907105',
#     'indexTimestamp': 1572631458388,
#     'internalReceivedDate': 1572631458388,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO-CLIMATE-CHANGE/OIL (FEATURE)',
#     'source': 'Thomson Reuters',
#     'version': 1681907105},
#    {'channelIds': [37917,
#      626,
#      176417,
#      34325,
#      63398,
#      63411,
#      57606,
#      63393,
#      63438,
#      63424,
#      583,
#      539,
#      584,
#      63447,
#      63446,
#      644,
#      211865,
#      20483,
#      142441,
#      672,
#      610,
#      63436,
#      561,
#      661,
#      565,
#      63462,
#      601,
#      118201,
#      2213,
#      127689,
#      176419,
#      634,
#      63430,
#      34327,
#      62871,
#      127687,
#      142045,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572615643000,
#     'destination': ['ZZ',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'U',
#      'Z',
#      'REULB',
#      'RBN',
#      'LBY',
#      'ZD',
#      'SOF',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'REUEB',
#      'AFA'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2',
#     'headline': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFICKING OFFENCES  IN RELATION TO 39 DEATHS IN UK TRUCK -  POLICE',
#     'id': 'tag:reuters.com,2019:newsml_MT1ALTL9N26H01T2:1099731627',
#     'indexTimestamp': 1572615647562,
#     'internalReceivedDate': 1572615647562,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 1,
#     'signal': ['var:itemMod',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:N'],
#     'slug': 'NORTHERN IRISH MAN IS CHARGED WITH MANSLAUGHTER AND HUMAN TRAFFI',
#     'source': 'Thomson Reuters',
#     'version': 1099731627},
#    {'channelIds': [37917,
#      176417,
#      159011,
#      63446,
#      644,
#      211865,
#      142441,
#      159015,
#      41078,
#      118201,
#      2213],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572613091000,
#     'destination': ['CSA',
#      'UCDPTEST',
#      'LBY',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27H0FD',
#     'headline': 'Reuters Entertainment News Summary',
#     'id': 'tag:reuters.com,2019:newsml_L2N27H0FD:1478540772',
#     'indexTimestamp': 1572613093408,
#     'internalReceivedDate': 1572613093408,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BC-LEISURE',
#     'source': 'Thomson Reuters',
#     'version': 1478540772},
#    {'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      161681,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      164607,
#      150029,
#      76633,
#      63685,
#      31396,
#      644,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572612751000,
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'AFA'],
#     'geography': ['VN', 'BE', 'GB', 'CN', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27E1H0',
#     'headline': 'Vietnam arrests two people, questioning others over UK truck deaths -statement',
#     'id': 'tag:reuters.com,2019:newsml_L3N27E1H0:518279271',
#     'indexTimestamp': 1572612756740,
#     'internalReceivedDate': 1572612756740,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 2,
#     'signal': ['sig:update',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'BRITAIN-BODIES/VIETNAM (URGENT)',
#     'source': 'Thomson Reuters',
#     'version': 518279271},
#    {'author': 'By Rosa Furneaux, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      626,
#      63692,
#      22321,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      634,
#      66631,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572610953000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G83A',
#     'headline': 'INTERVIEW-Failure to tackle worker abuse breeds modern slavery, U.N. expert warns',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G83A:1933360962',
#     'indexTimestamp': 1572610956024,
#     'internalReceivedDate': 1572610956024,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'UN-TRAFFICKING/WORKERS (INTERVIEW)',
#     'source': 'Thomson Reuters',
#     'version': 1933360962},
#    {'author': 'By Charles Pensulo, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      55889,
#      154815,
#      23929,
#      70666,
#      211145,
#      22791,
#      75332,
#      29598,
#      63633,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      118201,
#      2213,
#      634,
#      66631,
#      191903,
#      564,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572607152000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MW'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27H262',
#     'headline': 'Malawi court suspends wearing of wigs and gowns as temperatures soar',
#     'id': 'tag:reuters.com,2019:newsml_L8N27H262:1711023433',
#     'indexTimestamp': 1572607155178,
#     'internalReceivedDate': 1572607155178,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MALAWI-CLIMATE-CHANGE/COURT',
#     'source': 'Thomson Reuters',
#     'version': 1711023433},
#    {'channelIds': [76637,
#      63683,
#      37917,
#      26786,
#      619,
#      144993,
#      626,
#      68932,
#      159003,
#      662,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      623,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      46622,
#      605,
#      159011,
#      583,
#      63667,
#      539,
#      164607,
#      167293,
#      150029,
#      22802,
#      76633,
#      63685,
#      31396,
#      644,
#      621,
#      76630,
#      63646,
#      27216,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      20483,
#      142441,
#      63708,
#      672,
#      195519,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      141803,
#      23927,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      23926,
#      661,
#      565,
#      601,
#      118201,
#      31397,
#      63669,
#      22307,
#      2213,
#      63643,
#      127689,
#      170645,
#      63676,
#      176419,
#      634,
#      31377,
#      68945,
#      34327,
#      191903,
#      564,
#      127687,
#      22807,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572606114000,
#     'destination': ['NAT',
#      'PTD',
#      'C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'ABN',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'Z',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'UKI',
#      'OIL',
#      'RWSA',
#      'RAST',
#      'PEN',
#      'PCM',
#      'AFA'],
#     'geography': ['VN', 'GB', 'CN', 'IE', 'BG'],
#     'guid': 'tag:reuters.com,2019:newsml_L9N26H01Q',
#     'headline': 'UK police appeal for two brothers from N.Ireland to hand themselves in over truck deaths',
#     'id': 'tag:reuters.com,2019:newsml_L9N26H01Q:845204606',
#     'indexTimestamp': 1572606119796,
#     'internalReceivedDate': 1572606119796,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 2,
#     'signal': ['sig:update',
#      'prodId:TXT',
#      'pmt:text',
#      'source:ids',
#      'edStat:U'],
#     'slug': 'BRITAIN-BODIES/ (URGENT, TV)',
#     'source': 'Thomson Reuters',
#     'version': 845204606},
#    {'author': 'By Lisa Richwine and Stephen Nellis',
#     'channelIds': [24785,
#      76637,
#      63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      63693,
#      121245,
#      57606,
#      27217,
#      154815,
#      180027,
#      159019,
#      63675,
#      54560,
#      643,
#      153329,
#      159011,
#      583,
#      77679,
#      63667,
#      539,
#      23369,
#      27212,
#      26789,
#      153673,
#      63685,
#      49344,
#      644,
#      159025,
#      182977,
#      26561,
#      76630,
#      170643,
#      27199,
#      44352,
#      158991,
#      142441,
#      195519,
#      635,
#      159015,
#      141803,
#      150287,
#      42799,
#      180023,
#      41078,
#      661,
#      565,
#      27066,
#      26781,
#      118201,
#      2213,
#      63686,
#      24466,
#      23306,
#      32589,
#      37672,
#      176419,
#      634,
#      187915,
#      633,
#      620,
#      564,
#      152757,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572602400000,
#     'destination': ['PSC',
#      'LBY',
#      'PCU',
#      'E',
#      'G',
#      'DNP',
#      'ABN',
#      'RLF',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RVES',
#      'RNP',
#      'U',
#      'FWE',
#      'RWSA',
#      'REUVF',
#      'RAST',
#      'REULB',
#      'AFA',
#      'PCO',
#      'RBN'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27F2CV',
#     'headline': 'AppleTV+ debuts streaming TV service with Oprah and Aniston',
#     'id': 'tag:reuters.com,2019:newsml_L2N27F2CV:1176352693',
#     'indexTimestamp': 1572602409052,
#     'internalReceivedDate': 1572602409052,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEDIA-APPLE/APPLETV (PIX, TV)',
#     'source': 'Thomson Reuters',
#     'version': 1176352693},
#    {'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      34325,
#      63693,
#      57606,
#      154815,
#      180027,
#      63675,
#      63699,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      22798,
#      150029,
#      31376,
#      76633,
#      63685,
#      644,
#      31395,
#      182977,
#      63646,
#      27199,
#      44352,
#      211865,
#      180029,
#      158991,
#      142441,
#      610,
#      648,
#      635,
#      62870,
#      22283,
#      159015,
#      180025,
#      180033,
#      180023,
#      561,
#      41078,
#      661,
#      565,
#      601,
#      118201,
#      63669,
#      2213,
#      68945,
#      34327,
#      191903,
#      564,
#      180031,
#      63655,
#      70595,
#      30480,
#      63709,
#      554],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572602251000,
#     'destination': ['C',
#      'MTL',
#      'D',
#      'E',
#      'GRO',
#      'G',
#      'DNP',
#      'M',
#      'GNS',
#      'O',
#      'CSA',
#      'RNP',
#      'U',
#      'SI',
#      'REULB',
#      'RBN',
#      'PSC',
#      'LBY',
#      'SOF',
#      'PGE',
#      'RWS',
#      'UCDPTEST',
#      'OIL',
#      'RWSA',
#      'AFA'],
#     'geography': ['MM', 'TH', 'BD'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G4K4',
#     'headline': 'Thai court increases prison time for officials in Rohingya trafficking case',
#     'id': 'tag:reuters.com,2019:newsml_L3N27G4K4:110591051',
#     'indexTimestamp': 1572602255727,
#     'internalReceivedDate': 1572602255727,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'THAILAND-TRAFFICKING/',
#     'source': 'Thomson Reuters',
#     'version': 110591051},
#    {'author': 'By Michael Taylor, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      27217,
#      154815,
#      23929,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      27212,
#      22802,
#      204119,
#      26789,
#      63685,
#      644,
#      182977,
#      170643,
#      23751,
#      27216,
#      211865,
#      142441,
#      195519,
#      635,
#      22283,
#      159015,
#      26780,
#      23927,
#      41078,
#      31388,
#      118201,
#      31387,
#      162059,
#      26788,
#      2213,
#      127689,
#      170645,
#      634,
#      187915,
#      66631,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572599941000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MY', 'US', 'ID'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G2IU',
#     'headline': 'Palm oil giants double down on deforestation with new radar system',
#     'id': 'tag:reuters.com,2019:newsml_L3N27G2IU:1222774372',
#     'indexTimestamp': 1572599946676,
#     'internalReceivedDate': 1572599946676,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'ASIA-FOREST/PALMOIL',
#     'source': 'Thomson Reuters',
#     'version': 1222774372},
#    {'channelIds': [37917,
#      176417,
#      54560,
#      643,
#      75332,
#      159011,
#      574,
#      549,
#      66931,
#      63427,
#      63446,
#      644,
#      540,
#      211865,
#      20483,
#      142441,
#      63436,
#      159015,
#      176425,
#      63439,
#      41078,
#      118201,
#      2213,
#      24466,
#      176419,
#      634,
#      633],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572587592000,
#     'destination': ['LBY',
#      'BNX',
#      'RLF',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RVES',
#      'RWSA',
#      'RAST',
#      'REUVF',
#      'ABX',
#      'REULB',
#      'AFA',
#      'FUN'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27H1CI',
#     'headline': 'REUTERS NEWS SCHEDULE AT 6 a.m. GMT/2 p.m. SGT',
#     'id': 'tag:reuters.com,2019:newsml_L3N27H1CI:818295714',
#     'indexTimestamp': 1572587597883,
#     'internalReceivedDate': 1572587597883,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'REUTERS-SCHEDULE/',
#     'source': 'Thomson Reuters',
#     'version': 818295714},
#    {'author': 'By Layli Foroudi, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      22800,
#      55889,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      27212,
#      204119,
#      63685,
#      644,
#      182977,
#      27216,
#      211865,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      118201,
#      26788,
#      2213,
#      26791,
#      66631,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572570000000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['TN'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N26M5NV',
#     'headline': "FEATURE-Thirsty crops, leaky infrastructure drive Tunisia's water crisis",
#     'id': 'tag:reuters.com,2019:newsml_L5N26M5NV:442911856',
#     'indexTimestamp': 1572570007441,
#     'internalReceivedDate': 1572570007441,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'TUNISIA-WATER/LAND (FEATURE, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 442911856},
#    {'author': 'By Lefteris Papadimas',
#     'channelIds': [37917,
#      144993,
#      626,
#      154817,
#      159003,
#      176417,
#      63692,
#      22321,
#      208945,
#      154815,
#      86273,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      26785,
#      591,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      27215,
#      41078,
#      118201,
#      2213,
#      63659,
#      70937,
#      47543,
#      46844,
#      564,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572568071000,
#     'destination': ['PSC',
#      'LBY',
#      'GNN',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GR'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G85Y',
#     'headline': "UPDATE 1-Migrants in Greece living in 'horrible' conditions, says Europe rights watchdog",
#     'id': 'tag:reuters.com,2019:newsml_L8N27G85Y:272515641',
#     'indexTimestamp': 1572568074457,
#     'internalReceivedDate': 1572568074457,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'EUROPE-MIGRANTS/GREECE-ASYLUM (UPDATE 1, PIX, TV)',
#     'source': 'Thomson Reuters',
#     'version': 272515641},
#    {'channelIds': [37917,
#      176417,
#      54560,
#      643,
#      159011,
#      549,
#      66931,
#      63427,
#      63446,
#      644,
#      540,
#      211865,
#      142441,
#      63436,
#      159015,
#      176425,
#      63439,
#      41078,
#      118201,
#      2213,
#      24466,
#      176419,
#      634,
#      633],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572567687000,
#     'destination': ['LBY',
#      'BNX',
#      'RLF',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RVES',
#      'RWSA',
#      'RAST',
#      'REUVF',
#      'ABX',
#      'REULB',
#      'AFA',
#      'FUN'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27H03T',
#     'headline': 'REUTERS NEWS SCHEDULE AT 12:30 a.m. GMT/8:30 p.m. ET',
#     'id': 'tag:reuters.com,2019:newsml_L3N27H03T:223579017',
#     'indexTimestamp': 1572567693354,
#     'internalReceivedDate': 1572567693354,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'REUTERS-SCHEDULE/',
#     'source': 'Thomson Reuters',
#     'version': 223579017},
#    {'channelIds': [37917,
#      176417,
#      159011,
#      63446,
#      644,
#      211865,
#      142441,
#      159015,
#      41078,
#      118201,
#      2213],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572555334000,
#     'destination': ['CSA',
#      'UCDPTEST',
#      'LBY',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27G2CM',
#     'headline': 'Reuters Entertainment News Summary',
#     'id': 'tag:reuters.com,2019:newsml_L2N27G2CM:277102222',
#     'indexTimestamp': 1572555336416,
#     'internalReceivedDate': 1572555336416,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 4,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BC-LEISURE',
#     'source': 'Thomson Reuters',
#     'version': 277102222},
#    {'author': 'By Nellie Peyton, Thomson Reuters Foundation',
#     'channelIds': [542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      154815,
#      70666,
#      75332,
#      29598,
#      46622,
#      63633,
#      159011,
#      583,
#      63667,
#      199799,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      47543,
#      66631,
#      191903,
#      564,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572551429000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GM'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E5QE',
#     'headline': 'Gambian women testify about sex abuse under ex-president Jammeh',
#     'id': 'tag:reuters.com,2019:newsml_L8N27E5QE:785936669',
#     'indexTimestamp': 1572551434083,
#     'internalReceivedDate': 1572551434083,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'GAMBIA-POLITICS/SEXCRIMES (PIX)',
#     'source': 'Thomson Reuters',
#     'version': 785936669},
#    {'author': 'By Megan Rowling, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      23929,
#      27253,
#      22170,
#      211145,
#      22791,
#      75332,
#      159011,
#      583,
#      63667,
#      150029,
#      157307,
#      204119,
#      63685,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      63708,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      23926,
#      118201,
#      162059,
#      2213,
#      127689,
#      634,
#      31372,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572549320000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['DE', 'CL'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G92A',
#     'headline': 'UPDATE 1-Uncertainty over UN talks must not delay climate action, green groups say',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G92A:858358431',
#     'indexTimestamp': 1572549325106,
#     'internalReceivedDate': 1572549325106,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CLIMATE-CHANGE/CHILE-UN (UPDATE 1)',
#     'source': 'Thomson Reuters',
#     'version': 858358431},
#    {'author': 'By Rosa Furneaux, Thomson Reuters Foundation',
#     'channelIds': [22386,
#      63683,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      88661,
#      22321,
#      131355,
#      55889,
#      154815,
#      23309,
#      153329,
#      211145,
#      75332,
#      23754,
#      22383,
#      159011,
#      583,
#      77679,
#      63667,
#      66918,
#      164607,
#      150029,
#      27212,
#      204119,
#      153673,
#      63685,
#      644,
#      159025,
#      182977,
#      159017,
#      27216,
#      211865,
#      68970,
#      158991,
#      142441,
#      63708,
#      195519,
#      635,
#      22283,
#      159015,
#      141803,
#      150287,
#      41078,
#      26781,
#      118201,
#      162059,
#      26788,
#      2213,
#      127689,
#      23306,
#      634,
#      47543,
#      23279,
#      93099,
#      66631,
#      564,
#      127687,
#      152757,
#      22807,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572542732000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['DE', 'GB', 'AU', 'IE', 'CA', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27F7PN',
#     'headline': 'From beer to beauty, sales of vegan products surging with UK consumers fuelling the rise',
#     'id': 'tag:reuters.com,2019:newsml_L8N27F7PN:1380119384',
#     'indexTimestamp': 1572542739079,
#     'internalReceivedDate': 1572542739079,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'BRITAIN-CLIMATE/VEGANS',
#     'source': 'Thomson Reuters',
#     'version': 1380119384},
#    {'author': 'By Megan Rowling, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      22321,
#      131355,
#      55889,
#      154815,
#      23929,
#      27253,
#      22170,
#      211145,
#      22791,
#      75332,
#      159011,
#      583,
#      63667,
#      150029,
#      157307,
#      204119,
#      63685,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      63708,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      23926,
#      118201,
#      162059,
#      2213,
#      127689,
#      634,
#      31372,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572534059000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['DE', 'CL'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27G655',
#     'headline': 'Uncertainty over UN talks must not delay climate action, green groups say',
#     'id': 'tag:reuters.com,2019:newsml_L8N27G655:432604993',
#     'indexTimestamp': 1572534064763,
#     'internalReceivedDate': 1572534064763,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CLIMATE-CHANGE/CHILE-UN',
#     'source': 'Thomson Reuters',
#     'version': 432604993},
#    {'author': 'By Angela Moore',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      27217,
#      154815,
#      54560,
#      643,
#      159011,
#      583,
#      63667,
#      63685,
#      49344,
#      644,
#      182977,
#      26561,
#      170643,
#      20483,
#      142441,
#      195519,
#      635,
#      159015,
#      41078,
#      26781,
#      118201,
#      2213,
#      63686,
#      127689,
#      24466,
#      37672,
#      176419,
#      634,
#      187915,
#      633,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1572523200000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'RLF',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RVES',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REUVF',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['US', 'GB'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27F2CG',
#     'headline': "Movie 'Harriet' tells a different story about U.S. slavery",
#     'id': 'tag:reuters.com,2019:newsml_L2N27F2CG:1981153785',
#     'indexTimestamp': 1572523203340,
#     'internalReceivedDate': 1572523203340,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'FILM-HARRIET/ (TV, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1981153785},
#    {'author': 'By Michael Taylor, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      23925,
#      542,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      154815,
#      23929,
#      27253,
#      22170,
#      31371,
#      70666,
#      211145,
#      22791,
#      75332,
#      29598,
#      23754,
#      63633,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      157307,
#      22802,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      23751,
#      27216,
#      211865,
#      158991,
#      142441,
#      195519,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      26780,
#      23927,
#      41078,
#      118201,
#      31387,
#      162059,
#      2213,
#      127689,
#      170645,
#      634,
#      66631,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572517658000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['BR', 'CD', 'ID', 'AU', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L3N27G291',
#     'headline': 'Carbon emissions from tropical forest loss underestimated, scientists say',
#     'id': 'tag:reuters.com,2019:newsml_L3N27G291:4890607',
#     'indexTimestamp': 1572517663891,
#     'internalReceivedDate': 1572517663891,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'GLOBAL-FORESTS/EMISSIONS',
#     'source': 'Thomson Reuters',
#     'version': 4890607},
#    {'author': 'By K. Sophie Will, Thomson Reuters Foundation',
#     'channelIds': [173671,
#      63683,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      22321,
#      55889,
#      154815,
#      23929,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      150029,
#      27212,
#      204119,
#      63685,
#      644,
#      182977,
#      23751,
#      211865,
#      158991,
#      20483,
#      142441,
#      63708,
#      635,
#      22283,
#      159015,
#      41078,
#      26781,
#      118201,
#      26788,
#      2213,
#      127689,
#      170645,
#      634,
#      66631,
#      564,
#      127687,
#      22807,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572516207000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'UKI',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GB'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E5H9',
#     'headline': "Here's a trick: Recycle that pumpkin and cut Halloween waste",
#     'id': 'tag:reuters.com,2019:newsml_L8N27E5H9:1859875627',
#     'indexTimestamp': 1572516209498,
#     'internalReceivedDate': 1572516209498,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'HALLOWEEN-CLIMATE-CHANGE/BRITAIN',
#     'source': 'Thomson Reuters',
#     'version': 1859875627},
#    {'author': 'By Umberto Bacchi, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      626,
#      63692,
#      22321,
#      131355,
#      55889,
#      23325,
#      75332,
#      154257,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      63686,
#      127689,
#      24466,
#      634,
#      633,
#      66631,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572483661000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'RLF',
#      'GNS',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GB', 'CN', 'FR', 'US', 'ES'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E30I',
#     'headline': "FACTBOX-Cages, pods and containers: 8 homes highlighting cities' housing strains",
#     'id': 'tag:reuters.com,2019:newsml_L8N27E30I:55370042',
#     'indexTimestamp': 1572483667624,
#     'internalReceivedDate': 1572483667624,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'LANDRIGHTS-HOUSING/HOMELESSNESS (FACTBOX)',
#     'source': 'Thomson Reuters',
#     'version': 55370042},
#    {'author': 'By Nanchanok Wongsamuth, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      626,
#      63692,
#      22321,
#      55889,
#      75332,
#      583,
#      63685,
#      644,
#      211865,
#      142441,
#      22283,
#      41078,
#      118201,
#      2213,
#      66631,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572483600000,
#     'destination': ['CSA',
#      'PSC',
#      'UCDPTEST',
#      'LBY',
#      'TRFDN',
#      'RWSA',
#      'G',
#      'REULB',
#      'AFA',
#      'GNS',
#      'RWS',
#      'RBN'],
#     'geography': ['TH'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N27E22N',
#     'headline': 'INTERVIEW -Thai chef aims to turn insect eating into fine dining',
#     'id': 'tag:reuters.com,2019:newsml_L8N27E22N:791291950',
#     'indexTimestamp': 1572483604971,
#     'internalReceivedDate': 1572483604971,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'THAILAND-FOOD/CHEF (INTERVIEW, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 791291950},
#    {'author': 'By Beh Lih Yi, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      75332,
#      651,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      63698,
#      644,
#      182977,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      118201,
#      31387,
#      2213,
#      634,
#      47543,
#      191903,
#      564,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1572480060000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'SNS',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['ID'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N24A00L',
#     'headline': "FEATURE -In Indonesia, 'bride kidnapping' tradition fuels child marriage despite new ban",
#     'id': 'tag:reuters.com,2019:newsml_L8N24A00L:1250137644',
#     'indexTimestamp': 1572480063980,
#     'internalReceivedDate': 1572480063980,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'INDONESIA-WOMEN/MARRIAGE (FEATURE, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1250137644},
#    {'author': 'By Sonia Elks, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      662,
#      63692,
#      131355,
#      27217,
#      154815,
#      159011,
#      583,
#      63667,
#      27212,
#      204119,
#      63685,
#      49344,
#      644,
#      182977,
#      170643,
#      158991,
#      142441,
#      63708,
#      195519,
#      635,
# ...
#      66631,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571224163000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N26H2KF',
#     'headline': 'FEATURE-Bans, censors, jail: perfect storm for gay arts in Singapore?',
#     'id': 'tag:reuters.com,2019:newsml_L5N26H2KF:964477214',
#     'indexTimestamp': 1571224167950,
#     'internalReceivedDate': 1571224167950,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'SINGAPORE-LGBT/ENTERTAINMENT (FEATURE, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 964477214},
#    {'author': 'By Kim Harrisberg and Anastasia Moloney, Thomson Reuters Foundation',
#     'channelIds': [159335,
#      542,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      63697,
#      131355,
#      55889,
#      27217,
#      159023,
#      647,
#      70666,
#      31418,
#      75332,
#      29598,
#      23754,
#      46622,
#      63633,
#      159011,
#      583,
#      63667,
#      22798,
#      150029,
#      204119,
#      26789,
#      63685,
#      644,
#      182977,
#      27216,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      23927,
#      31373,
#      41078,
#      118201,
#      23278,
#      2213,
#      170645,
#      47543,
#      187915,
#      23340,
#      66631,
#      191903,
#      564,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571216400000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'SF',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['CO', 'ZA'],
#     'guid': 'tag:reuters.com,2019:newsml_L8N2583XX',
#     'headline': 'FEATURE-Guns or yoga? City crime fighters in South Africa and Colombia',
#     'id': 'tag:reuters.com,2019:newsml_L8N2583XX:1816780714',
#     'indexTimestamp': 1571216405582,
#     'internalReceivedDate': 1571216405582,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CITIES-FUTURE/SAFRICA (FEATURE, PIX, VIDEO)',
#     'source': 'Thomson Reuters',
#     'version': 1816780714},
#    {'author': 'By Zoe Tabary, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      542,
#      37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      131355,
#      22800,
#      55889,
#      161681,
#      27217,
#      23325,
#      70666,
#      22791,
#      31418,
#      75332,
#      29598,
#      23754,
#      46622,
#      63633,
#      159011,
#      583,
#      63667,
#      66918,
#      150029,
#      26789,
#      63685,
#      644,
#      27216,
#      211865,
#      158991,
#      31419,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      23927,
#      31373,
#      41078,
#      118201,
#      2213,
#      127689,
#      634,
#      31377,
#      31378,
#      22635,
#      93099,
#      66631,
#      191903,
#      564,
#      127687,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571216400000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GB', 'CN', 'AE', 'CO', 'US', 'ZA'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N26B4MI',
#     'headline': 'INSIGHT-Urban humans: Cities go up, down and high-tech to combat rising threats',
#     'id': 'tag:reuters.com,2019:newsml_L5N26B4MI:1283921418',
#     'indexTimestamp': 1571216409746,
#     'internalReceivedDate': 1571216409746,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'CITIES-FUTURE/SOLUTIONS (INSIGHT)',
#     'source': 'Thomson Reuters',
#     'version': 1283921418},
#    {'author': 'By Rina Chandran, Thomson Reuters Foundation',
#     'channelIds': [37917,
#      26786,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      161681,
#      27217,
#      154815,
#      75332,
#      23754,
#      159011,
#      583,
#      31391,
#      63667,
#      164607,
#      150029,
#      26789,
#      63685,
#      31396,
#      644,
#      31395,
#      182977,
#      170643,
#      27216,
#      211865,
#      142441,
#      195519,
#      635,
#      22283,
#      154381,
#      159015,
#      41078,
#      31388,
#      118201,
#      31387,
#      2213,
#      187915,
#      93099,
#      66631,
#      191903,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571213040000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['VN', 'PH', 'ID', 'TH', 'MY'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N2703UC',
#     'headline': "In Asia's booming cities, urban planners urged to include the poor",
#     'id': 'tag:reuters.com,2019:newsml_L5N2703UC:509560390',
#     'indexTimestamp': 1571213044820,
#     'internalReceivedDate': 1571213044820,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'LANDRIGHTS-CITIES/PLANNING',
#     'source': 'Thomson Reuters',
#     'version': 509560390},
#    {'author': 'By Kagondu Njagi, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      542,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      55889,
#      27217,
#      23929,
#      70666,
#      211145,
#      22791,
#      75332,
#      29598,
#      23754,
#      63633,
#      159011,
#      583,
#      63667,
#      167293,
#      150029,
#      27212,
#      22802,
#      204119,
#      26789,
#      63685,
#      644,
#      182977,
#      27216,
#      211865,
#      158991,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      26780,
#      23927,
#      41078,
#      118201,
#      26788,
#      2213,
#      34283,
#      170645,
#      634,
#      47543,
#      187915,
#      66631,
#      564,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571202006000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'DNP',
#      'AFN',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['GH'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N25V6RX',
#     'headline': "FEATURE-Innovation buzz: Drones help Ghana's farmers ward off birds - and drought risks",
#     'id': 'tag:reuters.com,2019:newsml_L5N25V6RX:1292224850',
#     'indexTimestamp': 1571202011100,
#     'internalReceivedDate': 1571202011100,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'GHANA-FARMING/DRONES (FEATURE, PIX)',
#     'source': 'Thomson Reuters',
#     'version': 1292224850},
#    {'author': 'By Thin Lei Win, Thomson Reuters Foundation',
#     'channelIds': [173671,
#      63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      88661,
#      22321,
#      131355,
#      22800,
#      55889,
#      154815,
#      23929,
#      211145,
#      22791,
#      75332,
#      23754,
#      159011,
#      583,
#      63667,
#      66918,
#      150029,
#      27212,
#      157307,
#      204119,
#      63685,
#      644,
#      182977,
#      88663,
#      23751,
#      211865,
#      142441,
#      635,
#      22283,
#      23742,
#      22285,
#      159015,
#      41078,
#      118201,
#      26788,
#      2213,
#      34283,
#      127689,
#      170645,
#      634,
#      47543,
#      66631,
#      127687,
#      177157,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571202000000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['RW', 'NP', 'US'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N26S45R',
#     'headline': 'EXPERT VIEWS-Changing incentives and policies crucial to end hunger and malnutrition',
#     'id': 'tag:reuters.com,2019:newsml_L5N26S45R:549001438',
#     'indexTimestamp': 1571202004787,
#     'internalReceivedDate': 1571202004787,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'GLOBAL-FOOD/HUNGER',
#     'source': 'Thomson Reuters',
#     'version': 549001438},
#    {'author': 'By David Shepardson',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      176417,
#      63692,
#      22321,
#      63693,
#      121245,
#      57606,
#      27217,
#      154815,
#      180027,
#      159019,
#      63675,
#      153329,
#      75332,
#      159011,
#      574,
#      583,
#      77679,
#      63667,
#      539,
#      63672,
#      23369,
#      150029,
#      549,
#      204119,
#      26789,
#      63685,
#      644,
#      76630,
#      540,
#      170643,
#      27199,
#      44352,
#      158991,
#      20483,
#      142441,
#      195519,
#      635,
#      22283,
#      159015,
#      176425,
#      42799,
#      180023,
#      41078,
#      23926,
#      661,
#      565,
#      118201,
#      2213,
#      127689,
#      32589,
#      176419,
#      634,
#      187915,
#      620,
#      191903,
#      564,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1571182550000,
#     'destination': ['PSC',
#      'LBY',
#      'PCU',
#      'E',
#      'G',
#      'DNP',
#      'ABN',
#      'BNX',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'U',
#      'RWSA',
#      'RAST',
#      'ABX',
#      'REULB',
#      'AFA',
#      'PCO',
#      'FUN',
#      'RBN'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N2701L6',
#     'headline': 'Google, Reddit defend tech legal protections ahead of Congress hearing',
#     'id': 'tag:reuters.com,2019:newsml_L2N2701L6:114479279',
#     'indexTimestamp': 1571182553571,
#     'internalReceivedDate': 1571182553571,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['sic:CPX', 'prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'USA-TECHNOLOGY/CONGRESS',
#     'source': 'Thomson Reuters',
#     'version': 114479279},
#    {'author': 'By Ross Kerber and Tim McLaughlin',
#     'channelIds': [159021,
#      159335,
#      63683,
#      37917,
#      32590,
#      144993,
#      626,
#      27138,
#      159003,
#      176417,
#      63692,
#      22321,
#      63693,
#      22800,
#      121245,
#      57606,
#      154815,
#      180027,
#      63675,
#      153329,
#      159011,
#      574,
#      583,
#      77679,
#      63667,
#      66918,
#      539,
#      63672,
#      549,
#      26787,
#      48620,
#      63685,
#      644,
#      76630,
#      540,
#      27214,
#      27199,
#      44352,
#      211865,
#      158991,
#      20483,
#      142441,
#      635,
#      159015,
#      176425,
#      42799,
#      23371,
#      180023,
#      41078,
#      661,
#      565,
#      160503,
#      118201,
#      139745,
#      2213,
#      127689,
#      170645,
#      176419,
#      634,
#      26784,
#      620,
#      564,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'RTRS',
#     'contributorName': 'Reuters',
#     'dateCreated': 1571181697000,
#     'destination': ['PSC',
#      'LBY',
#      'PCU',
#      'E',
#      'G',
#      'DNP',
#      'ABN',
#      'BNX',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'U',
#      'RWSA',
#      'RAST',
#      'ABX',
#      'REULB',
#      'AFA',
#      'PCO',
#      'FUN',
#      'RBN'],
#     'geography': ['US'],
#     'guid': 'tag:reuters.com,2019:newsml_L2N27019G',
#     'headline': 'UPDATE 3-Fidelity criticizes money manager Fisher, who loses Philadelphia as client',
#     'id': 'tag:reuters.com,2019:newsml_L2N27019G:598564934',
#     'indexTimestamp': 1571181702429,
#     'internalReceivedDate': 1571181702429,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:U'],
#     'slug': 'FUNDS-FIDELITY/FISHER (UPDATE 3)',
#     'source': 'Thomson Reuters',
#     'version': 598564934},
#    {'author': 'By Oscar Lopez, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      27217,
#      154815,
#      75332,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      63685,
#      49344,
#      644,
#      182977,
#      170643,
#      211865,
#      20483,
#      142441,
#      195519,
#      635,
#      22283,
#      159015,
#      23927,
#      41078,
#      27066,
#      26781,
#      31374,
#      118201,
#      2213,
#      37672,
#      634,
#      187915,
#      191903,
#      63655,
#      70595,
#      30480],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571179842000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['MX'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N2706LH',
#     'headline': 'Money for combating violence against women misused, Mexican official says',
#     'id': 'tag:reuters.com,2019:newsml_L5N2706LH:969787750',
#     'indexTimestamp': 1571179845687,
#     'internalReceivedDate': 1571179845687,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'MEXICO/WOMEN-VIOLENCE',
#     'source': 'Thomson Reuters',
#     'version': 969787750},
#    {'author': 'By Sonia Elks, Thomson Reuters Foundation',
#     'channelIds': [63683,
#      37917,
#      144993,
#      626,
#      159003,
#      63692,
#      22321,
#      131355,
#      22800,
#      55889,
#      154815,
#      159023,
#      75332,
#      23754,
#      46622,
#      159011,
#      583,
#      63667,
#      150029,
#      204119,
#      63685,
#      644,
#      182977,
#      170643,
#      142441,
#      635,
#      159015,
#      23927,
#      41078,
#      118201,
#      2213,
#      63686,
#      127689,
#      24466,
#      634,
#      633,
#      23340,
#      66631,
#      191903,
#      127687,
#      63655,
#      70595],
#     'channels': ['STK567'],
#     'contributorId': 'TRFN',
#     'contributorName': 'Thomson Reuters Foundation',
#     'dateCreated': 1571159645000,
#     'destination': ['PSC',
#      'LBY',
#      'G',
#      'RLF',
#      'GNS',
#      'PGE',
#      'RWS',
#      'CSA',
#      'UCDPTEST',
#      'TRFDN',
#      'RNP',
#      'RWSA',
#      'RAST',
#      'REULB',
#      'AFA',
#      'RBN'],
#     'geography': ['AR', 'US', 'CR'],
#     'guid': 'tag:reuters.com,2019:newsml_L5N2703OD',
#     'headline': "TIMELINE-Hollywood to Nollywood: Key moments in #MeToo's rise as a global movement",
#     'id': 'tag:reuters.com,2019:newsml_L5N2703OD:317756254',
#     'indexTimestamp': 1571159650408,
#     'internalReceivedDate': 1571159650408,
#     'language': 'en',
#     'mediaType': 'T',
#     'priority': 3,
#     'signal': ['prodId:TXT', 'pmt:text', 'source:ids', 'edStat:N'],
#     'slug': 'USA-WOMEN/METOO (TIMELINE)',
#     'source': 'Thomson Reuters',
#     'version': 317756254}],
#   'size': 300,
#   'start': 0,
#   'status': {'code': 20,
#    'errors': [{'faultcode': 1002,
#      'faultstring': 'Start date has been modified to 2019-10-03T13:37:12.075Z'}]}}}
